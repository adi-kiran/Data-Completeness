# %%
import json
import math
import pandas as pd
import numpy as np
import urllib
from itertools import combinations
from nltk.corpus import wordnet
from IPython.display import display

# %%
#preloading data such as schemas, categories and cos similarity values which we have ready for our dataset

#preloading all schemas and categories
all_schemas={}
all_categories={}
all_tablenames={}
with open("final_schema.txt") as ip_file:
    for line in ip_file.readlines():
        json_obj=json.loads(line)
        all_schemas[json_obj["filename"]]=json_obj["schema"]
        all_categories[json_obj["filename"]]=json_obj["categories"]
        all_tablenames[json_obj["filename"]]=json_obj["tablename"]
        
#preloading the candidate keys
with open("Candidate_key_dict.txt",'r') as ip_file:
    cand_key=json.load(ip_file)

#preloading column and category similarity values of tables
with open("cos_similarity.txt",'r') as ip_file:
    json_object=json.load(ip_file)
    col_sim = json_object["column_similarity"]
    cat_sim = json_object["category_similarity"]

# %%
# all functions needed to generate ontologies
def get_synonyms(word):
    meanings=set()
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for lemma in synset.lemmas():
            meanings.add(lemma.name())
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for hypernym in synset.hypernyms():
            meanings.add(hypernym.lemma_names()[0])
    meanings.add(word)
    return list(meanings)

# takes input list and returns ontology as dictionary with every word in list as the key
def generate_ontology(list1):
    ontology={}
    for word in list1:
        ontology[word]=get_synonyms(word)
    return ontology

# %%
x={'date': 'object', 'nationality': 'object', 'tonnage': 'int64', 'fate': 'object'}
y=['indian','diabetes','medical','association']
print(x,"\n","\n",generate_ontology(x),"\n")
print(y,"\n","\n",generate_ontology(y))
# Out:
# {'date': 'object', 'nationality': 'object', 'tonnage': 'int64', 'fate': 'object'}
#
#  {'date': ['escort', 'companion', 'appointment', 'point', 'particular_date', 'calendar_year', 'present', 'day', 'calendar_month', 'calendar_day', 'date', 'engagement', 'day_of_the_month', 'meeting', 'edible_fruit'], 'nationality': ['people', 'status', 'nationality'], 'tonnage': ['tonnage', 'tunnage', 'tonnage_duty', 'duty'], 'fate': ['luck', 'fate', 'lot', 'happening', 'condition', 'circumstances', 'fortune', 'causal_agent', 'portion', 'destiny']}
#
# ['indian', 'diabetes', 'medical', 'association']
#
#  {'indian': ['American_Indian', 'indian', 'natural_language', 'Asian', 'Amerindian_language', 'Indian', 'Amerindian', 'Red_Indian', 'American-Indian_language', 'Amerind'], 'diabetes': ['polygenic_disorder', 'diabetes'], 'medical': ['medical_exam', 'checkup', 'medical', 'medical_examination', 'health_check', 'medical_checkup', 'examination'], 'association': ['relation', 'connexion', 'connection', 'tie', 'social_activity', 'union', 'tie-up', 'group', 'memory', 'chemical_process', 'affiliation', 'association', 'relationship', 'organization']}

# %%
# making a list of transformation functions
tf_onto={}
transform_funct_list={"int64":['average','sum','maximum','minimum','range','median','variance','standard deviation','mode','frequency','avg'],"float64":['average','sum','maximum','minimum','range','median','variance','standard deviation','mode','frequency','avg'],"object":["tolower","toupper","substring","funct1","funct2","funct3"]}
for dtype,funct_list in transform_funct_list.items():
    tf_onto[dtype]=generate_ontology(funct_list)
# initialising knowledge graph data dictionary
kg_data={}
# making a list of all statistical functions and the various signs and combinations 
signs = ["<=",">=","<",">","=","!="]; functs =  ['count','mean','standard deviation','min','max','25%','50%','75%']; functs_onto = generate_ontology(functs)
functs_onto['25%'].append("first quartile");functs_onto['75%'].append("third quartile");functs_onto['50%'].append("second quartile");functs_onto['min'].append("minimum");functs_onto['max'].append("maximum")

# %%
#getting the input data: 1)schema 2)categories 3)transformations and 4)statistical functions requested

#import the input schema
with open("input_tranformations.txt",'r') as ip_file:
        ip_schema=json.load(ip_file)
input_schema=ip_schema["schema"]
#categories is an optional input, so it may or ay not be there
#if present it gives us more accurate otput matches
if "categories" in ip_schema:
    input_categories=ip_schema["categories"]
else:
    input_categories=-1
#transformations is an optional input
#if present we must determine if it is applicable on the column required by the user
if "transformations" in ip_schema:
    transformations=ip_schema["transformations"]
else:
    transformations=-1
# statistical conditions are an optional input
# if present we must determine which conditions are satisfied or not
if "stats" in ip_schema:
    stats=ip_schema["stats"]
else:
    stats=-1

# %%
# to generate cos similarity between two lists
def cos_sim(list1, list2):
    terms = set(list1).union(list2)
    intersect = set(list1) & set(list2)
    others = (set(list1)-intersect).union(set(list2)-intersect)
    product=0
    for word in terms:
        if word in intersect:
            product+=1
    l1mag = math.sqrt(len(list1))
    l2mag = math.sqrt(len(list2))
    if len(list1)==0 or len(list2)==0:
        return 0.0
    else:
        return product / (l1mag * l2mag)

# %%
a=["fate","tonnage","cost","boat","location","nationality"]
b=["boat","location","nationality","name","port","captian"]
print("a : ",a)
print("b : ",b)
print("cosine similarity score between a and b : ",cos_sim(a,b))
# Out:
# a :  ['fate', 'tonnage', 'cost', 'boat', 'location', 'nationality']
# b :  ['boat', 'location', 'nationality', 'name', 'port', 'captian']
# cosine similarity score between a and b :  0.5000000000000001

# %%
# if input has only schema(columns and their dataypes)
# it returns a list of all tables with one or more columns that match with input schema(or its ontology)
def col_only_list(input_schema,input_sch_onto):
    possible_tables={}
    for file in all_schemas:
        schema=all_schemas[file]
        cols1={col1:col1 for col1,d_type1 in schema.items() if col1 in input_schema and d_type1==input_schema[col1]}
        schema={k:v for k,v in schema.items() if k not in list(cols1.values())}
        cols2={col1:col for col1,d_type1 in schema.items() for col in input_sch_onto if col1 in input_sch_onto[col] and d_type1==input_schema[col]}
        schema={k:v for k,v in schema.items() if k not in cols1}
        cols={**cols1,**cols2}
        ip_schema={k:v for k,v in input_schema.items() if k not in list(cols.values())}
        for col1,d_type1 in ip_schema.items():
            x=[col2 for col2,d_type2 in schema.items() if ((len(col1)>3 and len(col2)>3) and ((col1 in col2) or (col2 in col1))) and (d_type1==d_type2)]
            if len(x)==1:
                cols[x[0]]=col1
        if(len(cols)>1):
            possible_tables[file]=cols       
    return possible_tables

# if input has categories as well as schema(columns and their dataypes)
# we consider it a match under the assumption that at least 75% category match exists
# then all tables that meet this criteria and have one or more columns that match are retured as a list 
def cat_and_col_list(input_categories,input_cat_onto,input_schema,input_sch_onto):
    possible_tables={}
    for file in all_categories:
        category=all_categories[file]
        cats1=[cat1 for cat1 in category if cat1 in input_categories]
        category=[k for k in category if k not in cats1]
        cats2=[cat2 for cat1 in category for cat2 in input_cat_onto if cat1 in input_cat_onto[cat2]]
        cat_list=cats1+cats2
        cos_val=cos_sim(cat_list,input_categories)
        if cos_val > 0.75 :
            schema=all_schemas[file]
            cols1={col1:col1 for col1,d_type1 in schema.items() if col1 in input_schema and d_type1==input_schema[col1]}
            schema={k:v for k,v in schema.items() if k not in list(cols1.values())}
            cols2={col1:col for col1,d_type1 in schema.items() for col in input_sch_onto if col1 in input_sch_onto[col] and d_type1==input_schema[col]}
            schema={k:v for k,v in schema.items() if k not in list(cols1.values())}
            cols={**cols1,**cols2}
            ip_schema={k:v for k,v in input_schema.items() if k not in list(cols.values())}
            for col1,d_type1 in ip_schema.items():
                x=[col2 for col2,d_type2 in schema.items() if ((len(col1)>3 and len(col2)>3) and ((col1 in col2) or (col2 in col1))) and (d_type1==d_type2)]
                if len(x)==1:
                    cols[col1]=x[0]
            if(len(cols)>1):
                possible_tables[file]=cols
    return possible_tables

# %%
input_schema={'date': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
input_sch_onto=generate_ontology(input_schema)
print("Input has schema only. All possible tables with one or more columns matching : ")
for i,j in col_only_list(input_schema,input_sch_onto).items():
    print(i," : ",j)
input_categories=["submarines","germany","shipwrecks","navy","uboat"]
input_cat_onto=generate_ontology(input_categories)
print("\nInput has schema and categories. All possible tables with 75% category match and one or more column match : ")
for i,j in cat_and_col_list(input_categories,input_cat_onto,input_schema,input_sch_onto).items():
    print(i," : ",j)
# Out:
# Input has schema only. All possible tables with one or more columns matching :
# 202_117.csv  :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# 203_102.csv  :  {'date': 'date', 'nation': 'nationality'}
# 203_148.csv  :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 203_268.csv  :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 203_433.csv  :  {'nationality': 'nationality', 'date': 'date'}
# 203_481.csv  :  {'nationality': 'nationality', 'date of birth': 'date'}
# 203_706.csv  :  {'status': 'nationality', 'dates': 'date'}
# 203_760.csv  :  {'status': 'nationality', 'appointment': 'date'}
# 204_100.csv  :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# 204_151.csv  :  {'date': 'date', 'day': 'date'}
# 204_272.csv  :  {'date': 'date', 'nationality': 'nationality'}
# 204_434.csv  :  {'date': 'date', 'status': 'nationality'}
# 204_678.csv  :  {'date': 'date', 'nation': 'nationality'}
# 204_806.csv  :  {'date': 'date', 'condition': 'fate'}
# 204_875.csv  :  {'date': 'date', 'day': 'date'}
# 204_931.csv  :  {'nationality': 'nationality', 'date': 'date'}
#
# Input has schema and categories. All possible tables with 75% category match and one or more column match :
# 202_117.csv  :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage (grt)': 'tonnage'}
# 203_148.csv  :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 203_268.csv  :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 204_100.csv  :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage (grt)': 'tonnage'}

# %%
# function generates all possible combinations of list l taking elements n to 2 at a time and returns a dictionary
def generate_all_combinations(l):
    x={}
    a=len(l)
    for i in range(a,1,-1):
        x[i]=list(combinations(l,i))
    return x

# %%
generate_all_combinations(['202_117.csv', '203_148.csv', '203_268.csv', '204_100.csv'])
# Out:
# {4: [('202_117.csv', '203_148.csv', '203_268.csv', '204_100.csv')],
#  3: [('202_117.csv', '203_148.csv', '203_268.csv'),
#   ('202_117.csv', '203_148.csv', '204_100.csv'),
#   ('202_117.csv', '203_268.csv', '204_100.csv'),
#   ('203_148.csv', '203_268.csv', '204_100.csv')],
#  2: [('202_117.csv', '203_148.csv'),
#   ('202_117.csv', '203_268.csv'),
#   ('202_117.csv', '204_100.csv'),
#   ('203_148.csv', '203_268.csv'),
#   ('203_148.csv', '204_100.csv'),
#   ('203_268.csv', '204_100.csv')]}

# %%
# for input table and column, get a list of all categories that the terms(elements) in that column belong to
def extract_info_from_knowledge_graphs(a,col1):
    with open("C:\\Users\\adith\\Desktop\\my_google_knowledge_graph_api_key.txt","r") as f:
        api_key=f.readline()
    service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
    params = {'limit': 50,'indent': True,'key': api_key}
    s={}
    ctr=0
    for row in a[col1]:
        if type(row)==type(np.nan):
            ctr+=1
            continue
        params['query']=row
        url = service_url + '?' + urllib.parse.urlencode(params)
        try:
            response = json.loads(urllib.request.urlopen(url).read())
        except urllib.error.HTTPError as httperr:
            try:
                response = json.loads(urllib.request.urlopen(url).read())
            except urllib.error.HTTPError as httperr:
                try:
                    response = json.loads(urllib.request.urlopen(url).read())
                except urllib.error.HTTPError as httperr:
                    ctr+=1
        for element in response['itemListElement']:
            for i in element["result"]["@type"]:
                b=i.lower()
                if b in s:
                    s[b]+=1
                else:
                    s[b]=1
            if "description" in element["result"]:
                b=element["result"]["description"].lower()
                if b in s:
                    s[b]+=1
                else:
                    s[b]=1
    return s,ctr

# %%
a=pd.read_csv("203_148.csv")
s,ctr=extract_info_from_knowledge_graphs(a,"name")
print(s)
# Out:
# {'thing': 292, 'organization': 18, 'sportsteam': 13, 'cycling team': 1, 'soccer club': 5, 'book': 3, 'book by antoon sanders': 1, 'basketball club': 1, 'corporation': 8, 'record label': 1, 'soccer team': 1, 'ship': 13, 'place': 24, 'professional sports team': 1, 'person': 118, "dulce of aragon's son": 1, 'event': 13, 'philosopher': 1, 'argentine goalkeeper': 1, 'soccer forward': 1, 'soccer player': 3, 'road cycling team': 3, 'argentine soccer player': 3, 'plants': 1, 'city': 9, 'town in argentina': 1, 'argentinean soccer player': 1, 'sportsorganization': 1, 'league': 1, 'soccer goalkeeper': 1, 'aerospace company': 1, 'country': 2, 'administrativearea': 4, 'country in central africa': 1, 'company': 2, 'bank': 1, 'musiccomposition': 1, 'opera by claudio monteverdi': 1, 'city in chile': 1, 'disaster': 1, 'stadiumorarena': 2, 'arena in hämeenlinna, finland': 1, 'tvseries': 3, 'brazilian telenovela': 2, 'military conflict': 1, 'movie': 4, '1917 film': 1, 'revolutionary': 1, 'song by franco battiato': 1, 'musicgroup': 3, 'musical group': 2, 'italian politician': 1, 'light rail station in guadalajara, mexico': 1, '2012 film': 1, 'mexican politician': 1, '2015 film': 1, 'indonesian politician': 1, 'song by bedřich smetana': 1, 'touristattraction': 3, 'mountain': 1, 'territory': 1, 'multi-purpose stadium in sucre, bolivia': 1, 'song by inocentes': 1, 'civicstructure': 1, 'movie theatre in bucharest, romania': 1, 'musicalbum': 2, 'album by quilapayún': 1, 'french politician': 1, 'town in paraguay': 1, 'musical': 1, 'museum in santo domingo, dominican republic': 1, 'novelist': 1, 'city in italy': 1, 'song by nomadi': 1, 'article': 1, 'poem by juan zorrilla de san martín': 1, 'song by alvaro torres': 1, 'american musician': 1, 'american singer': 3, 'city in california': 2, 'american songwriter': 1, 'u.s. representative': 2, 'american actress': 16, 'american pornographic actress': 1, 'singer-songwriter': 2, 'administrator of the small business administration': 1, 'educationalorganization': 1, 'collegeoruniversity': 1, 'university in loma linda, california': 1, '2005 film': 1, 'american teacher': 1, 'american television personality': 1, 'american singer-songwriter': 1, 'canadian model': 1, 'american author': 3, 'actress': 8, 'american film actress': 2, 'fictional superhero': 1, 'cyclist': 1, 'polish actor': 1, 'american activist': 1, 'finnish violinist': 1, 'vocal duo': 1, 'american-argentine actress': 1, 'american television actress': 1, 'singer': 2, 'norwegian politician': 1, 'canadian actress': 1, 'swedish singer-songwriter': 1, 'member of the bundestag': 1, 'swedish soccer player': 1, 'telenovela': 1, 'mexican film actress': 1, 'highway in mexico': 2, 'author': 1, 'british novelist': 1, 'correspondent': 1, 'american sports announcer': 1, 'swedish singer': 1, 'american biographer': 1, 'studio album by earl sweatshirt': 1, 'american navy man': 1, 'film director': 1, 'member of the swiss federal council': 1, 'tennis player': 1, 'american dancer': 1, 'german singer': 2, 'australian actress': 1, 'fictional character': 1, 'colombian visual artist': 1, 'member of the national council of austria': 1, 'spiritualist': 1, 'american film director': 1, "sharon tate's mother": 1, 'italian businessman': 1, 'nun': 1, 'american character actress': 1, 'canadian author': 1, 'french actor': 1, 'american script supervisor': 1, 'venezuelan actress': 1, 'american painter': 1, 'german journalist': 1, 'american political activist': 1, 'croatian goalkeeper': 1, 'bird': 19, 'commune': 1, 'submarine': 1, 'kosovar ballet dancer': 1, 'musicrecording': 9, 'song by jean c. roché': 10, 'song by taxim': 2, 'albanian fighter': 1, 'estonian poet': 1, 'estonian coach': 1, 'estonian geologist': 1, 'chemist': 1, 'poet': 1, 'song by vladimir vysotsky': 2, 'song': 4, 'videogame': 1, 'video game': 1, 'kara-class cruiser': 1, 'kara class': 2, 'moskva-class helicopter carrier': 2, 'aircraft carrier': 1, 'boat': 1, 'governmentorganization': 2, 'gendarmerie': 1, 'sports event': 1,  ...

# %%
# using data from google knowledge graphs, try to obtain alternate names for columns that do not match to merge them if they
# represent the same entity
# returned values are in the form (final_name,old_name)
def get_alternate_col_name(a,b,col1,col2):
    global kg_data
    if col1 not in kg_data:
        groups,count=extract_info_from_knowledge_graphs(a,col1)
        kg_data[col1]={"groups":groups,"count":count}
    if col2 not in kg_data:
        groups,count=extract_info_from_knowledge_graphs(b,col2)
        kg_data[col2]={"groups":groups,"count":count}
    s1=kg_data[col1]["groups"]
    ctr1=kg_data[col1]["count"]
    s2=kg_data[col2]["groups"]
    ctr2=kg_data[col2]["count"]
    if (col1 in s1) and (col1 in s2):
        if (s1[col1]>=len(a)-1-ctr1) and (s2[col1]>=len(b)-1-ctr2):
            kg_data[col1]["groups"][col1]+=kg_data[col2]["groups"][col1]
            kg_data[col1]["count"]+=kg_data[col2]["count"]
            del kg_data[col2]
            return (col1,col2)
    elif (col2 in s1) and (col2 in s2):
        if (s1[col2]>=len(a)-1-ctr1) and (s2[col2]>=len(b)-1-ctr2):
            kg_data[col2]["groups"][col2]+=kg_data[col1]["groups"][col2]
            kg_data[col2]["count"]+=kg_data[col1]["count"]
            del kg_data[col1]
            return (col2,col1)
    else:
        return 0,0

# %%
a=pd.read_csv("203_148.csv")
b=pd.read_csv("202_117.csv")
x=get_alternate_col_name(a,b,"name","ship")
print(x)
# Out:
# ('ship', 'name')

# %%
# using google knowledge graph update the column names and update tables (if possible) to improve merge accuracy and improve completeness
def graph_match(c,t1,t2):
    l=list(combinations(c,2))
    possible_column_renames={}
    flag=0
    for i in l:
        if ((i[0] in t1) and (i[1] in t2)):
            a,b=get_alternate_col_name(t1,t2,i[0],i[1])
        elif ((i[1] in t1) and (i[0] in t2)):
            a,b=get_alternate_col_name(t1,t2,i[1],i[0])
        else:
            a,b=0,0
        if a!=0 and b!=0:
            if b in input_schema:
                if b in t1:
                    t2.rename(columns={a:b},inplace=True)
                else:
                    t1.rename(columns={a:b},inplace=True)
            else:
                if a in t1:
                    t2.rename(columns={b:a},inplace=True)
                else:
                    t1.rename(columns={b:a},inplace=True)
            c.remove(a)
            c.remove(b)
            return t1,t2,c
    return t1,t2,0

# %%
def gen_kg_data(c,a,res):
    global kg_data
    for col in c:
        if col in a:
            b=a
        else:
            b=res
        if col not in kg_data:
            groups,ctr=extract_info_from_knowledge_graphs(b,col)
            kg_data[col]={"groups":groups,"count":ctr}

# %%
# function generates all matching columns between the res_cols schema and columns of table in fname
def generate_matching_columns(res_cols,fname):
    a=all_schemas[fname]
    c={**res_cols,**a}
    res_onto=generate_ontology(res_cols)
    cols1={col1:col1 for col1,d_type1 in a.items() if (col1 in res_cols) and d_type1==res_cols[col1]}
    res_onto={k:v for k,v in res_onto.items() if k not in cols1}
    a={k:v for k,v in a.items() if k not in cols1}
    cols2={col1:cols for col1,d_type1 in a.items() for col in res_onto if col1 in res_onto[col] and d_type1==res_cols[col]}
    a={k:v for k,v in a.items() if k not in cols2}
    cols={**cols1,**cols2}
    res_cols={k:v for k,v in res_cols.items() if k not in list(cols.values())}
    for col1,d_type1 in a.items():
        x=[col2 for col2,d_type2 in res_cols.items() if ((len(col1)>3 and len(col2)>3) and ((col1 in col2) or (col2 in col1))) and (d_type1==d_type2)]
        if len(x)==1:
            cols[col1]=x[0]
    matching_columns=cols
    c={k:v for k,v in c.items() if k not in matching_columns and v=='object'}
    return (matching_columns,list(c))

# %%
# returns a merged table of all tables given in input list l    
def merge_list(l):
    t1=pd.read_csv(l[0])
    a=all_schemas[l[0]]
    matching_columns,c=generate_matching_columns(a,l[1])
    t2=pd.read_csv(l[1])
    gen_kg_data(c,t1,t2)
    if len(c)>=2:
        t1,t2,c=graph_match(c,t1,t2)
        while c!=0:
            t1,t2,c=graph_match(c,t1,t2)
    t2.rename(columns = matching_columns,inplace=True)
    try:
        res=t1.merge(t2,how='outer')
    except:
        return -1
    for fname in l[2:]:
        res_cols={i:j for i,j in zip(res.columns,[str(i) for i in res.dtypes])}
        matching_columns,c=generate_matching_columns(res_cols,fname)
        t=pd.read_csv(fname)
        gen_kg_data(c,res,t)
        if len(c)>=2:
            res,t,c=graph_match(c,res,t)
            while c!=0:
                res,t,c=graph_match(c,res,t)
        t.rename(columns = matching_columns,inplace=True)
        try:
            res=res.merge(t,how='outer')
        except:
            return -1
    res_cols={i:j for i,j in zip(res.columns,[str(i) for i in res.dtypes])}
    a=input_schema
    cols1={col1:col1 for col1,d_type1 in res_cols.items() if (col1 in a) and d_type1==input_schema[col1]}
    a={k:v for k,v in a.items() if k not in cols1}
    a_onto=generate_ontology(a)
    cols2={col1:col for col1,d_type1 in res_cols.items() for col in a_onto if col1 in a_onto[col] and (d_type1==a[col])}
    a={k:v for k,v in a.items() if k not in cols2}
    cols={**cols1,**cols2}
    res_cols={k:v for k,v in res_cols.items() if k not in list(cols.values())}
    for col1,d_type1 in a.items():
        x=[col2 for col2,d_type2 in res_cols.items() if ((len(col1)>3 and len(col2)>3) and ((col1 in col2) or (col2 in col1))) and (d_type1==d_type2)]
        if len(x)==1:
            cols[x[0]]=col1
    res.rename(columns = cols,inplace=True)
    return res

# %%
# metrics calculated :
# 1)nan_score(number of nulls in each column)
# 2)coverage_score(no of matching columns with input schema/total number of columns in input schema)
# 3)completeness_score(a combination of coverage and nan scores to determine how complete the result dataset is)

# nan score = {x : (no on nans in column/no of entries in column)} where x is each column in the table
# gives the nan score(no on nans/no of entries in table) for each column in the input table
def nan_score(table=-1,fname=-1):
    if fname!=-1:
        table=pd.read_csv(fname)
    nan_count={}
    a=len(table)
    for i in table.columns:
        x=a-table[i].count()
        s=str(x)+'/'+str(a)
        nan_count[i]=s
    return nan_count

#returns the coverage score and completeness score of a given table
#coverage score is calculated as : 
# coverage = (no of columns matching with input schema/total number of columns in input schema)
#completeness score is calculated as : 
# completeness = (sum(x*(non null entries)/(total entries in the column))/total number of columns in input schema) 
#  where x=1 if column present in input schema and x=0 if column is not present in the input schema
def coverage_and_completeness(table):
    ctr=0
    comp=0.0
    cols=table.columns
    l=len(table)
    for col in cols:
        if col in input_schema:
            ctr+=1
            comp+=((l-sum(pd.isnull(table[col])))/l)
    comp=comp/len(input_schema)
    cov=ctr/len(input_schema)
    return (cov,comp)

# %%
def ranking_display(comp_score,no_of_rows):
    print()
    comp_rank=sorted(comp_score,reverse=True)
    count=0
    l=sorted(no_of_rows, key=lambda k: no_of_rows[k],reverse=True)
    for i in comp_rank:
        if len(comp_score[i])==1:
            count+=1
            print("Rank ",str(count).ljust(2," ")," : ",comp_score[i][0].ljust(20,' '),"completeness score : %0.16f"%(i),"\t\tnumber of rows: ",no_of_rows[comp_score[i][0]])
        else:
            for j in l:
                if j in comp_score[i]:
                    count+=1
                    print("Rank ",str(count).ljust(2," ")," : ",j.ljust(20,' '),"completeness score : %0.16f"%(i),"\t\tnumber of rows: ",no_of_rows[j])
    print("\nRanking Complete!!\n")

# %%
# takes output tables schema(columns and data_types) as the input, compare it with input schema and transformations required and
# returns a list of all the transformations applicable
def get_possible_transformations(cols):
    return {col:[i for i in tran if i in transform_funct_list[input_schema[col]]] for col,tran in transformations.items() if col in cols}

# %%
# function returns a boolean result after checking if confition is satisfied
def condition_check(sign,v,value):
    x={">=":v>=value,"<=":v<=value,"<":v<value,">":v>value,"=":v==value,"!=":v!=value}
    return x[sign]

# %%
# function returns all stastical conditions that are satisfied as well as unsatisfied
def check_stats(res):
    cols=res.columns; satisfied={}; unsatisfied={}
    for col in stats:
        if col in cols:
            if input_schema[col]=="int64" or input_schema[col]=="float64":
                for condition in stats[col]:
                    sign=[i for i in signs if i in condition][0]
                    funct,value=condition.split(sign)[0],condition.split(sign)[1]
                    funct=funct.lower()
                    if funct in functs_onto:
                        pass
                    else:
                        for f in functs_onto:
                            if funct in functs_onto[f]:
                                funct=f
                    v=res[col].describe()[funct]
                    if condition_check(sign,v,int(value)):
                        s=condition+"( "+str(v)+sign+value+" )"
                        if col in satisfied:
                            satisfied[col].append(s)
                        else:
                            satisfied[col]=[]
                            satisfied[col].append(s)
                    else:
                        s=condition+"( "+funct+" = "+str(v)+" )"
                        if col in unsatisfied:
                            unsatisfied[col].append(s)
                        else:
                            unsatisfied[col]=[]
                            unsatisfied[col].append(s)
        else:
            unsatisfied[col+"(Column Not Present)"]=stats[col]
    return (satisfied,unsatisfied)

# %%
# this is a function to print the individual tables names, their nan score, columns that match with input schema, 
# coverage score, and completeness score along with possible transformations if any
def display_individual_matches(matching_tables,matching_tables_dict):
    global comp_score
    global no_of_rows
    f=open("output_folder_transformation/results.txt",'a')
    if transformations==-1:
        flag=0
    else:
        flag=1
    for i in matching_tables:
        print(i+"("+all_tablenames[i]+")",file=f)
        print(i+"("+all_tablenames[i]+")")
        res=pd.read_csv(i)
        res.rename(columns=matching_tables_dict[i],inplace=True)
        cov,comp=coverage_and_completeness(res)
        if flag==1:
            cols=res.columns
            l=get_possible_transformations(cols)
            print("possible transformations are : ",l,file=f)
            print("possible transformations are : ",l)
            cov,comp=coverage_and_completeness(res)
        if stats!=-1:
            sat,unsat=check_stats(res)
            if len(sat)>0:
                print("Conditions Satisfied : ",sat,file=f)
                print("Conditions Satisfied : ",sat)
            if len(unsat)>0:
                print("Conditions NOT SATISFIED : ",unsat,file=f)
                print("Conditions NOT SATISFIED : ",unsat)
        print('Missing Values(NANs score): ',nan_score(fname=i),file=f)
        print('Missing Values(NANs score): ',nan_score(fname=i))
        print("Columns that match with input_schema:\n "+i+' : ',matching_tables_dict[i],file=f)
        print("Columns that match with input_schema:\n "+i+' : ',matching_tables_dict[i])
        print("Coverage Score : ",cov,"\t Completeness Score : ",comp,file=f)
        print("Coverage Score : ",cov,"\t Completeness Score : ",comp)
        print(file=f)
        print()
        no_of_rows[i]=len(res)
        if comp in comp_score:
            comp_score[comp].append(i)
        else:
            comp_score[comp]=[]
            comp_score[comp].append(i)

# %%
# this functions calls the col_only_list() or cat_and_col_list() based on input query requirements
# it recieves a list of tbales with one or more columns matching with input schema and if categories involved then 75% category cos similarity with input schema
# then we check for 75% column cosine cimilarity score and return a list of all tables having 75% column cosine similarity score
def check_possible_matches():
    input_sch_onto=generate_ontology(input_schema)
    if input_categories==-1:
        print('only schema')
        possible_tables=col_only_list(input_schema,input_sch_onto)
    else:
        print('category and schema')
        input_cat_onto=generate_ontology(input_categories)
        possible_tables=cat_and_col_list(input_categories,input_cat_onto,input_schema,input_sch_onto)
    matching_tables={}
#     print("Columns cosine similarity values that are greater than 75% :")
#     print("File Name\t\tcolumn cos similarity value")
    for i in possible_tables:
        cos_val=cos_sim(list(possible_tables[i].values()),list(input_schema))
        if cos_val>0.75:
#             print(i,"\t\t",cos_val)
            matching_tables[i]=possible_tables[i]
    print()
    return matching_tables

# %%
# the main function that is to be invoked and will call all the required functions to obtain the required matches and merges
# we have a list with all possible tables that are matches
# we generate all combinations of them in order to merge them
# a valid combination is one where every pair of tables have 50% cosine column and category similarity
# then we merge them and calculate the coverage score, null score and the completeness score
# all these details are displayed for each of the valid merges as well as individual tables
# the output is displayed in the output file "results.txt" along with the outputs in csv form
def get_matches():
    global comp_score
    global no_of_rows
    comp_score={}
    no_of_rows={}
    matching_tables_dict=check_possible_matches()
    matching_tables=list(matching_tables_dict)
    with open("output_folder_transformation/results.txt",'a') as f:
        print('******************************',file=f)
        print(file=f)
        print("All Possible Matches",file=f)
        print(file=f)
        print("Matching Tables : ",matching_tables,file=f)
        print("Matching Tables : ",matching_tables)
        for i in matching_tables:
            print(i,'\t',all_tablenames[i])
        if transformations==-1:
            print("\nNo Transformations In Input Schema",file=f)
            print(file=f)
        else:
            print('\nTransformations detected from input are : ',transformations,file=f)
            print(file=f)
    op_str1='output_folder_transformation/'
    op_str2='.csv'
    x=len(matching_tables)
    print()
    if x==0:
        with open("output_folder_transformation/results.txt",'a') as f:
            print("NO MATCHES FOUND",file=f)
            print(file=f)
    elif x==1:
        display_individual_matches(matching_tables,matching_tables_dict)
        print("Only one match found!! Rank 1 : ",matching_tables[0])
    elif x==2:
        a=matching_tables[0]+' : '+matching_tables[1]
        b=matching_tables[1]+' : '+matching_tables[0]
        if (a in cat_sim) or (b in cat_sim):
            if (cat_sim[a]>.50 and col_sim[a]>0.50) or (cat_sim[b]>.50 and col_sim[b]>0.50):
                res=merge_list([matching_tables[0],matching_tables[1]])
                op_string=op_str1+'1'+op_str2
                res.to_csv(op_string,sep=',', index=False)
                cols=res.columns
                cov,comp=coverage_and_completeness(res)
                with open("output_folder_transformation/results.txt",'a') as f:
                    print(op_string,file=f)
                    if transformations!=-1:
                        l=get_possible_transformations(cols)
                        print("possible transformations are : ",l,file=f)
                    if stats!=-1:
                        sat,unsat=check_stats(res)
                        if len(sat)>0:
                            print("Conditions Satisfied : ",sat,file=f)
                        if len(unsat)>0:
                            print("Conditions Not Satisfied : ",unsat,file=f)
                    print('Missing Values(NANs): ',nan_score(table=res),file=f)
                    print("Columns that match with input_schema: ",file=f)
                    for j in matching_tables:
                        print(j+' : ',matching_tables_dict[j],file=f)
                    print("Coverage Score : ",cov,"\t Completeness Score : ",comp,"\t Number of Rows : ",len(res),file=f)
                    print(file=f)
                    no_of_rows["output_"+str(ctr)+op_str2]=len(res)
                    if comp in comp_score:
                        comp_score[comp].append("output_"+str(ctr)+op_str2)
                    else:
                        comp_score[comp]=[]
                        comp_score[comp].append("output_"+str(ctr)+op_str2)
        display_individual_matches(matching_tables,matching_tables_dict)
    else:
        ctr=0
        count_comb=len(matching_tables)
        all_combos=generate_all_combinations(matching_tables)
        for i in range(count_comb,1,-1):
            for l in all_combos[i]:
                a=list(l)
                comb=list(combinations(a,2))
                flag=0
                for pair in comb:
                    if flag==0:
                        t1,t2=pair
                        if ((t1+' : '+t2) in cat_sim):
                            if (cat_sim[t1+' : '+t2]>=.50 and col_sim[t1+' : '+t2]>=0.50):
                                pass
                            else:
                                flag=1
                        else:
                            flag=1
                    else:
                        break
                if flag==0:
                    res=merge_list(a)
                    if type(res) != type(-1):
                        ctr+=1
                        op_string=op_str1+str(ctr)+op_str2
                        res.to_csv(op_string,sep=',', index=False)
                        cols=res.columns
                        cov,comp=coverage_and_completeness(res)
                        with open("output_folder_transformation/results.txt",'a') as f:
                            print(str(ctr)+op_str2+' : ',end='',file=f)
                            print(str(ctr)+op_str2+' : ',end='')
                            for j in a:
                                print(j+'\t\t',end='',file=f)
                                print(j+'\t\t',end='')
                            print(file=f)
                            print()
                            if transformations!=-1:
                                l=get_possible_transformations(cols)
                                print("possible transformations are : ",l,file=f)
                                print("possible transformations are : ",l)
                            if stats!=-1:
                                sat,unsat=check_stats(res)
                                if len(sat)>0:
                                    print("Conditions Satisfied : ",sat,file=f)
                                    print("Conditions Satisfied : ",sat)
                                if len(unsat)>0:
                                    print("Conditions Not Satisfied : ",unsat,file=f)
                                    print("Conditions Not Satisfied : ",unsat)
                            print('Missing Values(NANs): ',nan_score(table=res),file=f)
                            print('Missing Values(NANs): ',nan_score(table=res))
                            print("Columns that match with input_schema: ",file=f)
                            print("Columns that match with input_schema: ")
                            for j in a:
                                print(j+' : ',matching_tables_dict[j],file=f)
                                print(j+' : ',matching_tables_dict[j])
                            print("Coverage Score : ",cov,"\t Completeness Score : ",comp,file=f)
                            print("Coverage Score : ",cov,"\t Completeness Score : ",comp)
                            print()
                            print(file=f)
                            no_of_rows["output_"+str(ctr)+op_str2]=len(res)
                            if comp in comp_score:
                                comp_score[comp].append("output_"+str(ctr)+op_str2)
                            else:
                                comp_score[comp]=[]
                                comp_score[comp].append("output_"+str(ctr)+op_str2)
        display_individual_matches(matching_tables,matching_tables_dict)
    with open("output_folder_transformation/results.txt",'a') as f:
        print('******************************',file=f)
    ranking_display(comp_score,no_of_rows)

# %%
# only schema and individual tables
s='{"schema": {"round": "int64", "Round 1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"}}'
s=s.lower()
s=json.loads(s)
input_schema=s["schema"];input_categories=-1;transformations=-1;stats=-1
if "categories" in s:
    input_categories=s["categories"]
if "transformations" in s:
    transformations=s["transformations"]
if "stats" in s:
    stats=s["stats"]
# display query
print("Input Schema : ",input_schema)
if input_categories==-1:
    print("Input Categories : None")
else:
    print("Input Categories : ",input_categories)
if transformations==-1:
    print("Input Transformations : None")
else:
    print("Input Transformations : ",transformations)
if stats==-1:
    print("Input Condition based conditions : None")
else:
    print("Input Content based Conditions : ",stats)
print()
comp_score={}
no_of_rows={}
no_of_rows={}
matching_tables_dict=check_possible_matches()
matching_tables=list(matching_tables_dict)
print(matching_tables)
for i in matching_tables:
    print(i," : ",all_tablenames[i])
print("\n")
display_individual_matches(matching_tables,matching_tables_dict)
ranking_display(comp_score,no_of_rows)
# Out:
# Input Schema :  {'round': 'int64', 'round 1': 'object', 'circuit': 'object', 'date': 'object', 'pole position': 'object', 'fastest lap': 'object', 'winning driver': 'object'}
# Input Categories : None
# Input Transformations : None
# Input Condition based conditions : None
#
# only schema
#
# ['203_181.csv', '203_408.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv', '204_845.csv']
# 203_181.csv  :  1990 IndyCar season
# 203_408.csv  :  1989 Formula One season
# 203_514.csv  :  2008 Superleague Formula season
# 203_742.csv  :  1995 IndyCar season
# 204_253.csv  :  1990 Superbike World Championship season
# 204_40.csv  :  2008 Superbike World Championship season
# 204_455.csv  :  1989 Formula One season
# 204_569.csv  :  1998 Swedish Touring Car Championship season
# 204_63.csv  :  2002 Italian Formula Three season
# 204_845.csv  :  2003 Barber Dodge Pro Series season
#
#
# 203_181.csv(1990 IndyCar season)
# Missing Values(NANs score):  {'date': '0/17', 'rnd': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_181.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 203_408.csv(1989 Formula One season)
# Missing Values(NANs score):  {'rd ': '0/16', 'grand prix': '0/16', 'date': '0/16', 'location': '0/16', 'pole position': '0/16', 'fastest lap': '0/16', 'winning driver': '0/16', 'constructor': '0/16', 'report': '0/16'}
# Columns that match with input_schema:
#  203_408.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 203_514.csv(2008 Superleague Formula season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'race': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning club': '0/12', 'winning team': '0/12', 'report': '0/12'}
# Columns that match with input_schema:
#  203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.6428571428571429
#
# 203_742.csv(1995 IndyCar season)
# Missing Values(NANs score):  {'rnd': '0/17', 'date': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'fastest lap': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_742.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
# 204_253.csv(1990 Superbike World Championship season)
# Missing Values(NANs score):  {'round': '0/26', 'round 1': '0/26', 'circuit': '0/26', 'date': '0/26', 'pole position': '0/26', 'fastest lap': '0/26', 'winning rider': '0/26'}
# Columns that match with input_schema:
#  204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 204_40.csv(2008 Superbike World Championship season)
# Missing Values(NANs score):  {'round': '0/28', 'round 1': '0/28', 'country': '0/28', 'circuit': '0/28', 'date': '0/28', 'pole position': '0/28', 'fastest lap': '0/28', 'winning rider': '0/28', 'winning team': '0/28', 'report': '0/28'}
# Columns that match with input_schema:
#  204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 204_455.csv(1989 Formula One season)
# Missing Values(NANs score):  {'rd ': '0/16', 'grand prix': '0/16', 'date': '0/16', 'location': '0/16', 'pole position': '0/16', 'fastest lap': '0/16', 'winning driver': '0/16', 'constructor': '0/16', 'report': '0/16'}
# Columns that match with input_schema:
#  204_455.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 204_569.csv(1998 Swedish Touring Car Championship season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'circuit': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning driver': '0/12', 'winning team': '0/12', 'winning privateer': '0/12'}
# Columns that match with input_schema:
#  204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.9285714285714286
#
# 204_63.csv(2002 Italian Formula Three season)
# Missing Values(NANs score):  {'round': '0/9', 'circuit': '0/9', 'date': '0/9', 'pole position': '0/9', 'winning driver': '0/9', 'winning team': '0/9', 'trophy winner': '0/9'}
# Columns that match with input_schema:
#  204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
# 204_845.csv(2003 Barber Dodge Pro Series season)
# Missing Values(NANs score):  {'round': '0/10', 'circuit': '0/10', 'location': '0/10', 'date': '0/10', 'pole position': '0/10', 'fastest lap': '0/10', 'winning driver': '0/10', 'headline event': '0/10'}
# Columns that match with input_schema:
#  204_845.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
#
# Rank  1   :  204_569.csv          completeness score : 0.9285714285714286 		number of rows:  12
# Rank  2   :  204_40.csv           completeness score : 0.8571428571428571 		number of rows:  28
# Rank  3   :  204_253.csv          completeness score : 0.8571428571428571 		number of rows:  26
# Rank  4   :  204_845.csv          completeness score : 0.8571428571428571 		number of rows:  10
# Rank  5   :  203_742.csv          completeness score : 0.7142857142857143 		number of rows:  17
# Rank  6   :  204_63.csv           completeness score : 0.7142857142857143 		number of rows:  9
# Rank  7   :  203_514.csv          completeness score : 0.6428571428571429 		number of rows:  12
# Rank  8   :  203_181.csv          completeness score : 0.5714285714285714 		number of rows:  17
# Rank  9   :  203_408.csv          completeness score : 0.5714285714285714 		number of rows:  16
# Rank  10  :  204_455.csv          completeness score : 0.5714285714285714 		number of rows:  16
#
# Ranking Complete!!

# %%
l=['203_181.csv', '203_408.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv', '204_845.csv']
for i in l:
    x=pd.read_csv(i)
    print(i," : ",all_tablenames[i])
    display(x)
# Out:
# 203_181.csv  :  1990 IndyCar season
#    date           rnd                               race name  \
# 0     1       April 8                           Autoworks 200
# 1     2      April 22            Toyota Long Beach Grand Prix
# 2     3        May 27                   74th Indianapolis 500
# 3     4        June 3                Miller Genuine Draft 200
# 4     5       June 17         Valvoline Grand Prix of Detroit
# 5     6       June 24                 Budweiser/G.I.Joe's 200
# 6     7        July 8       Budweiser Grand Prix of Cleveland
# 7     8       July 15  Marlboro Grand Prix at the Meadowlands
# 8     9       July 22                     Molson Indy Toronto
# 9    10      August 5                            Marlboro 500
# 10   11     August 26    Texaco/Havoline Grand Prix of Denver
# 11   12   September 2                   Molson Indy Vancouver
# 12   13  September 16                       Red Roof Inns 200
# 13   14  September 23                     Texaco/Havoline 200
# 14   NC     October 6                      Marlboro Challenge
# 15   15     October 7             Bosch Spark Plug Grand Prix
# 16   16    October 21                Champion Spark Plug 300K
#
#                               circuit                city/location  \
# 0       Phoenix International Raceway             Phoenix, Arizona
# 1               Streets of Long Beach       Long Beach, California
# 2         Indianapolis Motor Speedway            Speedway, Indiana
# 3                      Milwaukee Mile        West Allis, Wisconsin
# 4                  Streets of Detroit            Detroit, Michigan
# 5      Portland International Raceway             Portland, Oregon
# 6   Cleveland Burke Lakefront Airport              Cleveland, Ohio
# 7          Meadowlands Sports Complex  East Rutherford, New Jersey
# 8                    Exhibition Place             Toronto, Ontario
# 9     Michigan International Speedway           Brooklyn, Michigan
# 10                  Streets of Denver             Denver, Colorado
# 11               Streets of Vancouver  Vancouver, British Columbia
# 12         Mid-Ohio Sports Car Course              Lexington, Ohio
# 13                       Road America      Elkhart Lake, Wisconsin
# 14                  Nazareth Speedway       Nazareth, Pennsylvania
# 15                  Nazareth Speedway       Nazareth, Pennsylvania
# 16                Laguna Seca Raceway         Monterey, California
#
#          pole position      winning driver          winning team  report
# 0           Rick Mears          Rick Mears           Team Penske  Report
# 1        Al Unser, Jr.       Al Unser, Jr.   Galles-Kraco Racing  Report
# 2   Emerson Fittipaldi       Arie Luyendyk  Doug Shierson Racing  Report
# 3           Rick Mears       Al Unser, Jr.   Galles-Kraco Racing  Report
# 4     Michael Andretti    Michael Andretti    Newman/Haas Racing  Report
# 5       Danny Sullivan    Michael Andretti    Newman/Haas Racing  Report
# 6           Rick Mears      Danny Sullivan           Team Penske  Report
# 7     Michael Andretti    Michael Andretti    Newman/Haas Racing  Report
# 8       Danny Sullivan       Al Unser, Jr.   Galles-Kraco Racing  Report
# 0  February 23         Leonardo Maia      Dan Di Leo   Leonardo Maia
# 1     March 23         Leonardo Maia  David Martinez  David Martinez
# 2       June 1  Victor Gonzalez, Jr.   Scott Poirier   Leonardo Maia
# 3      June 15            Memo Rojas   Leonardo Maia      Dan Di Leo
# 4      June 22         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 5       July 5         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 6      July 13         Leonardo Maia   Leonardo Maia      Memo Rojas
# 7      July 27         Leonardo Maia  David Martinez   Leonardo Maia
# 8     August 3         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 9    August 24            Memo Rojas   Leonardo Maia      Memo Rojas
#
#                      headline event
# 0      Grand Prix of St. Petersburg
# 1              Monterrey Grand Prix
# 2     Milwaukee Mile Centennial 250
# 3            Grand Prix of Monterey
# 4                    G.I. Joe's 200
# 5    U.S. Bank Cleveland Grand Prix
# 6               Molson Indy Toronto
# 7             Molson Indy Vancouver
# 8  Champ Car Grand Prix of Mid-Ohio
# 9              Molson Indy Montreal

# %%
# only schema with merge
s='{"schema": {"round": "int64", "Round 1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"}}'
s=s.lower()
s=json.loads(s)
input_schema=s["schema"];input_categories=-1;transformations=-1;stats=-1
if "categories" in s:
    input_categories=s["categories"]
if "transformations" in s:
    transformations=s["transformations"]
if "stats" in s:
    stats=s["stats"]
# display query
print("Input Schema : ",input_schema)
if input_categories==-1:
    print("Input Categories : None")
else:
    print("Input Categories : ",input_categories)
if transformations==-1:
    print("Input Transformations : None")
else:
    print("Input Transformations : ",transformations)
if stats==-1:
    print("Input Condition based conditions : None")
else:
    print("Input Content based Conditions : ",stats)
print()
get_matches()
# Out:
# Input Schema :  {'round': 'int64', 'round 1': 'object', 'circuit': 'object', 'date': 'object', 'pole position': 'object', 'fastest lap': 'object', 'winning driver': 'object'}
# Input Categories : None
# Input Transformations : None
# Input Condition based conditions : None
#
# only schema
#
# Matching Tables :  ['203_181.csv', '203_408.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv', '204_845.csv']
# 203_181.csv 	 1990 IndyCar season
# 203_408.csv 	 1989 Formula One season
# 203_514.csv 	 2008 Superleague Formula season
# 203_742.csv 	 1995 IndyCar season
# 204_253.csv 	 1990 Superbike World Championship season
# 204_40.csv 	 2008 Superbike World Championship season
# 204_455.csv 	 1989 Formula One season
# 204_569.csv 	 1998 Swedish Touring Car Championship season
# 204_63.csv 	 2002 Italian Formula Three season
# 204_845.csv 	 2003 Barber Dodge Pro Series season
#
# 1.csv : 203_514.csv		204_40.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/52', 'round 1': '0/52', 'race': '40/52', 'date': '0/52', 'pole position': '12/52', 'fastest lap': '0/52', 'winning club': '40/52', 'winning team': '0/52', 'report': '12/52', 'country': '24/52', 'circuit': '12/52', 'winning rider': '24/52', 'winning driver': '40/52', 'winning privateer': '40/52'}
# Columns that match with input_schema:
# 203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8241758241758241
#
# 2.csv : 204_253.csv		204_40.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/66', 'round 1': '0/66', 'circuit': '0/66', 'date': '0/66', 'pole position': '6/66', 'fastest lap': '0/66', 'winning rider': '12/66', 'country': '38/66', 'winning team': '26/66', 'report': '38/66', 'winning driver': '54/66', 'winning privateer': '54/66'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8701298701298701
#
# 3.csv : 204_253.csv		204_569.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/47', 'round 1': '9/47', 'circuit': '0/47', 'date': '0/47', 'pole position': '6/47', 'fastest lap': '9/47', 'winning rider': '21/47', 'winning driver': '26/47', 'winning team': '26/47', 'winning privateer': '35/47', 'trophy winner': '38/47'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8480243161094225
#
# 4.csv : 203_181.csv		204_63.csv
# Missing Values(NANs):  {'date': '0/26', 'rnd': '9/26', 'race name': '9/26', 'circuit': '0/26', 'city/location': '9/26', 'pole position': '0/26', 'winning driver': '0/26', 'winning team': '0/26', 'report': '9/26', 'round': '17/26', 'trophy winner': '17/26'}
# Columns that match with input_schema:
# 203_181.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.6208791208791208
#
# 5.csv : 203_408.csv		204_455.csv
# Missing Values(NANs):  {'rd ': '0/16', 'grand prix': '0/16', 'date': '0/16', 'location': '0/16', 'pole position': '0/16', 'fastest lap': '0/16', 'winning driver': '0/16', 'constructor': '0/16', 'report': '0/16'}
# Columns that match with input_schema:
# 203_408.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_455.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 6.csv : 203_514.csv		204_40.csv
# Missing Values(NANs):  {'round': '0/40', 'round 1': '0/40', 'race': '28/40', 'date': '0/40', 'pole position': '6/40', 'fastest lap': '0/40', 'winning club': '28/40', 'winning team': '0/40', 'report': '0/40', 'country': '12/40', 'circuit': '12/40', 'winning rider': '12/40'}
# Columns that match with input_schema:
# 203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.7928571428571428
#
# 7.csv : 203_514.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/24', 'round 1': '0/24', 'race': '12/24', 'date': '0/24', 'pole position': '12/24', 'fastest lap': '0/24', 'winning club': '12/24', 'winning team': '0/24', 'report': '12/24', 'circuit': '12/24', 'winning driver': '12/24', 'winning privateer': '12/24'}
# Columns that match with input_schema:
# 203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.7857142857142857
#
# 8.csv : 203_742.csv		204_845.csv
# Missing Values(NANs):  {'rnd': '10/27', 'date': '0/27', 'race name': '10/27', 'circuit': '0/27', 'city/location': '0/27', 'pole position': '0/27', 'fastest lap': '0/27', 'winning driver': '0/27', 'winning team': '10/27', 'report': '10/27', 'round': '17/27', 'headline event': '17/27'}
# Columns that match with input_schema:
# 203_742.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_845.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.7671957671957672
#
# 9.csv : 204_253.csv		204_40.csv
# Missing Values(NANs):  {'round': '0/54', 'round 1': '0/54', 'circuit': '0/54', 'date': '0/54', 'pole position': '0/54', 'fastest lap': '0/54', 'winning rider': '0/54', 'country': '26/54', 'winning team': '26/54', 'report': '26/54'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 10.csv : 204_253.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/38', 'round 1': '0/38', 'circuit': '0/38', 'date': '0/38', 'pole position': '6/38', 'fastest lap': '0/38', 'winning rider': '12/38', 'winning driver': '26/38', 'winning team': '26/38', 'winning privateer': '26/38'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8796992481203008
#
# 11.csv : 204_253.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/35', 'round 1': '9/35', 'circuit': '0/35', 'date': '0/35', 'pole position': '0/35', 'fastest lap': '9/35', 'winning rider': '9/35', 'winning driver': '26/35', 'winning team': '26/35', 'trophy winner': '26/35'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8204081632653061
#
# 12.csv : 204_40.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/40', 'round 1': '0/40', 'country': '12/40', 'circuit': '0/40', 'date': '0/40', 'pole position': '6/40', 'fastest lap': '0/40', 'winning rider': '12/40', 'winning team': '0/40', 'report': '12/40', 'winning driver': '28/40', 'winning privateer': '28/40'}
# Columns that match with input_schema:
# 204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8785714285714284
#
# 13.csv : 204_569.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/21', 'round 1': '9/21', 'circuit': '0/21', 'date': '0/21', 'pole position': '6/21', 'fastest lap': '9/21', 'winning driver': '0/21', 'winning team': '0/21', 'winning privateer': '9/21', 'trophy winner': '12/21'}
# Columns that match with input_schema:
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.836734693877551
#
# 203_181.csv(1990 IndyCar season)
# Missing Values(NANs score):  {'date': '0/17', 'rnd': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_181.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 203_408.csv(1989 Formula One season)
# Missing Values(NANs score):  {'rd ': '0/16', 'grand prix': '0/16', 'date': '0/16', 'location': '0/16', 'pole position': '0/16', 'fastest lap': '0/16', 'winning driver': '0/16', 'constructor': '0/16', 'report': '0/16'}
# Columns that match with input_schema:
#  203_408.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 203_514.csv(2008 Superleague Formula season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'race': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning club': '0/12', 'winning team': '0/12', 'report': '0/12'}
# Columns that match with input_schema:
#  203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.6428571428571429
#
# 203_742.csv(1995 IndyCar season)
# Missing Values(NANs score):  {'rnd': '0/17', 'date': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'fastest lap': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_742.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
# 204_253.csv(1990 Superbike World Championship season)
# Missing Values(NANs score):  {'round': '0/26', 'round 1': '0/26', 'circuit': '0/26', 'date': '0/26', 'pole position': '0/26', 'fastest lap': '0/26', 'winning rider': '0/26'}
# Columns that match with input_schema:
#  204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 204_40.csv(2008 Superbike World Championship season)
# Missing Values(NANs score):  {'round': '0/28', 'round 1': '0/28', 'country': '0/28', 'circuit': '0/28', 'date': '0/28', 'pole position': '0/28', 'fastest lap': '0/28', 'winning rider': '0/28', 'winning team': '0/28', 'report': '0/28'}
# Columns that match with input_schema:
#  204_40.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 204_455.csv(1989 Formula One season)
# Missing Values(NANs score):  {'rd ': '0/16', 'grand prix': '0/16', 'date': '0/16', 'location': '0/16', 'pole position': '0/16', 'fastest lap': '0/16', 'winning driver': '0/16', 'constructor': '0/16', 'report': '0/16'}
# Columns that match with input_schema:
#  204_455.csv :  {'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 204_569.csv(1998 Swedish Touring Car Championship season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'circuit': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning driver': '0/12', 'winning team': '0/12', 'winning privateer': '0/12'}
# Columns that match with input_schema:
#  204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.9285714285714286
#
# 204_63.csv(2002 Italian Formula Three season)
# Missing Values(NANs score):  {'round': '0/9', 'circuit': '0/9', 'date': '0/9', 'pole position': '0/9', 'winning driver': '0/9', 'winning team': '0/9', 'trophy winner': '0/9'}
# Columns that match with input_schema:
#  204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
# 204_845.csv(2003 Barber Dodge Pro Series season)
# Missing Values(NANs score):  {'round': '0/10', 'circuit': '0/10', 'location': '0/10', 'date': '0/10', 'pole position': '0/10', 'fastest lap': '0/10', 'winning driver': '0/10', 'headline event': '0/10'}
# Columns that match with input_schema:
#  204_845.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
#
# Rank  1   :  204_569.csv          completeness score : 0.9285714285714286 		number of rows:  12
# Rank  2   :  output_10.csv        completeness score : 0.8796992481203008 		number of rows:  38
# Rank  3   :  output_12.csv        completeness score : 0.8785714285714284 		number of rows:  40
# Rank  4   :  output_2.csv         completeness score : 0.8701298701298701 		number of rows:  66
# Rank  5   :  output_9.csv         completeness score : 0.8571428571428571 		number of rows:  54
# Rank  6   :  204_40.csv           completeness score : 0.8571428571428571 		number of rows:  28
# Rank  7   :  204_253.csv          completeness score : 0.8571428571428571 		number of rows:  26
# Rank  8   :  204_845.csv          completeness score : 0.8571428571428571 		number of rows:  10
# Rank  9   :  output_3.csv         completeness score : 0.8480243161094225 		number of rows:  47
# Rank  10  :  output_13.csv        completeness score : 0.8367346938775510 		number of rows:  21
# Rank  11  :  output_1.csv         completeness score : 0.8241758241758241 		number of rows:  52
# Rank  12  :  output_11.csv        completeness score : 0.8204081632653061 		number of rows:  35
# Rank  13  :  output_6.csv         completeness score : 0.7928571428571428 		number of rows:  40
# Rank  14  :  output_7.csv         completeness score : 0.7857142857142857 		number of rows:  24
# Rank  15  :  output_8.csv         completeness score : 0.7671957671957672 		number of rows:  27
# Rank  16  :  203_742.csv          completeness score : 0.7142857142857143 		number of rows:  17
# Rank  17  :  204_63.csv           completeness score : 0.7142857142857143 		number of rows:  9
# Rank  18  :  203_514.csv          completeness score : 0.6428571428571429 		number of rows:  12
# Rank  19  :  output_4.csv         completeness score : 0.6208791208791208 		number of rows:  26
# Rank  20  :  203_181.csv          completeness score : 0.5714285714285714 		number of rows:  17
# Rank  21  :  output_5.csv         completeness score : 0.5714285714285714 		number of rows:  16
# Rank  22  :  203_408.csv          completeness score : 0.5714285714285714 		number of rows:  16
# Rank  23  :  204_455.csv          completeness score : 0.5714285714285714 		number of rows:  16
#
# Ranking Complete!!

# %%
l=['output_folder_transformation/1.csv', 'output_folder_transformation/2.csv', 'output_folder_transformation/3.csv', 'output_folder_transformation/4.csv', 'output_folder_transformation/5.csv', 'output_folder_transformation/6.csv', 'output_folder_transformation/7.csv', 'output_folder_transformation/8.csv', 'output_folder_transformation/9.csv', 'output_folder_transformation/10.csv', 'output_folder_transformation/11.csv', 'output_folder_transformation/12.csv', 'output_folder_transformation/13.csv', '203_181.csv', '203_408.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv', '204_845.csv']
for i in l:
    x=pd.read_csv(i)
    print(i)
    display(x)
# Out:
# output_folder_transformation/1.csv
#     round round 1            race          date         pole position  \
# 0       1      R1  Donington Park     August 31         Beijing Guoan
# 1       1      R2  Donington Park     August 31                   NaN
# 2       2      R1     Nurburgring  September 21            A.C. Milan
# 3       2      R2     Nurburgring  September 21                   NaN
# 4       3      R1          Zolder     October 5     Borussia Dortmund
# 5       3      R2          Zolder     October 5                   NaN
# 6       4      R1         Estoril    October 19             A.S. Roma
# 7       4      R2         Estoril    October 19                   NaN
# 8       5      R1      Vallelunga    November 2        Liverpool F.C.
# 9       5      R2      Vallelunga    November 2                   NaN
# 10      6      R1           Jerez   November 23        Liverpool F.C.
# 11      6      R2           Jerez   November 23                   NaN
# 12      1      R1             NaN   23 February           Troy Corser
# 13      1      R2             NaN   23 February           Troy Corser
# 14      2      R1             NaN       2 March          Troy Bayliss
# 15      2      R2             NaN       2 March          Troy Bayliss
# 16      3      R1             NaN       6 April       Max Neukirchner
# 17      3      R2             NaN       6 April       Max Neukirchner
# 18      4      R1             NaN      27 April          Troy Bayliss
# 19      4      R2             NaN      27 April          Troy Bayliss
# 20      5      R1             NaN        11 May          Troy Bayliss
# 21      5      R2             NaN        11 May          Troy Bayliss
# 22      6      R1             NaN        1 June          Carlos Checa
# 23      6      R2             NaN        1 June          Carlos Checa
# 24      7      R1             NaN       15 June       Max Neukirchner
# 25      7      R2             NaN       15 June       Max Neukirchner
# 26      8      R1             NaN       29 June           Troy Corser
# 27      8      R2             NaN       29 June           Troy Corser
# 28      9      R1             NaN       20 July          Troy Bayliss
# 29      9      R2             NaN       20 July          Troy Bayliss
# 30     10      R1             NaN      3 August          Troy Bayliss
# 31     10      R2             NaN      3 August          Troy Bayliss
# 32     11      R1             NaN   7 September          Troy Bayliss
# 33     11      R2             NaN   7 September          Troy Bayliss
# 34     12      R1             NaN  21 September          Troy Bayliss
# 35     12      R2             NaN  21 September          Troy Bayliss
# 36     13      R1             NaN     5 October         Noriyuki Haga
# 37     13      R2             NaN     5 October         Noriyuki Haga
# 38     14      R1             NaN    2 November          Troy Bayliss
# 39     14      R2             NaN    2 November          Troy Bayliss
# 40      1      R1             NaN        10 May       Mattias Ekström
# 41      1      R2             NaN        10 May                   NaN
# 42      2      R3             NaN        31 May           Jan Nilsson
# 43      2      R4             NaN        31 May                   NaN
# 44      3      R5             NaN       28 June       Mattias Ekström
# 45      3      R6             NaN       28 June                   NaN
# 46      4      R7             NaN        9 July            Jens Edman
# 47      4      R8             NaN        9 July                   NaN
# 48      5      R9             NaN   6 September        Fredrik Ekblom
# 49      5     R10             NaN   6 September                   NaN
# 50      6     R11             NaN  27 September  Tommy Kristoffersson
# 51      6     R12             NaN  27 September                   NaN
#
#           fastest lap       winning club               winning team  report  \
# 0       Beijing Guoan      Beijing Guoan                   Zakspeed  Report
# 1       PSV Eindhoven         Sevilla FC      GTA Motor Competicion  Report
# 2       PSV Eindhoven         A.C. Milan          Scuderia Playteam  Report
# 3      SC Corinthians      PSV Eindhoven          Azerti Motorsport  Report
# 4      Liverpool F.C.     Liverpool F.C.         Hitech Junior Team  Report
# 5     Atletico Madrid      Beijing Guoan                   Zakspeed  Report
# 6     Atletico Madrid     Liverpool F.C.         Hitech Junior Team  Report
# 7   Borussia Dortmund             Al Ain          Azerti Motorsport  Report
# 8       Beijing Guoan      Beijing Guoan                   Zakspeed  Report
# 9     Atletico Madrid         F.C. Porto         Hitech Junior Team  Report
# 10  R.S.C. Anderlecht         A.C. Milan          Scuderia Playteam  Report
# 11      Beijing Guoan  Borussia Dortmund                   Zakspeed  Report
# 12      Noriyuki Haga                NaN               Xerox Ducati  Report
# 13        Fonsi Nieto                NaN             Alstare Suzuki  Report
# 14       Troy Bayliss                NaN               Xerox Ducati  Report
# 15         Max Biaggi                NaN               Xerox Ducati  Report
# 16      Noriyuki Haga                NaN                   Team R.G  Report
# 17       Carlos Checa                NaN        Yamaha Motor Italia  Report
# 18    Max Neukirchner                NaN               Xerox Ducati  Report
# 25         Germany              Nurburgring     Noriyuki Haga
# 26      San Marino         Misano Adriatico   Max Neukirchner
# 27      San Marino         Misano Adriatico        Ruben Xaus
# 28  Czech Republic                     Brno      Troy Bayliss
# 29  Czech Republic                     Brno      Troy Bayliss
# 30   Great Britain             Brands Hatch  Ryuichi Kiyonari
# 31   Great Britain             Brands Hatch  Ryuichi Kiyonari
# 32          Europe           Donington Park      Troy Bayliss
# 33          Europe           Donington Park  Ryuichi Kiyonari
# 34           Italy               Vallelunga     Noriyuki Haga
# 35           Italy               Vallelunga     Noriyuki Haga
# 36          France              Magny-Cours     Noriyuki Haga
# 37          France              Magny-Cours      Troy Bayliss
# 38        Portugal                 Portimão      Troy Bayliss
# 39        Portugal                 Portimão      Troy Bayliss
# 40             NaN             Mantorp Park               NaN
# 41             NaN             Mantorp Park               NaN
# 42             NaN     Karlskoga-Gelleråsen               NaN
# 43             NaN     Karlskoga-Gelleråsen               NaN
# 44             NaN               Anderstorp               NaN
# 45             NaN               Anderstorp               NaN
# 46             NaN               Falkenberg               NaN
# 47             NaN               Falkenberg               NaN
# 48             NaN           Ring Knutstorp               NaN
# 49             NaN           Ring Knutstorp               NaN
# 50             NaN             Mantorp Park               NaN
# 51             NaN             Mantorp Park               NaN
#
#       winning driver  winning privateer
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
# 9                NaN                NaN
# 10               NaN                NaN
# 11               NaN                NaN
# 12               NaN                NaN
# 13               NaN                NaN
# 14               NaN                NaN
# 15               NaN                NaN
# 16               NaN                NaN
# 17               NaN                NaN
# 18               NaN                NaN
# 19               NaN                NaN
# 20               NaN                NaN
# 21               NaN                NaN
# 22               NaN                NaN
# 23               NaN                NaN
# 24               NaN                NaN
# 25               NaN                NaN
# 26               NaN                NaN
# 27               NaN                NaN
# 28               NaN                NaN
# 29               NaN                NaN
# 30               NaN                NaN
# 31               NaN                NaN
# 32               NaN                NaN
# 33               NaN                NaN
# 34               NaN                NaN
# 35               NaN                NaN
# 36               NaN                NaN
# 37               NaN                NaN
# 38               NaN                NaN
# 39               NaN                NaN
# 40       Mats Linden  Richard Göransson
# 41    Fredrik Ekblom       Pontus Mörth
# 42       Jan Nilsson       Pontus Mörth
# 43  Peggen Andersson       Pontus Mörth
# 44       Jan Nilsson       Pontus Mörth
# 45  Peggen Andersson      Georg Bakajev
# 46       Jan Nilsson       Pontus Mörth
# 47        Jens Edman       Pontus Mörth
# 48    Fredrik Ekblom       Pontus Mörth
# 49       Jan Nilsson      Georg Bakajev
# 50    Fredrik Ekblom       Pontus Mörth
# 51       Jan Nilsson       Pontus Mörth
# output_folder_transformation/2.csv
#     round round 1                  circuit          date  \
# 0       1      R1                    Jerez      18 March
# 1       1      R2                    Jerez      18 March
# 2       2      R1                Donington      16 April
# 3       2      R2                Donington      16 April
# 4       3      R1              Hungaroring      30 April
# 5       3      R2              Hungaroring      30 April
# 6       4      R1               Hockenheim         6 May
# 7       4      R2               Hockenheim         6 May
# 8       5      R1                  Mosport        3 June
# 9       5      R2                  Mosport        3 June
# 10      6      R1                 Brainerd       10 June
# 11      6      R2                 Brainerd       10 June
# 12      7      R1           Österreichring        1 July
# 13      7      R2           Österreichring        1 July
# 14      8      R1                     Sugo     26 August
# 15      8      R2                     Sugo     26 August
# 16      9      R1                  Le Mans   9 September
# 17      9      R2                  Le Mans   9 September
# 18     10      R1                    Monza     7 October
# 19     10      R2                    Monza     7 October
# 20     11      R1                Shah Alam    4 November
# 21     11      R2                Shah Alam    4 November
# 22     12      R1           Phillip Island   11 November
# 23     12      R2           Phillip Island   11 November
# 24     13      R1                 Manfeild   18 November
# 25     13      R2                 Manfeild   18 November
# 26      1      R1                   Losail   23 February
# 27      1      R2                   Losail   23 February
# 28      2      R1           Phillip Island       2 March
# 29      2      R2           Phillip Island       2 March
# ..    ...     ...                      ...           ...
# 36      6      R1  Miller Motorsports Park        1 June
# 37      6      R2  Miller Motorsports Park        1 June
# 38      7      R1              Nurburgring       15 June
# 39      7      R2              Nurburgring       15 June
# 40      8      R1         Misano Adriatico       29 June
# 41      8      R2         Misano Adriatico       29 June
# 42      9      R1                     Brno       20 July
# 43      9      R2                     Brno       20 July
# 44     10      R1             Brands Hatch      3 August
# 45     10      R2             Brands Hatch      3 August
# 46     11      R1           Donington Park   7 September
# 47     11      R2           Donington Park   7 September
# 48     12      R1               Vallelunga  21 September
# 49     12      R2               Vallelunga  21 September
# 50     13      R1              Magny-Cours     5 October
# 51     13      R2              Magny-Cours     5 October
# 52     14      R1                 Portimão    2 November
# 53     14      R2                 Portimão    2 November
# 54      1      R1             Mantorp Park        10 May
# 55      1      R2             Mantorp Park        10 May
# 56      2      R3     Karlskoga-Gelleråsen        31 May
# 57      2      R4     Karlskoga-Gelleråsen        31 May
# 58      3      R5               Anderstorp       28 June
# 59      3      R6               Anderstorp       28 June
# 60      4      R7               Falkenberg        9 July
# 61      4      R8               Falkenberg        9 July
# 62      5      R9           Ring Knutstorp   6 September
# 63      5     R10           Ring Knutstorp   6 September
# 64      6     R11             Mantorp Park  27 September
# 65      6     R12             Mantorp Park  27 September
#
#            pole position        fastest lap      winning rider  \
# 0          Raymond Roche   Stephane Mertens      Raymond Roche
# 1          Raymond Roche      Raymond Roche      Raymond Roche
# 2      Giancarlo Falappa        Rob Phillis        Fred Merkel
# 3      Giancarlo Falappa      Raymond Roche  Giancarlo Falappa
# 4       Malcolm Campbell      Raymond Roche        Fred Merkel
# 5       Malcolm Campbell        Fred Merkel      Raymond Roche
# 6          Raymond Roche        Fred Merkel        Fred Merkel
# 7          Raymond Roche      Raymond Roche   Stephane Mertens
# 8      Giancarlo Falappa      Raymond Roche      Raymond Roche
# 9      Giancarlo Falappa        Jamie James      Raymond Roche
# 10         Doug Chandler      Doug Chandler   Stephane Mertens
# 11         Doug Chandler  Fabrizio Pirovano      Doug Chandler
# 12      Stephane Mertens        Rob McElnea  Fabrizio Pirovano
# 13      Stephane Mertens   Stephane Mertens   Stephane Mertens
# 14         Raymond Roche      Raymond Roche      Raymond Roche
# 15         Raymond Roche      Peter Goddard      Doug Chandler
# 10             NaN                        NaN     NaN               NaN
# 11             NaN                        NaN     NaN               NaN
# 12             NaN                        NaN     NaN               NaN
# 13             NaN                        NaN     NaN               NaN
# 14             NaN                        NaN     NaN               NaN
# 15             NaN                        NaN     NaN               NaN
# 16             NaN                        NaN     NaN               NaN
# 17             NaN                        NaN     NaN               NaN
# 18             NaN                        NaN     NaN               NaN
# 19             NaN                        NaN     NaN               NaN
# 20             NaN                        NaN     NaN               NaN
# 21             NaN                        NaN     NaN               NaN
# 22             NaN                        NaN     NaN               NaN
# 23             NaN                        NaN     NaN               NaN
# 24             NaN                        NaN     NaN               NaN
# 25             NaN                        NaN     NaN               NaN
# 26           Qatar               Xerox Ducati  Report               NaN
# 27           Qatar             Alstare Suzuki  Report               NaN
# 28       Australia               Xerox Ducati  Report               NaN
# 29       Australia               Xerox Ducati  Report               NaN
# ..             ...                        ...     ...               ...
# 36   United States             Ten Kate Honda  Report               NaN
# 37   United States             Ten Kate Honda  Report               NaN
# 38         Germany        Yamaha Motor Italia  Report               NaN
# 39         Germany        Yamaha Motor Italia  Report               NaN
# 40      San Marino             Alstare Suzuki  Report               NaN
# 41      San Marino      Sterilgarda Go Eleven  Report               NaN
# 42  Czech Republic               Xerox Ducati  Report               NaN
# 43  Czech Republic               Xerox Ducati  Report               NaN
# 44   Great Britain             Ten Kate Honda  Report               NaN
# 45   Great Britain             Ten Kate Honda  Report               NaN
# 46          Europe               Xerox Ducati  Report               NaN
# 47          Europe             Ten Kate Honda  Report               NaN
# 48           Italy        Yamaha Motor Italia  Report               NaN
# 49           Italy        Yamaha Motor Italia  Report               NaN
# 50          France        Yamaha Motor Italia  Report               NaN
# 51          France               Xerox Ducati  Report               NaN
# 52        Portugal               Xerox Ducati  Report               NaN
# 53        Portugal               Xerox Ducati  Report               NaN
# 54             NaN  Kristoffersson Motorsport     NaN       Mats Linden
# 55             NaN            BMW Dealer Team     NaN    Fredrik Ekblom
# 56             NaN          Flash Engineering     NaN       Jan Nilsson
# 57             NaN            BMW Dealer Team     NaN  Peggen Andersson
# 58             NaN          Flash Engineering     NaN       Jan Nilsson
# 59             NaN            BMW Dealer Team     NaN  Peggen Andersson
# 60             NaN          Flash Engineering     NaN       Jan Nilsson
# 61             NaN          Flash Engineering     NaN        Jens Edman
# 62             NaN            BMW Dealer Team     NaN    Fredrik Ekblom
# 63             NaN          Flash Engineering     NaN       Jan Nilsson
# 64             NaN            BMW Dealer Team     NaN    Fredrik Ekblom
# 65             NaN          Flash Engineering     NaN       Jan Nilsson
#
#     winning privateer
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ..                ...
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                NaN
# 52                NaN
# 53                NaN
# 54  Richard Göransson
# 55       Pontus Mörth
# 56       Pontus Mörth
# 57       Pontus Mörth
# 58       Pontus Mörth
# 59      Georg Bakajev
# 60       Pontus Mörth
# 61       Pontus Mörth
# 62       Pontus Mörth
# 63      Georg Bakajev
# 64       Pontus Mörth
# 65       Pontus Mörth
#
# [66 rows x 12 columns]
# output_folder_transformation/3.csv
#     round round 1                                     circuit          date  \
# 0       1      R1                                       Jerez      18 March
# 1       1      R2                                       Jerez      18 March
# 2       2      R1                                   Donington      16 April
# 3       2      R2                                   Donington      16 April
# 4       3      R1                                 Hungaroring      30 April
# 5       3      R2                                 Hungaroring      30 April
# 6       4      R1                                  Hockenheim         6 May
# 7       4      R2                                  Hockenheim         6 May
# 8       5      R1                                     Mosport        3 June
# 9       5      R2                                     Mosport        3 June
# 10      6      R1                                    Brainerd       10 June
# 11      6      R2                                    Brainerd       10 June
# 12      7      R1                              Österreichring        1 July
# 13      7      R2                              Österreichring        1 July
# 14      8      R1                                        Sugo     26 August
# 15      8      R2                                        Sugo     26 August
# 16      9      R1                                     Le Mans   9 September
# 17      9      R2                                     Le Mans   9 September
# 18     10      R1                                       Monza     7 October
# 19     10      R2                                       Monza     7 October
# 20     11      R1                                   Shah Alam    4 November
# 21     11      R2                                   Shah Alam    4 November
# 22     12      R1                              Phillip Island   11 November
# 23     12      R2                              Phillip Island   11 November
# 24     13      R1                                    Manfeild   18 November
# 25     13      R2                                    Manfeild   18 November
# 26      1      R1                                Mantorp Park        10 May
# 27      1      R2                                Mantorp Park        10 May
# 28      2      R3                        Karlskoga-Gelleråsen        31 May
# 29      2      R4                        Karlskoga-Gelleråsen        31 May
# 30      3      R5                                  Anderstorp       28 June
# 31      3      R6                                  Anderstorp       28 June
# 32      4      R7                                  Falkenberg        9 July
# 33      4      R8                                  Falkenberg        9 July
# 34      5      R9                              Ring Knutstorp   6 September
# 35      5     R10                              Ring Knutstorp   6 September
# 36      6     R11                                Mantorp Park  27 September
# 37      6     R12                                Mantorp Park  27 September
# 38      1     NaN  ACI Vallelunga Circuit, Campagnano di Roma       7 April
# 39      2     NaN                        Misano World Circuit      28 April
# 40      3     NaN                  Autodromo di Pergusa, Enna        19 May
# 41      4     NaN                   Autodromo Nazionale Monza       30 June
# 42      5     NaN          Autodromo Riccardo Paletti, Varano       21 July
# 43      6     NaN        Autodromo Enzo e Dino Ferrari, Imola   1 September
# 44      7     NaN              Autodromo del Levante, Binetto   8 September
# 45      8     NaN                  Mugello Circuit, Scarperia     6 October
# 46      9     NaN              Autodromo dell'Umbria, Magione    20 October
#
#            pole position        fastest lap      winning rider  \
# 0          Raymond Roche   Stephane Mertens      Raymond Roche
# 1          Raymond Roche      Raymond Roche      Raymond Roche
# 2      Giancarlo Falappa        Rob Phillis        Fred Merkel
# 3      Giancarlo Falappa      Raymond Roche  Giancarlo Falappa
# 4       Malcolm Campbell      Raymond Roche        Fred Merkel
# 5       Malcolm Campbell        Fred Merkel      Raymond Roche
# 6          Raymond Roche        Fred Merkel        Fred Merkel
# 7          Raymond Roche      Raymond Roche   Stephane Mertens
# 8      Giancarlo Falappa      Raymond Roche      Raymond Roche
# 9      Giancarlo Falappa        Jamie James      Raymond Roche
# 10         Doug Chandler      Doug Chandler   Stephane Mertens
# 6      7              Autodromo del Levante, Binetto  8 September
# 7      8                  Mugello Circuit, Scarperia    6 October
# 8      9              Autodromo dell'Umbria, Magione   20 October
#
#          pole position       winning driver            winning team  \
# 0       Miloš Pavlović       Miloš Pavlović           Target Racing
# 1       Miloš Pavlović       Miloš Pavlović           Target Racing
# 2       Miloš Pavlović  Philip Cloostermans            Azeta Racing
# 3  Philip Cloostermans  Philip Cloostermans            Azeta Racing
# 4       Miloš Pavlović       Miloš Pavlović           Target Racing
# 5    Vitantonio Liuzzi    Vitantonio Liuzzi  Bertram Schäfer Racing
# 6    Christiano Citron       Miloš Pavlović           Target Racing
# 7       Miloš Pavlović       Miloš Pavlović           Target Racing
# 8        Andreas Zuber    Christiano Citron           Target Racing
#
#        trophy winner
# 0          Nino Famà
# 1  Giovanni Faraonio
# 2   Carmine Tancredi
# 3   Carmine Tancredi
# 4   Carmine Tancredi
# 5     Silvio Alberti
# 6   Carmine Tancredi
# 7      Dino Lusuardi
# 8    Alberto Morelli
# 204_845.csv
#    round                         circuit                 location  \
# 0      1          Albert Whitted Airport  St. Petersburg, Florida
# 1      2                  Fundidora park                Monterrey
# 2      3                  Milwaukee Mile    West Allis, Wisconsin
# 3      4       Mazda Raceway Laguna Seca     Monterey, California
# 4      5  Portland International Raceway         Portland, Oregon
# 5      6         Burke Lakefront Airport          Cleveland, Ohio
# 6      7                Exhibition Place                  Toronto
# 7      8           Concord Pacific Place                Vancouver
# 8      9      Mid-Ohio Sports Car Course          Lexington, Ohio
# 9     10       Circuit Gilles Villeneuve                 Montreal
#
#           date         pole position     fastest lap  winning driver  \
# 0  February 23         Leonardo Maia      Dan Di Leo   Leonardo Maia
# 1     March 23         Leonardo Maia  David Martinez  David Martinez
# 2       June 1  Victor Gonzalez, Jr.   Scott Poirier   Leonardo Maia
# 3      June 15            Memo Rojas   Leonardo Maia      Dan Di Leo
# 4      June 22         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 5       July 5         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 6      July 13         Leonardo Maia   Leonardo Maia      Memo Rojas
# 7      July 27         Leonardo Maia  David Martinez   Leonardo Maia
# 8     August 3         Leonardo Maia   Leonardo Maia   Leonardo Maia
# 9    August 24            Memo Rojas   Leonardo Maia      Memo Rojas
#
#                      headline event
# 0      Grand Prix of St. Petersburg
# 1              Monterrey Grand Prix
# 2     Milwaukee Mile Centennial 250
# 3            Grand Prix of Monterey
# 4                    G.I. Joe's 200
# 5    U.S. Bank Cleveland Grand Prix
# 6               Molson Indy Toronto
# 7             Molson Indy Vancouver
# 8  Champ Car Grand Prix of Mid-Ohio
# 9              Molson Indy Montreal

# %%
# schema and categories
s='{"schema": {"Round": "int64", "Round 1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"},"categories": ["motorsport", "car", "seasons"]}'
s=s.lower()
s=json.loads(s)
input_schema=s["schema"];input_categories=-1;transformations=-1;stats=-1
if "categories" in s:
    input_categories=s["categories"]
if "transformations" in s:
    transformations=s["transformations"]
if "stats" in s:
    stats=s["stats"]
# display query
print("Input Schema : ",input_schema)
if input_categories==-1:
    print("Input Categories : None")
else:
    print("Input Categories : ",input_categories)
if transformations==-1:
    print("Input Transformations : None")
else:
    print("Input Transformations : ",transformations)
if stats==-1:
    print("Input Condition based conditions : None")
else:
    print("Input Content based Conditions : ",stats)
print()
get_matches()
# Out:
# Input Schema :  {'round': 'int64', 'round 1': 'object', 'circuit': 'object', 'date': 'object', 'pole position': 'object', 'fastest lap': 'object', 'winning driver': 'object'}
# Input Categories :  ['motorsport', 'car', 'seasons']
# Input Transformations : None
# Input Condition based conditions : None
#
# category and schema
#
# Matching Tables :  ['203_181.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_569.csv', '204_63.csv']
# 203_181.csv 	 1990 IndyCar season
# 203_514.csv 	 2008 Superleague Formula season
# 203_742.csv 	 1995 IndyCar season
# 204_253.csv 	 1990 Superbike World Championship season
# 204_569.csv 	 1998 Swedish Touring Car Championship season
# 204_63.csv 	 2002 Italian Formula Three season
#
# 1.csv : 204_253.csv		204_569.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/47', 'round 1': '9/47', 'circuit': '0/47', 'date': '0/47', 'pole position': '6/47', 'fastest lap': '9/47', 'winning rider': '21/47', 'winning driver': '26/47', 'winning team': '26/47', 'winning privateer': '35/47', 'trophy winner': '38/47'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8480243161094225
#
# 2.csv : 203_181.csv		204_63.csv
# Missing Values(NANs):  {'date': '0/26', 'rnd': '9/26', 'race name': '9/26', 'circuit': '0/26', 'city/location': '9/26', 'pole position': '0/26', 'winning driver': '0/26', 'winning team': '0/26', 'report': '9/26', 'round': '17/26', 'trophy winner': '17/26'}
# Columns that match with input_schema:
# 203_181.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.6208791208791208
#
# 3.csv : 203_514.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/24', 'round 1': '0/24', 'race': '12/24', 'date': '0/24', 'pole position': '12/24', 'fastest lap': '0/24', 'winning club': '12/24', 'winning team': '0/24', 'report': '12/24', 'circuit': '12/24', 'winning driver': '12/24', 'winning privateer': '12/24'}
# Columns that match with input_schema:
# 203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.7857142857142857
#
# 4.csv : 204_253.csv		204_569.csv
# Missing Values(NANs):  {'round': '0/38', 'round 1': '0/38', 'circuit': '0/38', 'date': '0/38', 'pole position': '6/38', 'fastest lap': '0/38', 'winning rider': '12/38', 'winning driver': '26/38', 'winning team': '26/38', 'winning privateer': '26/38'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8796992481203008
#
# 5.csv : 204_253.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/35', 'round 1': '9/35', 'circuit': '0/35', 'date': '0/35', 'pole position': '0/35', 'fastest lap': '9/35', 'winning rider': '9/35', 'winning driver': '26/35', 'winning team': '26/35', 'trophy winner': '26/35'}
# Columns that match with input_schema:
# 204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.8204081632653061
#
# 6.csv : 204_569.csv		204_63.csv
# Missing Values(NANs):  {'round': '0/21', 'round 1': '9/21', 'circuit': '0/21', 'date': '0/21', 'pole position': '6/21', 'fastest lap': '9/21', 'winning driver': '0/21', 'winning team': '0/21', 'winning privateer': '9/21', 'trophy winner': '12/21'}
# Columns that match with input_schema:
# 204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# 204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.836734693877551
#
# 203_181.csv(1990 IndyCar season)
# Missing Values(NANs score):  {'date': '0/17', 'rnd': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_181.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.5714285714285714 	 Completeness Score :  0.5714285714285714
#
# 203_514.csv(2008 Superleague Formula season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'race': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning club': '0/12', 'winning team': '0/12', 'report': '0/12'}
# Columns that match with input_schema:
#  203_514.csv :  {'round': 'round', 'round 1': 'round 1', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.6428571428571429
#
# 203_742.csv(1995 IndyCar season)
# Missing Values(NANs score):  {'rnd': '0/17', 'date': '0/17', 'race name': '0/17', 'circuit': '0/17', 'city/location': '0/17', 'pole position': '0/17', 'fastest lap': '0/17', 'winning driver': '0/17', 'winning team': '0/17', 'report': '0/17'}
# Columns that match with input_schema:
#  203_742.csv :  {'date': 'date', 'circuit': 'circuit', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
# 204_253.csv(1990 Superbike World Championship season)
# Missing Values(NANs score):  {'round': '0/26', 'round 1': '0/26', 'circuit': '0/26', 'date': '0/26', 'pole position': '0/26', 'fastest lap': '0/26', 'winning rider': '0/26'}
# Columns that match with input_schema:
#  204_253.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap'}
# Coverage Score :  0.8571428571428571 	 Completeness Score :  0.8571428571428571
#
# 204_569.csv(1998 Swedish Touring Car Championship season)
# Missing Values(NANs score):  {'round': '0/12', 'round 1': '0/12', 'circuit': '0/12', 'date': '0/12', 'pole position': '6/12', 'fastest lap': '0/12', 'winning driver': '0/12', 'winning team': '0/12', 'winning privateer': '0/12'}
# Columns that match with input_schema:
#  204_569.csv :  {'round': 'round', 'round 1': 'round 1', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'fastest lap': 'fastest lap', 'winning driver': 'winning driver'}
# Coverage Score :  1.0 	 Completeness Score :  0.9285714285714286
#
# 204_63.csv(2002 Italian Formula Three season)
# Missing Values(NANs score):  {'round': '0/9', 'circuit': '0/9', 'date': '0/9', 'pole position': '0/9', 'winning driver': '0/9', 'winning team': '0/9', 'trophy winner': '0/9'}
# Columns that match with input_schema:
#  204_63.csv :  {'round': 'round', 'circuit': 'circuit', 'date': 'date', 'pole position': 'pole position', 'winning driver': 'winning driver'}
# Coverage Score :  0.7142857142857143 	 Completeness Score :  0.7142857142857143
#
#
# Rank  1   :  204_569.csv          completeness score : 0.9285714285714286 		number of rows:  12
# Rank  2   :  output_4.csv         completeness score : 0.8796992481203008 		number of rows:  38
# Rank  3   :  204_253.csv          completeness score : 0.8571428571428571 		number of rows:  26
# Rank  4   :  output_1.csv         completeness score : 0.8480243161094225 		number of rows:  47
# Rank  5   :  output_6.csv         completeness score : 0.8367346938775510 		number of rows:  21
# Rank  6   :  output_5.csv         completeness score : 0.8204081632653061 		number of rows:  35
# Rank  7   :  output_3.csv         completeness score : 0.7857142857142857 		number of rows:  24
# Rank  8   :  203_742.csv          completeness score : 0.7142857142857143 		number of rows:  17
# Rank  9   :  204_63.csv           completeness score : 0.7142857142857143 		number of rows:  9
# Rank  10  :  203_514.csv          completeness score : 0.6428571428571429 		number of rows:  12
# Rank  11  :  output_2.csv         completeness score : 0.6208791208791208 		number of rows:  26
# Rank  12  :  203_181.csv          completeness score : 0.5714285714285714 		number of rows:  17
#
# Ranking Complete!!

# %%
l=['output_folder_transformation/1.csv', 'output_folder_transformation/2.csv', 'output_folder_transformation/3.csv', 'output_folder_transformation/4.csv', 'output_folder_transformation/5.csv', 'output_folder_transformation/6.csv', '203_181.csv', '203_514.csv', '203_742.csv', '204_253.csv', '204_569.csv', '204_63.csv']
for i in l:
    x=pd.read_csv(i)
    print(i)
    display(x)
# Out:
# output_folder_transformation/1.csv
#     round round 1                                     circuit          date  \
# 0       1      R1                                       Jerez      18 March
# 1       1      R2                                       Jerez      18 March
# 2       2      R1                                   Donington      16 April
# 3       2      R2                                   Donington      16 April
# 4       3      R1                                 Hungaroring      30 April
# 5       3      R2                                 Hungaroring      30 April
# 6       4      R1                                  Hockenheim         6 May
# 7       4      R2                                  Hockenheim         6 May
# 8       5      R1                                     Mosport        3 June
# 9       5      R2                                     Mosport        3 June
# 10      6      R1                                    Brainerd       10 June
# 11      6      R2                                    Brainerd       10 June
# 12      7      R1                              Österreichring        1 July
# 13      7      R2                              Österreichring        1 July
# 14      8      R1                                        Sugo     26 August
# 15      8      R2                                        Sugo     26 August
# 16      9      R1                                     Le Mans   9 September
# 17      9      R2                                     Le Mans   9 September
# 18     10      R1                                       Monza     7 October
# 19     10      R2                                       Monza     7 October
# 20     11      R1                                   Shah Alam    4 November
# 21     11      R2                                   Shah Alam    4 November
# 22     12      R1                              Phillip Island   11 November
# 23     12      R2                              Phillip Island   11 November
# 24     13      R1                                    Manfeild   18 November
# 25     13      R2                                    Manfeild   18 November
# 26      1      R1                                Mantorp Park        10 May
# 27      1      R2                                Mantorp Park        10 May
# 28      2      R3                        Karlskoga-Gelleråsen        31 May
# 29      2      R4                        Karlskoga-Gelleråsen        31 May
# 30      3      R5                                  Anderstorp       28 June
# 31      3      R6                                  Anderstorp       28 June
# 32      4      R7                                  Falkenberg        9 July
# 33      4      R8                                  Falkenberg        9 July
# 34      5      R9                              Ring Knutstorp   6 September
# 35      5     R10                              Ring Knutstorp   6 September
# 36      6     R11                                Mantorp Park  27 September
# 37      6     R12                                Mantorp Park  27 September
# 38      1     NaN  ACI Vallelunga Circuit, Campagnano di Roma       7 April
# 39      2     NaN                        Misano World Circuit      28 April
# 14     Michael Andretti           Rick Mears             Team Penske  Report
# 15          Bobby Rahal   Emerson Fittipaldi             Team Penske  Report
# 16       Danny Sullivan       Danny Sullivan             Team Penske  Report
# 17       Miloš Pavlović       Miloš Pavlović           Target Racing     NaN
# 18       Miloš Pavlović       Miloš Pavlović           Target Racing     NaN
# 19       Miloš Pavlović  Philip Cloostermans            Azeta Racing     NaN
# 20  Philip Cloostermans  Philip Cloostermans            Azeta Racing     NaN
# 21       Miloš Pavlović       Miloš Pavlović           Target Racing     NaN
# 22    Vitantonio Liuzzi    Vitantonio Liuzzi  Bertram Schäfer Racing     NaN
# 23    Christiano Citron       Miloš Pavlović           Target Racing     NaN
# 24       Miloš Pavlović       Miloš Pavlović           Target Racing     NaN
# 25        Andreas Zuber    Christiano Citron           Target Racing     NaN
#
#     round      trophy winner
# 0     NaN                NaN
# 1     NaN                NaN
# 2     NaN                NaN
# 3     NaN                NaN
# 4     NaN                NaN
# 5     NaN                NaN
# 6     NaN                NaN
# 7     NaN                NaN
# 8     NaN                NaN
# 9     NaN                NaN
# 10    NaN                NaN
# 11    NaN                NaN
# 12    NaN                NaN
# 13    NaN                NaN
# 14    NaN                NaN
# 15    NaN                NaN
# 16    NaN                NaN
# 17    1.0          Nino Famà
# 18    2.0  Giovanni Faraonio
# 19    3.0   Carmine Tancredi
# 20    4.0   Carmine Tancredi
# 21    5.0   Carmine Tancredi
# 22    6.0     Silvio Alberti
# 23    7.0   Carmine Tancredi
# 24    8.0      Dino Lusuardi
# 25    9.0    Alberto Morelli
# output_folder_transformation/3.csv
#     round round 1            race          date         pole position  \
# 0       1      R1  Donington Park     August 31         Beijing Guoan
# 1       1      R2  Donington Park     August 31                   NaN
# 2       2      R1     Nurburgring  September 21            A.C. Milan
# 3       2      R2     Nurburgring  September 21                   NaN
# 4       3      R1          Zolder     October 5     Borussia Dortmund
# 5       3      R2          Zolder     October 5                   NaN
# 6       4      R1         Estoril    October 19             A.S. Roma
# 7       4      R2         Estoril    October 19                   NaN
# 8       5      R1      Vallelunga    November 2        Liverpool F.C.
# 9       5      R2      Vallelunga    November 2                   NaN
# 10      6      R1           Jerez   November 23        Liverpool F.C.
# 11      6      R2           Jerez   November 23                   NaN
# 12      1      R1             NaN        10 May       Mattias Ekström
# 13      1      R2             NaN        10 May                   NaN
# 14      2      R3             NaN        31 May           Jan Nilsson
# 15      2      R4             NaN        31 May                   NaN
# 16      3      R5             NaN       28 June       Mattias Ekström
# 17      3      R6             NaN       28 June                   NaN
# 18      4      R7             NaN        9 July            Jens Edman
# 19      4      R8             NaN        9 July                   NaN
# 20      5      R9             NaN   6 September        Fredrik Ekblom
# 21      5     R10             NaN   6 September                   NaN
# 22      6     R11             NaN  27 September  Tommy Kristoffersson
# 23      6     R12             NaN  27 September                   NaN
#
#           fastest lap       winning club               winning team  report  \
# 0       Beijing Guoan      Beijing Guoan                   Zakspeed  Report
# 1       PSV Eindhoven         Sevilla FC      GTA Motor Competicion  Report
# 2       PSV Eindhoven         A.C. Milan          Scuderia Playteam  Report
# 9       5      R2               Mosport        3 June     Giancarlo Falappa
# 10      6      R1              Brainerd       10 June         Doug Chandler
# 11      6      R2              Brainerd       10 June         Doug Chandler
# 12      7      R1        Österreichring        1 July      Stephane Mertens
# 13      7      R2        Österreichring        1 July      Stephane Mertens
# 14      8      R1                  Sugo     26 August         Raymond Roche
# 15      8      R2                  Sugo     26 August         Raymond Roche
# 16      9      R1               Le Mans   9 September     Baldassarre Monti
# 17      9      R2               Le Mans   9 September     Baldassarre Monti
# 18     10      R1                 Monza     7 October     Baldassarre Monti
# 19     10      R2                 Monza     7 October     Baldassarre Monti
# 20     11      R1             Shah Alam    4 November           Rob Phillis
# 21     11      R2             Shah Alam    4 November           Rob Phillis
# 22     12      R1        Phillip Island   11 November         Peter Goddard
# 23     12      R2        Phillip Island   11 November         Peter Goddard
# 24     13      R1              Manfeild   18 November           Rob Phillis
# 25     13      R2              Manfeild   18 November           Rob Phillis
# 26      1      R1          Mantorp Park        10 May       Mattias Ekström
# 27      1      R2          Mantorp Park        10 May                   NaN
# 28      2      R3  Karlskoga-Gelleråsen        31 May           Jan Nilsson
# 29      2      R4  Karlskoga-Gelleråsen        31 May                   NaN
# 30      3      R5            Anderstorp       28 June       Mattias Ekström
# 31      3      R6            Anderstorp       28 June                   NaN
# 32      4      R7            Falkenberg        9 July            Jens Edman
# 33      4      R8            Falkenberg        9 July                   NaN
# 34      5      R9        Ring Knutstorp   6 September        Fredrik Ekblom
# 35      5     R10        Ring Knutstorp   6 September                   NaN
# 36      6     R11          Mantorp Park  27 September  Tommy Kristoffersson
# 37      6     R12          Mantorp Park  27 September                   NaN
#
#           fastest lap      winning rider    winning driver  \
# 0    Stephane Mertens      Raymond Roche               NaN
# 1       Raymond Roche      Raymond Roche               NaN
# 2         Rob Phillis        Fred Merkel               NaN
# 3       Raymond Roche  Giancarlo Falappa               NaN
# 4       Raymond Roche        Fred Merkel               NaN
# 5         Fred Merkel      Raymond Roche               NaN
# 6         Fred Merkel        Fred Merkel               NaN
# 7       Raymond Roche   Stephane Mertens               NaN
# 8       Raymond Roche      Raymond Roche               NaN
# 9         Jamie James      Raymond Roche               NaN
# 10      Doug Chandler   Stephane Mertens               NaN
# 11  Fabrizio Pirovano      Doug Chandler               NaN
# 12        Rob McElnea  Fabrizio Pirovano               NaN
# 13   Stephane Mertens   Stephane Mertens               NaN
# 14      Raymond Roche      Raymond Roche               NaN
# 15      Peter Goddard      Doug Chandler               NaN
# 16      Raymond Roche      Raymond Roche               NaN
# 17        Jamie James      Raymond Roche               NaN
# 18        Rob Phillis  Fabrizio Pirovano               NaN
# 19        Rob Phillis  Fabrizio Pirovano               NaN
# 20  Fabrizio Pirovano  Fabrizio Pirovano               NaN
# 21      Raymond Roche  Fabrizio Pirovano               NaN
# 22  Fabrizio Pirovano      Peter Goddard               NaN
# 23   Malcolm Campbell        Rob Phillis               NaN
# 24     Brian Morrison        Terry Rymer               NaN
# 25      Raymond Roche        Rob Phillis               NaN
# 26     Fredrik Ekblom                NaN       Mats Linden
# 27   Peggen Andersson                NaN    Fredrik Ekblom
# 28        Jan Nilsson                NaN       Jan Nilsson
# 29     Fredrik Ekblom                NaN  Peggen Andersson
# 30     Fredrik Ekblom                NaN       Jan Nilsson
# 31   Peggen Andersson                NaN  Peggen Andersson
# 32         Jens Edman                NaN       Jan Nilsson
# 33    Mattias Ekström                NaN        Jens Edman
# 34     Fredrik Ekblom                NaN    Fredrik Ekblom
# 35        Mats Linden                NaN       Jan Nilsson
# 36     Fredrik Ekblom                NaN    Fredrik Ekblom
# 37   Peggen Andersson                NaN       Jan Nilsson
#
#                  winning team  winning privateer
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                         NaN                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
# 5                         NaN                NaN
# 6                         NaN                NaN
# 7                         NaN                NaN
# 8                         NaN                NaN
# 9                         NaN                NaN
# 10                        NaN                NaN
# 11                        NaN                NaN
# 12                        NaN                NaN
# 13                        NaN                NaN
# 14                        NaN                NaN
# 15                        NaN                NaN
# 16                        NaN                NaN
# 17                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 20                        NaN                NaN
# 21                        NaN                NaN
# 22                        NaN                NaN
# 23                        NaN                NaN
# 24                        NaN                NaN
# 25                        NaN                NaN
# 26  Kristoffersson Motorsport  Richard Göransson
# 27            BMW Dealer Team       Pontus Mörth
# 28          Flash Engineering       Pontus Mörth
# 29            BMW Dealer Team       Pontus Mörth
# 30          Flash Engineering       Pontus Mörth
# 31            BMW Dealer Team      Georg Bakajev
# 32          Flash Engineering       Pontus Mörth
# 33          Flash Engineering       Pontus Mörth
# 34            BMW Dealer Team       Pontus Mörth
# 35          Flash Engineering      Georg Bakajev
# 36            BMW Dealer Team       Pontus Mörth
# 37          Flash Engineering       Pontus Mörth
# output_folder_transformation/5.csv
#     round round 1                                     circuit         date  \
# 0       1      R1                                       Jerez     18 March
# 1       1      R2                                       Jerez     18 March
# 2       2      R1                                   Donington     16 April
# 3       2      R2                                   Donington     16 April
# 4       3      R1                                 Hungaroring     30 April
# 5       3      R2                                 Hungaroring     30 April
# 6       4      R1                                  Hockenheim        6 May
# 7       4      R2                                  Hockenheim        6 May
# 8       5      R1                                     Mosport       3 June
# 9       5      R2                                     Mosport       3 June
# 10      6      R1                                    Brainerd      10 June
# 11      6      R2                                    Brainerd      10 June
# 12      7      R1                              Österreichring       1 July
# 13      7      R2                              Österreichring       1 July
# 14      8      R1                                        Sugo    26 August
# 15      8      R2                                        Sugo    26 August
# 16      9      R1                                     Le Mans  9 September
# 17      9      R2                                     Le Mans  9 September
# 18     10      R1                                       Monza    7 October
# 19     10      R2                                       Monza    7 October
# 20     11      R1                                   Shah Alam   4 November
# 21     11      R2                                   Shah Alam   4 November
# 22     12      R1                              Phillip Island  11 November
# 23     12      R2                              Phillip Island  11 November
# 24     13      R1                                    Manfeild  18 November
# 25     13      R2                                    Manfeild  18 November
# 26      1     NaN  ACI Vallelunga Circuit, Campagnano di Roma      7 April
# 27      2     NaN                        Misano World Circuit     28 April
# 28      3     NaN                  Autodromo di Pergusa, Enna       19 May
# 13  Marlboro Team Penske  Report
# 14    Tasman Motorsports  Report
# 15  Marlboro Team Penske  Report
# 16       Jim Hall Racing  Report
# 204_253.csv
#     round round 1         circuit         date      pole position  \
# 0       1      R1           Jerez     18 March      Raymond Roche
# 1       1      R2           Jerez     18 March      Raymond Roche
# 2       2      R1       Donington     16 April  Giancarlo Falappa
# 3       2      R2       Donington     16 April  Giancarlo Falappa
# 4       3      R1     Hungaroring     30 April   Malcolm Campbell
# 5       3      R2     Hungaroring     30 April   Malcolm Campbell
# 6       4      R1      Hockenheim        6 May      Raymond Roche
# 7       4      R2      Hockenheim        6 May      Raymond Roche
# 8       5      R1         Mosport       3 June  Giancarlo Falappa
# 9       5      R2         Mosport       3 June  Giancarlo Falappa
# 10      6      R1        Brainerd      10 June      Doug Chandler
# 11      6      R2        Brainerd      10 June      Doug Chandler
# 12      7      R1  Österreichring       1 July   Stephane Mertens
# 13      7      R2  Österreichring       1 July   Stephane Mertens
# 14      8      R1            Sugo    26 August      Raymond Roche
# 15      8      R2            Sugo    26 August      Raymond Roche
# 16      9      R1         Le Mans  9 September  Baldassarre Monti
# 17      9      R2         Le Mans  9 September  Baldassarre Monti
# 18     10      R1           Monza    7 October  Baldassarre Monti
# 19     10      R2           Monza    7 October  Baldassarre Monti
# 20     11      R1       Shah Alam   4 November        Rob Phillis
# 21     11      R2       Shah Alam   4 November        Rob Phillis
# 22     12      R1  Phillip Island  11 November      Peter Goddard
# 23     12      R2  Phillip Island  11 November      Peter Goddard
# 24     13      R1        Manfeild  18 November        Rob Phillis
# 25     13      R2        Manfeild  18 November        Rob Phillis
#
#           fastest lap      winning rider
# 0    Stephane Mertens      Raymond Roche
# 1       Raymond Roche      Raymond Roche
# 2         Rob Phillis        Fred Merkel
# 3       Raymond Roche  Giancarlo Falappa
# 4       Raymond Roche        Fred Merkel
# 5         Fred Merkel      Raymond Roche
# 6         Fred Merkel        Fred Merkel
# 7       Raymond Roche   Stephane Mertens
# 8       Raymond Roche      Raymond Roche
# 9         Jamie James      Raymond Roche
# 10      Doug Chandler   Stephane Mertens
# 11  Fabrizio Pirovano      Doug Chandler
# 12        Rob McElnea  Fabrizio Pirovano
# 13   Stephane Mertens   Stephane Mertens
# 14      Raymond Roche      Raymond Roche
# 15      Peter Goddard      Doug Chandler
# 16      Raymond Roche      Raymond Roche
# 17        Jamie James      Raymond Roche
# 18        Rob Phillis  Fabrizio Pirovano
# 19        Rob Phillis  Fabrizio Pirovano
# 20  Fabrizio Pirovano  Fabrizio Pirovano
# 21      Raymond Roche  Fabrizio Pirovano
# 22  Fabrizio Pirovano      Peter Goddard
# 23   Malcolm Campbell        Rob Phillis
# 24     Brian Morrison        Terry Rymer
# 25      Raymond Roche        Rob Phillis
# 204_569.csv
#     round round 1               circuit          date         pole position  \
# 0       1      R1          Mantorp Park        10 May       Mattias Ekström
# 1       1      R2          Mantorp Park        10 May                   NaN
# 2       2      R3  Karlskoga-Gelleråsen        31 May           Jan Nilsson
# 3       2      R4  Karlskoga-Gelleråsen        31 May                   NaN
s='{"schema": {"date": "object", "nationality": "object", "tonnage (grt)": "int64", "fate": "object"},"transformations":{"tonnage (grt)":["sum","funct1","avg","minimum"],"nationality":["funct1","sum"]},"stats":{"tonnage (grt)":["minimum>0","maximum<10000"]}}'
s=s.lower()
s=json.loads(s)
input_schema=s["schema"];input_categories=-1;transformations=-1;stats=-1
if "categories" in s:
    input_categories=s["categories"]
if "transformations" in s:
    transformations=s["transformations"]
if "stats" in s:
    stats=s["stats"]
# display query
print("Input Schema : ",input_schema)
if input_categories==-1:
    print("Input Categories : None")
else:
    print("Input Categories : ",input_categories)
if transformations==-1:
    print("Input Transformations : None")
else:
    print("Input Transformations : ",transformations)
if stats==-1:
    print("Input Condition based conditions : None")
else:
    print("Input Content based Conditions : ",stats)
print()
get_matches()
# Out:
# Input Schema :  {'date': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
# Input Categories : None
# Input Transformations :  {'tonnage (grt)': ['sum', 'funct1', 'avg', 'minimum'], 'nationality': ['funct1', 'sum']}
# Input Content based Conditions :  {'tonnage (grt)': ['minimum>0', 'maximum<10000']}
#
# only schema
#
# Matching Tables :  ['202_117.csv', '203_148.csv', '203_268.csv', '204_100.csv']
# 202_117.csv 	 German submarine U-559
# 203_148.csv 	 German submarine U-9 (1935)
# 203_268.csv 	 German submarine U-502
# 204_100.csv 	 Hans-Rudolf Rosing
#
# 1.csv : 202_117.csv		203_148.csv		203_268.csv
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 412.0>0 )']}
# Conditions Not Satisfied :  {'tonnage (grt)': ['maximum<10000( max = 14795.0 )']}
# Missing Values(NANs):  {'date': '0/31', 'ship': '0/31', 'nationality': '0/31', 'tonnage (grt)': '0/31', 'fate': '0/31'}
# Columns that match with input_schema:
# 202_117.csv :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# 203_148.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 203_268.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 2.csv : 202_117.csv		203_148.csv
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 412.0>0 )', 'maximum<10000( 5995.0<10000 )']}
# Missing Values(NANs):  {'date': '0/15', 'ship': '0/15', 'nationality': '0/15', 'tonnage (grt)': '0/15', 'fate': '0/15'}
# Columns that match with input_schema:
# 202_117.csv :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# 203_148.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 3.csv : 202_117.csv		203_268.csv
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 1060.0>0 )']}
# Conditions Not Satisfied :  {'tonnage (grt)': ['maximum<10000( max = 14795.0 )']}
# Missing Values(NANs):  {'date': '0/22', 'ship': '0/22', 'nationality': '0/22', 'tonnage (grt)': '0/22', 'fate': '0/22'}
# Columns that match with input_schema:
# 202_117.csv :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# 203_268.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 4.csv : 203_148.csv		203_268.csv
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 412.0>0 )']}
# Conditions Not Satisfied :  {'tonnage (grt)': ['maximum<10000( max = 14795.0 )']}
# Missing Values(NANs):  {'date': '0/25', 'name': '0/25', 'nationality': '0/25', 'tonnage (grt)': '0/25', 'fate': '0/25'}
# Columns that match with input_schema:
# 203_148.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# 203_268.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 202_117.csv(German submarine U-559)
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 1060.0>0 )', 'maximum<10000( 5917.0<10000 )']}
# Missing Values(NANs score):  {'date': '0/6', 'ship': '0/6', 'nationality': '0/6', 'tonnage': '0/6', 'fate': '0/6'}
# Columns that match with input_schema:
#  202_117.csv :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 203_148.csv(German submarine U-9 (1935))
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 412.0>0 )', 'maximum<10000( 5995.0<10000 )']}
# Missing Values(NANs score):  {'date': '0/9', 'name': '0/9', 'nationality': '0/9', 'tonnage (grt)': '0/9', 'fate': '0/9'}
# Columns that match with input_schema:
#  203_148.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 203_268.csv(German submarine U-502)
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 2391.0>0 )']}
# Conditions NOT SATISFIED :  {'tonnage (grt)': ['maximum<10000( max = 14795.0 )']}
# Missing Values(NANs score):  {'date': '0/16', 'name': '0/16', 'nationality': '0/16', 'tonnage (grt)': '0/16', 'fate': '0/16'}
# Columns that match with input_schema:
#  203_268.csv :  {'date': 'date', 'nationality': 'nationality', 'tonnage (grt)': 'tonnage (grt)', 'fate': 'fate'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
# 204_100.csv(Hans-Rudolf Rosing)
# possible transformations are :  {'tonnage (grt)': ['sum', 'avg', 'minimum'], 'nationality': ['funct1']}
# Conditions Satisfied :  {'tonnage (grt)': ['minimum>0( 798.0>0 )', 'maximum<10000( 7590.0<10000 )']}
# Missing Values(NANs score):  {'date': '0/13', 'name of ship': '0/13', 'nationality': '0/13', 'tonnage': '0/13', 'fate': '0/13'}
# Columns that match with input_schema:
#  204_100.csv :  {'date': 'date', 'nationality': 'nationality', 'fate': 'fate', 'tonnage': 'tonnage (grt)'}
# Coverage Score :  1.0 	 Completeness Score :  1.0
#
#
# Rank  1   :  output_1.csv         completeness score : 1.0000000000000000 		number of rows:  31
# Rank  2   :  output_4.csv         completeness score : 1.0000000000000000 		number of rows:  25
# Rank  3   :  output_3.csv         completeness score : 1.0000000000000000 		number of rows:  22
# Rank  4   :  203_268.csv          completeness score : 1.0000000000000000 		number of rows:  16
# Rank  5   :  output_2.csv         completeness score : 1.0000000000000000 		number of rows:  15
# Rank  6   :  204_100.csv          completeness score : 1.0000000000000000 		number of rows:  13
# Rank  7   :  203_148.csv          completeness score : 1.0000000000000000 		number of rows:  9
# Rank  8   :  202_117.csv          completeness score : 1.0000000000000000 		number of rows:  6
#
# Ranking Complete!!

# %%
l=["202_117.csv",'203_148.csv', '203_268.csv', '204_100.csv',"output_folder_transformation/1.csv","output_folder_transformation/2.csv","output_folder_transformation/3.csv","output_folder_transformation/4.csv"]
for i in l:
    x=pd.read_csv(i)
    print(i)
    display(x)
# Out:
# 202_117.csv
#                date             ship            nationality  tonnage     fate
# 0    19 August 1941        SS Aguila         United Kingdom     3255     Sunk
# 1  27 November 1941  HMAS Parramatta  Royal Australian Navy     1060     Sunk
# 2  23 December 1941      SS Shuntien         United Kingdom     3059     Sunk
# 3  26 December 1941      SS Warszawa                 Poland     2487     Sunk
# 4      10 June 1942        MV Athene                 Norway     4681     Sunk
# 5      10 June 1942   SS Brambleleaf         United Kingdom     5917  Damaged
# 203_148.csv
#                date             name     nationality  tonnage (grt)  \
# 0   18 January 1940         Flandria          Sweden           1179
# 1   19 January 1940           Patria          Sweden           1188
# 2  11 February 1940            Linda         Estonia           1213
# 3        4 May 1940     San Tiburcio  United Kingdom           5995
# 4        9 May 1940            Doris     French Navy            552
# 5       11 May 1940           Tringa  United Kingdom           1930
# 6       11 May 1940             Viiu         Estonia           1908
# 7       23 May 1940  Sigurd Faulbaum         Belgium           3256
# 8       11 May 1944           Shtorm    Soviet Union            412
#
#           fate
# 0         Sunk
# 1         Sunk
# 2         Sunk
# 3  Sunk (mine)
# 4         Sunk
# 5         Sunk
# 6         Sunk
# 7         Sunk
# 8      Damaged
# 203_268.csv
#                 date               name     nationality  tonnage (grt)  \
# 0     7 October 1941         Svend Foyn  United Kingdom          14795
# 1   16 February 1942            Monagas       Venezuela           2650
# 2   16 February 1942       San Nicholas  United Kingdom           2391
# 3   16 February 1942          Tia Juana  United Kingdom           2395
# 4   22 February 1942            J.N.Pew   United States           9033
# 5   23 February 1942                Sun   United States           9002
# 6   23 February 1942             Thalia          Panama           8329
# 7        11 May 1942  Cape of Good Hope  United Kingdom           4963
# 8        24 May 1942     Gonçalves Dias          Brazil           4996
# 9        28 May 1942      Alcoa Pilgrim   United States           6759
# 10       3 June 1942       M.F. Ellliot   United States           6940
# 11       9 June 1942          Bruxelles         Belgium           5085
# 12       9 June 1942   Franklin K. Lane   United States           6589
# 13      15 June 1942        Cold Harbor          Panama           5010
# 20         Sunk
# 21         Sunk
# 22         Sunk
# 23         Sunk
# 24         Sunk

# %%
# Special Function to generate scores for a single table/schema that is provided by th user
def get_scores(input_schema,check_schema,check_tablename=-1):
    print("Requirements : ",input_schema)
    print("Schema to be scored : ",check_schema)
    input_sch_onto=generate_ontology(input_schema)
    cols1={col1:col1 for col1,d_type1 in check_schema.items() if col1 in input_schema and d_type1==input_schema[col1]}
    check_schema={k:v for k,v in check_schema.items() if k not in list(cols1.values())}
    cols2={col1:col for col1,d_type1 in check_schema.items() for col in input_sch_onto if col1 in input_sch_onto[col] and d_type1==input_schema[col]}
    check_schema={k:v for k,v in check_schema.items() if k not in cols1}
    cols={**cols1,**cols2}
    ip_schema={k:v for k,v in input_schema.items() if k not in list(cols.values())}
    for col1,d_type1 in ip_schema.items():
        x=[col2 for col2,d_type2 in check_schema.items() if ((len(col1)>3 and len(col2)>3) and ((col1 in col2) or (col2 in col1))) and (d_type1==d_type2)]
        if len(x)==1:
            cols[x[0]]=col1
    print("Matching Columns : ",cols)
    print("Coverage : ",len(cols)/len(input_schema))
    if check_tablename!=-1:
        x=pd.read_csv(check_tablename)
        l=len(x)
        print("NULL scores : ",nan_score(table=x))
        comp=0.0
        for col in cols:
            comp+=((l-sum(pd.isnull(x[col])))/l)
        comp=comp/len(input_schema)
        print("Completeness score : ",comp)
    else:
        print("Table Not Available. Completeness and Null Scores not applicable.")

# %%
# when schema and table is provided to function all scores are generated
ip_sch={'date': 'object', 'name of ship': 'object', 'nation': 'object', 'tonnage': 'int64', 'fate': 'object'}
sch={'date': 'object', 'name': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
tname='203_268.csv'
get_scores(ip_sch,sch,tname)
# Out:
# Requirements :  {'date': 'object', 'name of ship': 'object', 'nation': 'object', 'tonnage': 'int64', 'fate': 'object'}
# Schema to be scored :  {'date': 'object', 'name': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
# Matching Columns :  {'date': 'date', 'fate': 'fate', 'name': 'name of ship', 'nationality': 'nation', 'tonnage (grt)': 'tonnage'}
# Coverage :  1.0
# NULL scores :  {'date': '0/16', 'name': '0/16', 'nationality': '0/16', 'tonnage (grt)': '0/16', 'fate': '0/16'}
# Completeness score :  1.0

# %%
# when only schema is provided only coverage generated, no completeness score
ip_sch={'date': 'object', 'name of ship': 'object', 'nation': 'object', 'tonnage': 'int64', 'fate': 'object'}
sch={'day': 'object', 'name': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
get_scores(ip_sch,sch)
# Out:
# Requirements :  {'date': 'object', 'name of ship': 'object', 'nation': 'object', 'tonnage': 'int64', 'fate': 'object'}
# Schema to be scored :  {'day': 'object', 'name': 'object', 'nationality': 'object', 'tonnage (grt)': 'int64', 'fate': 'object'}
# Matching Columns :  {'fate': 'fate', 'day': 'date', 'name': 'name of ship', 'nationality': 'nation', 'tonnage (grt)': 'tonnage'}
# Coverage :  1.0
# Table Not Available. Completeness and Null Scores not applicable.
