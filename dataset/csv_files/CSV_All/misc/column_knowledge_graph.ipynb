# %%
import json
import math
import pandas as pd
import numpy as np
from nltk.corpus import wordnet
from itertools import product

# %%
all_schemas={}
with open("final_schema.txt") as f:
    for line in f.readlines():
        json_obj=json.loads(line)
        all_schemas[json_obj["filename"]]={"tablename":json_obj["tablename"],"schema":json_obj["schema"],"categories":json_obj["categories"]}

# %%
def syn_hyp_generation(word):
    word=word.split()
    i,j=word[0],word[1]
    l1=get_synonyms(i)
    l2=get_synonyms(j)
    l3=list(product(l1,l2))
    print(l1,"\n",l2,"\n",l3)
    print(len(l1),len(l2),len(l3))
        
    
def get_synonyms(word):
    meanings=set()
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for lemma in synset.lemmas():
            meanings.add(lemma.name())
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for hypernym in synset.hypernyms():
            meanings.add(hypernym.lemma_names()[0])
    meanings.add(word)
    return list(meanings)

# %%
syn_hyp_generation("employee id")
# Out:
# ['employee', 'worker']
#  ['badge', 'Gem_State', 'Idaho', 'instinct', 'ID', 'positive_identification', 'I.D.', 'id']
#  [('employee', 'badge'), ('employee', 'Gem_State'), ('employee', 'Idaho'), ('employee', 'instinct'), ('employee', 'ID'), ('employee', 'positive_identification'), ('employee', 'I.D.'), ('employee', 'id'), ('worker', 'badge'), ('worker', 'Gem_State'), ('worker', 'Idaho'), ('worker', 'instinct'), ('worker', 'ID'), ('worker', 'positive_identification'), ('worker', 'I.D.'), ('worker', 'id')]
# 2 8 16

# %%
from nltk.corpus import wordnet as wn
from itertools import product

wordx, wordy = "pole","position"
sem1, sem2 = wn.synsets(wordx,pos=wordnet.NOUN), wn.synsets(wordy,pos=wordnet.NOUN)

maxscore = 0
score=0
for i,j in list(product(*[sem1,sem2])):
    score = i.wup_similarity(j) # Wu-Palmer Similarity
    score = 0.0 if type(score) == None else score
    
    maxscore = score if maxscore < score else maxscore
    print(i,j,score)
# Out:
# Synset('pole.n.01') Synset('position.n.01') 0.4
# Synset('pole.n.01') Synset('military_position.n.01') 0.4
# Synset('pole.n.01') Synset('position.n.03') 0.125
# Synset('pole.n.01') Synset('position.n.04') 0.13333333333333333
# Synset('pole.n.01') Synset('status.n.01') 0.14285714285714285
# Synset('pole.n.01') Synset('position.n.06') 0.11764705882352941
# Synset('pole.n.01') Synset('position.n.07') 0.15384615384615385
# Synset('pole.n.01') Synset('position.n.08') 0.4
# Synset('pole.n.01') Synset('position.n.09') 0.11764705882352941
# Synset('pole.n.01') Synset('placement.n.03') 0.125
# Synset('pole.n.01') Synset('situation.n.02') 0.13333333333333333
# Synset('pole.n.01') Synset('position.n.12') 0.13333333333333333
# Synset('pole.n.01') Synset('side.n.10') 0.13333333333333333
# Synset('pole.n.01') Synset('place.n.15') 0.13333333333333333
# Synset('pole.n.01') Synset('stead.n.01') 0.10526315789473684
# Synset('pole.n.01') Synset('position.n.16') 0.125
# Synset('pole.n.02') Synset('position.n.01') 0.4
# Synset('pole.n.02') Synset('military_position.n.01') 0.4
# Synset('pole.n.02') Synset('position.n.03') 0.14285714285714285
# Synset('pole.n.02') Synset('position.n.04') 0.15384615384615385
# Synset('pole.n.02') Synset('status.n.01') 0.16666666666666666
# Synset('pole.n.02') Synset('position.n.06') 0.13333333333333333
# Synset('pole.n.02') Synset('position.n.07') 0.18181818181818182
# Synset('pole.n.02') Synset('position.n.08') 0.4
# Synset('pole.n.02') Synset('position.n.09') 0.13333333333333333
# Synset('pole.n.02') Synset('placement.n.03') 0.14285714285714285
# Synset('pole.n.02') Synset('situation.n.02') 0.15384615384615385
# Synset('pole.n.02') Synset('position.n.12') 0.15384615384615385
# Synset('pole.n.02') Synset('side.n.10') 0.15384615384615385
# Synset('pole.n.02') Synset('place.n.15') 0.15384615384615385
# Synset('pole.n.02') Synset('stead.n.01') 0.11764705882352941
# Synset('pole.n.02') Synset('position.n.16') 0.14285714285714285
# Synset('pole.n.03') Synset('position.n.01') 0.14285714285714285
# Synset('pole.n.03') Synset('military_position.n.01') 0.14285714285714285
# Synset('pole.n.03') Synset('position.n.03') 0.5333333333333333
# Synset('pole.n.03') Synset('position.n.04') 0.2857142857142857
# Synset('pole.n.03') Synset('status.n.01') 0.3076923076923077
# Synset('pole.n.03') Synset('position.n.06') 0.375
# Synset('pole.n.03') Synset('position.n.07') 0.3333333333333333
# Synset('pole.n.03') Synset('position.n.08') 0.14285714285714285
# Synset('pole.n.03') Synset('position.n.09') 0.375
# Synset('pole.n.03') Synset('placement.n.03') 0.4
# Synset('pole.n.03') Synset('situation.n.02') 0.2857142857142857
# Synset('pole.n.03') Synset('position.n.12') 0.5714285714285714
# Synset('pole.n.03') Synset('side.n.10') 0.2857142857142857
# Synset('pole.n.03') Synset('place.n.15') 0.2857142857142857
# Synset('pole.n.03') Synset('stead.n.01') 0.3333333333333333
# Synset('pole.n.03') Synset('position.n.16') 0.4
# Synset('perch.n.02') Synset('position.n.01') 0.15384615384615385
# Synset('perch.n.02') Synset('military_position.n.01') 0.15384615384615385
# Synset('perch.n.02') Synset('position.n.03') 0.2857142857142857
# Synset('perch.n.02') Synset('position.n.04') 0.3076923076923077
# Synset('perch.n.02') Synset('status.n.01') 0.3333333333333333
# Synset('perch.n.02') Synset('position.n.06') 0.26666666666666666
# Synset('perch.n.02') Synset('position.n.07') 0.36363636363636365
# Synset('perch.n.02') Synset('position.n.08') 0.15384615384615385
# Synset('perch.n.02') Synset('position.n.09') 0.26666666666666666
# Synset('perch.n.02') Synset('placement.n.03') 0.2857142857142857
# Synset('perch.n.02') Synset('situation.n.02') 0.3076923076923077
# Synset('perch.n.02') Synset('position.n.12') 0.3076923076923077
# Synset('perch.n.02') Synset('side.n.10') 0.3076923076923077
# Synset('perch.n.02') Synset('place.n.15') 0.3076923076923077
# Synset('perch.n.02') Synset('stead.n.01') 0.23529411764705882
# Synset('perch.n.02') Synset('position.n.16') 0.2857142857142857
# Synset('perch.n.03') Synset('position.n.01') 0.15384615384615385
# Synset('perch.n.03') Synset('military_position.n.01') 0.15384615384615385
# Synset('perch.n.03') Synset('position.n.03') 0.2857142857142857
# Synset('perch.n.03') Synset('position.n.04') 0.3076923076923077
# Synset('perch.n.03') Synset('status.n.01') 0.3333333333333333
# Synset('perch.n.03') Synset('position.n.06') 0.26666666666666666
# Synset('perch.n.03') Synset('position.n.07') 0.36363636363636365
# Synset('perch.n.03') Synset('position.n.08') 0.15384615384615385
# Synset('perch.n.03') Synset('position.n.09') 0.26666666666666666
# Synset('perch.n.03') Synset('placement.n.03') 0.2857142857142857
# Synset('perch.n.03') Synset('situation.n.02') 0.3076923076923077
# Synset('perch.n.03') Synset('position.n.12') 0.3076923076923077
# Synset('perch.n.03') Synset('side.n.10') 0.3076923076923077
# Synset('perch.n.03') Synset('place.n.15') 0.3076923076923077
# Synset('perch.n.03') Synset('stead.n.01') 0.23529411764705882
# Synset('perch.n.03') Synset('position.n.16') 0.2857142857142857
# Synset('pole.n.06') Synset('position.n.01') 0.7692307692307693
# Synset('pole.n.06') Synset('military_position.n.01') 0.7692307692307693
# Synset('pole.n.06') Synset('position.n.03') 0.14285714285714285
# Synset('pole.n.06') Synset('position.n.04') 0.15384615384615385
# Synset('pole.n.06') Synset('status.n.01') 0.16666666666666666
# Synset('pole.n.06') Synset('position.n.06') 0.13333333333333333
# Synset('pole.n.06') Synset('position.n.07') 0.18181818181818182
# Synset('pole.n.06') Synset('position.n.08') 0.7692307692307693
# Synset('pole.n.06') Synset('position.n.09') 0.13333333333333333
# Synset('pole.n.06') Synset('placement.n.03') 0.14285714285714285
# Synset('pole.n.06') Synset('situation.n.02') 0.15384615384615385
# Synset('pole.n.06') Synset('position.n.12') 0.15384615384615385
# Synset('pole.n.06') Synset('side.n.10') 0.15384615384615385
# Synset('pole.n.06') Synset('place.n.15') 0.15384615384615385
# Synset('pole.n.06') Synset('stead.n.01') 0.11764705882352941
# Synset('pole.n.06') Synset('position.n.16') 0.14285714285714285
# Synset('pole.n.07') Synset('position.n.01') 0.7692307692307693
# Synset('pole.n.07') Synset('military_position.n.01') 0.7692307692307693
# Synset('pole.n.07') Synset('position.n.03') 0.14285714285714285
# Synset('pole.n.07') Synset('position.n.04') 0.15384615384615385
# Synset('pole.n.07') Synset('status.n.01') 0.16666666666666666
# Synset('pole.n.07') Synset('position.n.06') 0.13333333333333333
# Synset('pole.n.07') Synset('position.n.07') 0.18181818181818182
# Synset('pole.n.07') Synset('position.n.08') 0.7692307692307693
# Synset('pole.n.07') Synset('position.n.09') 0.13333333333333333
# Synset('pole.n.07') Synset('placement.n.03') 0.14285714285714285
# Synset('pole.n.07') Synset('situation.n.02') 0.15384615384615385
# Synset('pole.n.07') Synset('position.n.12') 0.15384615384615385
# Synset('pole.n.07') Synset('side.n.10') 0.15384615384615385
# Synset('pole.n.07') Synset('place.n.15') 0.15384615384615385
# Synset('pole.n.07') Synset('stead.n.01') 0.11764705882352941
# Synset('pole.n.07') Synset('position.n.16') 0.14285714285714285
# Synset('terminal.n.02') Synset('position.n.01') 0.375
# Synset('terminal.n.02') Synset('military_position.n.01') 0.375
# Synset('terminal.n.02') Synset('position.n.03') 0.11764705882352941
# Synset('terminal.n.02') Synset('position.n.04') 0.125
# Synset('terminal.n.02') Synset('status.n.01') 0.13333333333333333
# Synset('terminal.n.02') Synset('position.n.06') 0.1111111111111111
# Synset('terminal.n.02') Synset('position.n.07') 0.14285714285714285
# Synset('terminal.n.02') Synset('position.n.08') 0.375
# Synset('terminal.n.02') Synset('position.n.09') 0.1111111111111111
# Synset('terminal.n.02') Synset('placement.n.03') 0.11764705882352941
# Synset('terminal.n.02') Synset('situation.n.02') 0.125
# Synset('terminal.n.02') Synset('position.n.12') 0.125
# Synset('terminal.n.02') Synset('side.n.10') 0.125
# Synset('terminal.n.02') Synset('place.n.15') 0.125
# Synset('terminal.n.02') Synset('stead.n.01') 0.1
# Synset('terminal.n.02') Synset('position.n.16') 0.11764705882352941
# Synset('pole.n.09') Synset('position.n.01') 0.4
# Synset('pole.n.09') Synset('military_position.n.01') 0.4
# Synset('pole.n.09') Synset('position.n.03') 0.125
# Synset('pole.n.09') Synset('position.n.04') 0.13333333333333333
# Synset('pole.n.09') Synset('status.n.01') 0.14285714285714285
# Synset('pole.n.09') Synset('position.n.06') 0.11764705882352941
# Synset('pole.n.09') Synset('position.n.07') 0.15384615384615385
# Synset('pole.n.09') Synset('position.n.08') 0.4
# Synset('pole.n.09') Synset('position.n.09') 0.11764705882352941
# Synset('pole.n.09') Synset('placement.n.03') 0.125
# Synset('pole.n.09') Synset('situation.n.02') 0.13333333333333333
# Synset('pole.n.09') Synset('position.n.12') 0.13333333333333333
# Synset('pole.n.09') Synset('side.n.10') 0.13333333333333333
# Synset('pole.n.09') Synset('place.n.15') 0.13333333333333333
# Synset('pole.n.09') Synset('stead.n.01') 0.10526315789473684
# Synset('pole.n.09') Synset('position.n.16') 0.125
# Synset('pole.n.10') Synset('position.n.01') 0.5714285714285714
# Synset('pole.n.10') Synset('military_position.n.01') 0.5714285714285714
# Synset('pole.n.10') Synset('position.n.03') 0.13333333333333333
# Synset('pole.n.10') Synset('position.n.04') 0.14285714285714285
# Synset('pole.n.10') Synset('status.n.01') 0.15384615384615385
# Synset('pole.n.10') Synset('position.n.06') 0.125
# Synset('pole.n.10') Synset('position.n.07') 0.16666666666666666
# Synset('pole.n.10') Synset('position.n.08') 0.5714285714285714
# Synset('pole.n.10') Synset('position.n.09') 0.125
# Synset('pole.n.10') Synset('placement.n.03') 0.13333333333333333
# Synset('pole.n.10') Synset('situation.n.02') 0.14285714285714285
# Synset('pole.n.10') Synset('position.n.12') 0.14285714285714285
# Synset('pole.n.10') Synset('side.n.10') 0.14285714285714285
# Synset('pole.n.10') Synset('place.n.15') 0.14285714285714285
# Synset('pole.n.10') Synset('stead.n.01') 0.1111111111111111
# Synset('pole.n.10') Synset('position.n.16') 0.13333333333333333

# %%
maxscore,sem1,sem2
# Out:
# (0.7692307692307693,
#  [Synset('pole.n.01'),
#   Synset('pole.n.02'),
#   Synset('pole.n.03'),
#   Synset('perch.n.02'),
#   Synset('perch.n.03'),
#   Synset('pole.n.06'),
#   Synset('pole.n.07'),
#   Synset('terminal.n.02'),
#   Synset('pole.n.09'),
#   Synset('pole.n.10')],
#  [Synset('position.n.01'),
#   Synset('military_position.n.01'),
#   Synset('position.n.03'),
#   Synset('position.n.04'),
#   Synset('status.n.01'),
#   Synset('position.n.06'),
#   Synset('position.n.07'),
#   Synset('position.n.08'),
#   Synset('position.n.09'),
#   Synset('placement.n.03'),
#   Synset('situation.n.02'),
#   Synset('position.n.12'),
#   Synset('side.n.10'),
#   Synset('place.n.15'),
#   Synset('stead.n.01'),
#   Synset('position.n.16')])

# %%
d={}
for i in all_schemas:
    for j in all_schemas[i]["schema"]:
        x=j.lower()
        if x in d:
            d[x]+=1
        else:
            d[x]=1

# %%
d1=sorted(d.items(), key=lambda x: x[1], reverse=True)

# %%
d1
# Out:
# [('year', 395),
#  ('date', 367),
#  ('notes', 274),
#  ('name', 261),
#  ('rank', 199),
#  ('opponent', 161),
#  ('position', 146),
#  ('location', 142),
#  ('venue', 134),
#  ('title', 125),
#  ('num', 120),
#  ('team', 118),
#  ('result', 112),
#  ('total', 110),
#  ('attendance', 108),
#  ('competition', 108),
#  ('time', 95),
#  ('nation', 86),
#  ('country', 85),
#  ('points', 85),
#  ('player', 82),
#  ('gold', 78),
#  ('silver', 78),
#  ('bronze', 78),
#  ('score', 77),
#  ('season', 70),
#  ('nationality', 67),
#  ('no ', 64),
#  ('event', 61),
#  ('type', 58),
#  ('place', 56),
#  ('winner', 55),
#  ('round', 54),
#  ('pos', 54),
#  ('party', 53),
#  ('driver', 52),
#  ('no', 51),
#  ('role', 49),
#  ('laps', 47),
#  ('city', 45),
#  ('unnamed: 0', 45),
#  ('week', 40),
#  ('album', 39),
#  ('division', 39),
#  ('time/retired', 38),
#  ('grid', 38),
#  ('tournament', 38),
#  ('site', 37),
#  ('club', 35),
#  ('record', 35),
#  ('number', 33),
#  ('film', 31),
#  ('athlete', 31),
#  ('constructor', 28),
#  ('surface', 28),
#  ('pos ', 27),
#  ('age', 25),
#  ('county', 25),
#  ('length', 25),
#  ('area (km2)', 24),
#  ('outcome', 24),
#  ('opponentnum', 24),
#  ('district', 23),
#  ('population', 23),
#  ('league', 23),
#  ('state', 22),
#  ('ranknum', 22),
#  ('scorers', 22),
#  ('class', 21),
#  ('votes', 21),
#  ('height', 21),
#  ('wins', 21),
#  ('tv', 21),
#  ('percentage', 20),
#  ('from', 20),
#  ('rider', 20),
#  ('award', 19),
#  ('category', 19),
#  ('description', 19),
#  ('month', 18),
#  ('model', 18),
#  ('language', 18),
#  ('runners up', 18),
#  ('engine', 18),
#  ('goals', 18),
#  ('home team', 18),
#  ('status', 17),
#  ('game', 17),
#  ('report', 17),
#  ('builder', 17),
#  ('label', 16),
#  ('artist', 16),
#  ('capacity', 16),
#  ('car', 16),
#  ('playoffs', 16),
#  ('region', 15),
#  ('played', 15),
#  ('series', 15),
#  ('2011', 15),
#  ('chassis', 15),
#  ('song', 15),
#  ('runner up', 15),
#  ('manufacturer', 15),
#  ('college', 15),
#  ('2007', 15),
#  ('2009', 15),
#  ('opponents', 15),
#  ('hometown', 15),
#  ('jan', 14),
#  ('feb', 14),
#  ('mar', 14),
#  ('apr', 14),
#  ('may', 14),
#  ('jun', 14),
#  ('jul', 14),
#  ('aug', 14),
#  ('sep', 14),
#  ('oct', 14),
#  ('nov', 14),
#  ('dec', 14),
#  ('left office', 14),
#  ('fate', 14),
#  ('weight', 14),
#  ('tier', 14),
#  ('away team', 14),
#  ('2010', 14),
#  ('owner', 13),
#  ('single', 13),
#  ('finish', 13),
#  ('coordinates', 13),
#  ('won', 13),
#  ('lost', 13),
#  ('took office', 13),
#  ('circuit', 13),
#  ('winning team', 13),
#  ('2005', 13),
#  ('comments', 12),
#  ('format', 12),
#  ('coach', 12),
#  ('director', 12),
#  ('2006', 12),
#  ('network', 12),
#  ('producers', 12),
#  ('to par', 12),
#  ('pole position', 12),
#  ('games', 12),
#  ('2008', 12),
#  ('publisher', 11),
#  ('score 1', 11),
#  ('school', 11),
#  ('years', 11),
#  ('2004', 11),
#  ('stadium', 11),
#  ('genre', 11),
#  ('method', 10),
#  ('to', 10),
#  ('candidate', 10),
#  ('level', 10),
#  ('home', 10),
#  ('entrant', 10),
#  ('game site', 10),
#  ('win', 10),
#  ('founded', 10),
#  ('pick', 10),
#  ('note', 10),
#  ('representative', 10),
#  ('matches', 10),
#  ('pick num', 10),
#  ('bib', 10),
#  ('jockey', 9),
#  ('area', 9),
#  ('dates', 9),
#  ('drivers', 9),
#  ('2001', 9),
#  ('2002', 9),
#  ('third', 9),
#  ('performers', 9),
#  ('winners', 9),
#  ('save', 9),
#  ('nickname', 9),
#  ('losses', 9),
#  ('release date', 9),
#  ('draw', 9),
#  ('championship', 9),
#  ('2012', 9),
#  ('fastest lap', 9),
#  ('2003', 9),
#  ('money ($)', 9),
#  ('opposition', 9),
#  ('drawn', 8),
#  ('origin', 8),
#  ('year built', 8),
#  ('seats', 8),
#  ('institution', 8),
#  ('partner', 8),
#  ('sport', 8),
#  ('loss', 8),
#  ('visitor', 8),
#  ('province', 8),
#  ('winning driver', 8),
#  ('tie no', 8),
#  ('first elected', 8),
#  ('stage', 8),
#  ('original air date', 8),
#  ('launched', 8),
#  ('town', 8),
#  ('open cup', 8),
#  ('2000', 8),
#  ('loser', 8),
#  ('contestant', 8),
#  ('lane', 8),
#  ('peak chart positions uk', 7),
#  ('peak chart positions us', 7),
#  ('occupation', 7),
#  ('completed', 7),
#  ('ship', 7),
#  ('heat', 7),
#  ('member', 7),
#  ('+/ ', 7),
#  ('episodes', 7),
#  ('callsign', 7),
#  ('code', 7),
#  ('second', 7),
#  ('race name', 7),
#  ('floors', 7),
#  ('english title', 7),
#  ('enrollment', 7),
#  ("men's winner", 7),
#  ('races', 7),
#  ('date of birth', 7),
#  ('opponent in the final', 7),
#  ('average', 7),
#  ('year 1', 7),
#  ('release', 7),
#  ('directed by', 7),
#  ('written by', 7),
#  ('2013', 7),
#  ('head coach', 7),
#  ('team 1', 7),
#  ('team 2', 7),
#  ('incumbent', 7),
#  ('regular season', 7),
#  ('frequency', 6),
#  ('peak chart positions ger', 6),
#  ('remarks', 6),
#  ('in service', 6),
#  ('section', 6),
#  ('movements', 6),
#  ('municipality', 6),
#  ('established', 6),
#  ('total goals', 6),
#  ('operator', 6),
#  ('opponents in the final', 6),
#  ('rnd', 6),
#  ('results', 6),
#  ('ot', 6),
#  ('caps', 6),
#  ('goals for', 6),
#  ('goals against', 6),
#  ("women's winner", 6),
#  ('poles', 6),
#  ('margin of victory', 6),
#  ('losing team', 6),
#  ('goal', 6),
#  ('win percentage', 6),
#  ('nfl team', 6),
#  ('against', 6),
#  ('difference', 6),
#  ('race', 6),
#  ('premiere date', 6),
#  ('version', 6),
#  ('start', 6),
#  ('candidates', 6),
#  ('run 1', 6),
#  ('run 2', 6),
#  ('change', 6),
#  ('population (2011)', 6),
#  ('laid down', 6),
#  ('constituency', 6),
#  ('developer', 6),
#  ('episode', 6),
#  ('deficit', 6),
#  ('nominated work', 5),
#  ('call sign', 5),
#  ('city of license', 5),
#  ('trainer', 5),
#  ('w', 5),
#  ('l', 5),
#  ('peak chart positions aus', 5),
#  ('gross', 5),
#  ('character', 5),
#  ('other', 5),
#  ('source', 5),
#  ('third place', 5),
#  ('league apps', 5),
#  ('league goals', 5),
#  ('total apps', 5),
#  ('headquarters', 5),
#  ('opened', 5),
#  ('round 1', 5),
#  ('distance', 5),
#  ('name of place', 5),
#  ('principal county', 5),
#  ('music', 5),
#  ('champion', 5),
#  ('day', 5),
#  ('draws', 5),
#  ('goal difference', 5),
#  ('podiums', 5),
#  ('winning score', 5),
#  ('capital', 5),
#  ('airline', 5),
#  ('channel', 5),
#  ('conference', 5),
#  ('final', 5),
#  ('appointed by', 5),
#  ('group', 5),
#  ('finished', 5),
#  ('company', 5),
#  ('works number', 5),
#  ('year 2', 5),
#  ('route', 5),
#  ('terrain', 5),
#  ('edition', 5),
#  ('apps', 5),
#  ('others', 5),
#  ('years won', 5),
#  ('2014', 5),
#  ('power', 5),
#  ('township', 5),
#  ('fips', 5),
#  ('geographic coordinates', 5),
#  ('pts', 5),
#  ('votes 1', 5),
#  ('votes 2', 5),
#  ('date:', 5),
#  ('notes:', 5),
#  ('reign', 5),
#  ('1999', 5),
#  ('cup', 5),
#  ('manager', 5),
#  ('athletes', 5),
#  ('residence', 5),
#  ('fee', 5),
#  ('deaths', 4),
#  ('service', 4),
#  ('icao', 4),
#  ('iata', 4),
#  ('gf', 4),
#  ('ga', 4),
#  ('office', 4),
#  ('political party', 4),
#  ('population (2010 census)', 4),
#  ('link', 4),
#  ('peak chart positions us r&b', 4),
#  ('peak chart positions nz', 4),
#  ('livery', 4),
#  ('make', 4),
#  ('diameter', 4),
#  ('election', 4),
#  ('gb', 4),
#  ('chart', 4),
#  ('titles', 4),
#  ('formed', 4),
#  ('gender', 4),
#  ('wrestler', 4),
#  ('airport', 4),
#  ('chinese', 4),
#  ('show', 4),
#  ('composition', 4),
#  ('name 1', 4),
#  ('time 1', 4),
#  ('tv time', 4),
#  ('lower zip code', 4),
#  ('birth date', 4),
#  ('viewers', 4),
#  ('symbol', 4),
#  ('unnamed: 2', 4),
#  ('date of appointment', 4),
#  ('area km2', 4),
#  ('ranking', 4),
#  ('overall', 4),
#  ('margin', 4),
#  ('teams', 4),
#  ('land area (km2)', 4),
#  ('gauge', 4),
#  ('songwriters', 4),
#  ('for', 4),
#  ('president', 4),
#  ('entered service', 4),
#  ('withdrawn', 4),
#  ('community', 4),
#  ('reg season', 4),
#  ('comment', 4),
#  ('current status', 4),
#  ('qual', 4),
#  ('retired', 4),
#  ('no in series', 4),
#  ('no in season', 4),
#  ('production code', 4),
#  ('agg ', 4),
#  ('released', 4),
#  ('final points', 4),
#  ('co driver', 4),
#  ('medal', 4),
#  ('number of counties', 4),
#  ('lifetime', 4),
#  ('notable as', 4),
#  ('population center', 4),
#  ('population density /km2 (/sq mi)', 4),
#  ('land area km2 (sq mi)', 4),
#  ('water area km2 (sq mi)', 4),
#  ('water percentage', 4),
#  ('us hot 100', 4),
#  ('sub divisions', 4),
#  ('place, theatre', 4),
#  ('assists', 4),
#  ('home/away', 4),
#  ('college/junior/club team', 4),
#  ('high school', 4),
#  ('host', 4),
#  ('elevation', 4),
#  ('match', 4),
#  ('names', 4),
#  ('1995', 4),
#  ('1996', 4),
#  ('1997', 4),
#  ('cyclist', 4),
#  ('performer', 4),
#  ('air date', 4),
#  ('wrestler:', 4),
#  ('res ', 4),
#  ('discipline', 4),
#  ('kickoff', 4),
#  ('fa cup', 4),
#  ('wrestlers', 4),
#  ('days held', 4),
#  ('h / a', 4),
#  ('seasons', 4),
#  ('artists', 4),
#  ('league cup', 4),
#  ('total votes', 4),
#  ('density', 3),
#  ('carries', 3),
#  ('summary', 3),
#  ('studio', 3),
#  ('actors', 3),
#  ('points for', 3),
#  ('points against', 3),
#  ('prime minister', 3),
#  ('passengers', 3),
#  ('duration', 3),
#  ('n', 3),
#  ('tonnage', 3),
#  ('material', 3),
#  ('latitude', 3),
#  ('longitude', 3),
#  ('period', 3),
#  ('affiliation', 3),
#  ('date opened', 3),
#  ('catalog', 3),
#  ('parish', 3),
#  ('church name', 3),
#  ('ethnicity', 3),
#  ('1992', 3),
#  ('gp', 3),
#  ('name on the register', 3),
#  ('date listed', 3),
#  ('pct', 3),
#  ('fourth place', 3),
#  ('via', 3),
#  ('average population (x 1000)', 3),
#  ('live births', 3),
#  ('natural change', 3),
#  ('crude birth rate (per 1000)', 3),
#  ('crude death rate (per 1000)', 3),
#  ('natural change (per 1000)', 3),
#  ('hanzi', 3),
#  ('density (/km2)', 3),
#  ('pl/mi percentage', 3),
#  ('team num1', 3),
#  ('team num2', 3),
#  ('tyres', 3),
#  ('fa cup apps', 3),
#  ('fa cup goals', 3),
#  ('album details', 3),
#  ('no of reigns', 3),
#  ('combined days', 3),
#  ('sales', 3),
#  ('captain', 3),
#  ('long', 3),
#  ('value', 3),
#  ('performance', 3),
#  ('aircraft', 3),
#  ('street address', 3),
#  ('height ft (m)', 3),
#  ('introduced', 3),
#  ('bike', 3),
#  ('f/laps', 3),
#  ('hungarians', 3),
#  ('unnamed: 4', 3),
#  ('date of death', 3),
#  ('slalom', 3),
#  ('giant slalom', 3),
#  ('super g', 3),
#  ('downhill', 3),
#  ('combined', 3),
#  ('co star', 3),
#  ('winning team 1', 3),
#  ('losing team 1', 3),
#  ('color', 3),
#  ('champions', 3),
#  ('termination of mission', 3),
#  ('closed', 3),
#  ('pages', 3),
#  ('goals scored', 3),
#  ('high points', 3),
#  ('high rebounds', 3),
#  ('high assists', 3),
#  ('location attendance', 3),
#  ('chinese title', 3),
#  ('counties represented', 3),
#  ('song title', 3),
#  ('apparent magnitude', 3),
#  ('combined tackles', 3),
#  ('tackles', 3),
#  ('assisted tackles', 3),
#  ('sacks', 3),
#  ('forced fumbles', 3),
#  ('fumble recoveries', 3),
#  ('fumble return yards', 3),
#  ('interceptions', 3),
#  ('interception return yards', 3),
#  ('yards per interception return', 3),
#  ('longest interception return', 3),
#  ('interceptions returned for touchdown', 3),
#  ('passes defended', 3),
#  ('co drivers', 3),
#  ('class pos ', 3),
#  ('years active', 3),
#  ('volume', 3),
#  ('aggregate', 3),
#  ('serial no', 3),
#  ('handheld', 3),
#  ('rating', 3),
#  ('yacht', 3),
#  ('school/club team', 3),
#  ('crowd', 3),
#  ('college/junior/club team (league)', 3),
#  ('pennant', 3),
#  ('employees', 3),
#  ('destinations', 3),
#  ('led', 3),
#  ('appearance', 3),
#  ('meet', 3),
#  ('designation', 3),
#  ('commissioned', 3),
#  ('diver', 3),
#  ('preliminary points', 3),
#  ('preliminary rank', 3),
#  ('cast', 3),
#  ('author', 3),
#  ('launch date', 3),
#  ('school name', 3),
#  ('successor', 3),
#  ('tyre', 3),
#  ('rounds', 3),
#  ('rd ', 3),
#  ('starting price', 3),
#  ('standard', 3),
#  ('subject', 3),
#  ('libretto', 3),
#  ('mark', 3),
#  ('unnamed: 5', 3),
#  ('games played', 3),
#  ('rebounds', 3),
#  ('built', 3),
#  ('platforms', 3),
#  ('times:', 3),
#  ('location:', 3),
#  ('nhl team', 3),
#  ('tenure', 3),
#  ('partnering', 3),
#  ('yards', 3),
#  ('area served', 3),
#  ('created', 3),
#  ('poll source', 3),
#  ('sample size', 3),
#  ('margin of error', 3),
#  ('home ground', 3),
#  ('opponent team', 3),
#  ('quantity', 3),
#  ('election year', 3),
#  ('size', 3),
#  ('image', 3),
#  ('eliminated', 3),
#  ('1993', 3),
#  ('1998', 3),
#  ('common name', 3),
#  ('speed', 3),
#  ('episode title', 3),
#  ('final rank', 3),
#  ('time (h:m:s)', 3),
#  ('time (h:m:s) 1', 3),
#  ('represent', 3),
#  ('1991', 3),
#  ('males', 3),
#  ('females', 3),
#  ('undecided', 3),
#  ('weight (lbs )', 3),
#  ('dimensions', 3),
#  ('track', 3),
#  ('rf', 3),
#  ('balls', 3),
#  ('inns ', 3),
#  ('opposing team', 3),
#  ('wager', 3),
#  ('laps led', 3),
#  ('network name', 3),
#  ('flagship', 3),
#  ('programming type', 3),
#  ('affiliates', 3),
#  ('features', 3),
#  ('score in the final', 3),
#  ('uk', 3),
#  ('km', 3),
#  ('train', 3),
#  ('jurisdiction', 3),
#  ('destination', 3),
#  ('behind', 3),
#  ('rank 1', 3),
#  ('rank 2', 3),
#  ('alma mater', 3),
#  ('final score', 3),
#  ('chart positions uk', 2),
#  ('chart positions us', 2),
#  ('chart positions nl', 2),
#  ('nominee', 2),
#  ('act', 2),
#  ('peak chart positions us main', 2),
#  ('peak chart positions us dance', 2),
#  ('airport name', 2),
#  ('usage', 2),
#  ('active voters', 2),
#  ('inactive voters', 2),
#  ('total voters', 2),
#  ('t', 2),
#  ('seat', 2),
#  ('p', 2),
#  ('gd', 2),
#  ('pts ', 2),
#  ('term start', 2),
#  ('term end', 2),
#  ('peak chart positions aut', 2),
#  ('peak chart positions fin', 2),
#  ('peak chart positions ned', 2),
#  ('peak chart positions swe', 2),
#  ('peak chart positions sui', 2),
#  ('landmark name', 2),
#  ('members', 2),
#  ('original airdate', 2),
#  ('leader', 2),
#  ('picture', 2),
#  ('peak chart positions nld', 2),
#  ('certifications', 2),
#  ('peak chart positions swi', 2),
#  ('film title', 2),
#  ('governorate', 2),
#  ('writer', 2),
#  ('incpercentage', 2),
#  ('function', 2),
#  ('sentence', 2),
#  ('primary sponsors', 2),
#  ('listed owners', 2),
#  ('crew chief', 2),
#  ('number 1', 2),
#  ('number 2', 2),
#  ('live births per year', 2),
#  ('deaths per year', 2),
#  ('natural change per year', 2),
#  ('m', 2),
#  ('station', 2),
#  ('city/ neighborhood', 2),
#  ('year opened', 2),
#  ('1880', 2),
#  ('1956', 2),
#  ('start date', 2),
#  ('gap', 2),
#  ('date and time', 2),
#  ('foundation', 2),
#  ('regular season won', 2),
#  ('regular season lost', 2),
#  ('regular season win percentage', 2),
#  ('regular season finish', 2),
#  ('population (2001 census)', 2),
#  ('density (per km2)', 2),
#  ('literacy (percentage)', 2),
#  ('sex ratio', 2),
#  ('route number', 2),
#  ('hanyu pinyin', 2),
#  ('accolade', 2),
#  ('1960', 2),
#  ('passengers handled', 2),
#  ('skip', 2),
#  ('lead', 2),
#  ('postseason result', 2),
#  ('placing', 2),
#  ('time 2', 2),
#  ('olympics', 2),
#  ('notes/events', 2),
#  ('kilometers', 2),
#  ('intersecting routes', 2),
#  ('organization', 2),
#  ('total passengers', 2),
#  ('counties', 2),
#  ('current club', 2),
#  ('lyrics', 2),
#  ('color commentators', 2),
#  ('ratings', 2),
#  ('winning years', 2),
#  ('glyph', 2),
#  ('unicode', 2),
#  ('car num', 2),
#  ('japanese title', 2),
#  ('joined', 2),
#  ('sr no ', 2),
#  ('island', 2),
#  ('association', 2),
#  ('tonnage (grt)', 2),
#  ('outgoing manager', 2),
#  ('manner of departure', 2),
#  ('date of vacancy', 2),
#  ('replaced by', 2),
#  ('position in table', 2),
#  ('area sq mi', 2),
#  ('div ', 2),
#  ('serbs', 2),
#  ('romanians', 2),
#  ('ceremony', 2),
#  ('surname', 2),
#  ('full name', 2),
#  ('hosts', 2),
#  ('weekend end date', 2),
#  ('city/location', 2),
#  ('presentation of credentials', 2),
#  ('ship name', 2),
#  ('seed', 2),
#  ('final opponent', 2),
#  ('displacement', 2),
#  ('total wins', 2),
#  ('money list rank', 2),
#  ('banner', 2),
#  ('area acres', 2),
#  ('electorate', 2),
#  ('block', 2),
#  ('innings', 2),
#  ('runs', 2),
#  ('100s', 2),
#  ('50s', 2),
#  ('leg', 2),
#  ('moving from', 2),
#  ('league 1', 2),
#  ('lose', 2),
#  ('r a (j2000)', 2),
#  ('dec (j2000)', 2),
#  ('redshift (km/s)', 2),
#  ('production', 2),
#  ('rd', 2),
#  ('fuel', 2),
#  ('singers', 2),
#  ('japanese', 2),
#  ('connections', 2),
#  ('decision', 2),
#  ('odds', 2),
#  ('prize money', 2),
#  ('national cup', 2),
#  ('state/country', 2),
#  ('skipper', 2),
#  ('finalists', 2),
#  ('number of contestants', 2),
#  ('remixed by', 2),
#  ('references', 2),
#  ('equipment', 2),
#  ('nations', 2),
#  ('born', 2),
#  ('goals conceded', 2),
#  ('extra', 2),
#  ('europe', 2),
#  ('november', 2),
#  ('services', 2),
#  ('international caps', 2),
#  ('original name', 2),
#  ('party leaders', 2),
#  ('term of office', 2),
#  ('first downs', 2),
#  ('chord', 2),
#  ('root', 2),
#  ('perfect fifth', 2),
#  ('kit manufacturer', 2),
#  ('shirt sponsor', 2),
#  ('year of election', 2),
#  ('pole', 2),
#  ('synopsis', 2),
#  ('tries', 2),
#  ('1st leg', 2),
#  ('2nd leg', 2),
#  ('featured guests', 2),
#  ('urban area', 2),
#  ('administrative area', 2),
#  ('formula', 2),
#  ('casualties', 2),
#  ('details', 2),
#  ('low grade', 2),
#  ('high grade', 2),
#  ('vacator', 2),
#  ('reason for change', 2),
#  ('festival', 2),
#  ('awards', 2),
#  ('term expires', 2),
#  ('grand prix', 2),
#  ('altitude (mslm)', 2),
#  ('rnd ', 2),
#  ('conf ', 2),
#  ('until', 2),
#  ('city or town', 2),
#  ('winnings', 2),
#  ('polling firm', 2),
#  ('republican', 2),
#  ('wind', 2),
#  ('auto', 2),
#  ('transfer fee ( million)', 2),
#  ('box office', 2),
#  ('recipient', 2),
#  ('profession', 2),
#  ('opening date', 2),
#  ('closing date', 2),
#  ('overall record', 2),
#  ('name 2', 2),
#  ('title (latin)', 2),
#  ('title (english translation)', 2),
#  ('system', 2),
#  ('swing', 2),
#  ("men's team", 2),
#  ("women's team", 2),
#  ('website', 2),
#  ('position 1', 2),
#  ('population density (/km2)', 2),
#  ('chart position', 2),
#  ('visiting team', 2),
#  ('swimsuit', 2),
#  ('interview', 2),
#  ('evening gown', 2),
#  ('points per game', 2),
#  ('rebounds per game', 2),
#  ('assists per game', 2),
#  ('minutes played', 2),
#  ('steals', 2),
#  ('flight', 2),
#  ('meaning', 2),
#  ('events', 2),
#  ('order', 2),
#  ('president served under', 2),
#  ('high', 2),
#  ('low', 2),
#  ('judge', 2),
#  ('reason for termination', 2),
#  ('hand', 2),
#  ('postal code', 2),
#  ('country of origin', 2),
#  ('pct ', 2),
#  ('course', 2),
#  ('purpose', 2),
#  ('delivery', 2),
#  ('mountain peak', 2),
#  ('prominence', 2),
#  ('isolation', 2),
#  ('platform', 2),
#  ('wheel arrangement', 2),
#  ('brazil scorers', 2),
#  ('licensee', 2),
#  ('locomotive', 2),
#  ('peak chart positions us mod', 2),
#  ('combined defenses', 2),
#  ('speed (km/h)', 2),
#  ('num of constituency votes', 2),
#  ('num of party list votes', 2),
#  ('percentage of party list votes', 2),
#  ('num of overall seats won', 2),
#  ('date of award', 2),
#  ('stations', 2),
#  ('uk singles', 2),
#  ('postseason', 2),
#  ('1994', 2),
#  ('career sr', 2),
#  ('metropolitan area', 2),
#  ('percentage of votes', 2),
#  ('album title', 2),
#  ('building', 2),
#  ('reactor type', 2),
#  ('net capacity (mwe)', 2),
#  ('gross capacity (mwe)', 2),
#  ('represented', 2),
#  ('publication', 2),
#  ('model name', 2),
#  ('1989', 2),
#  ('date from', 2),
#  ('reigns:', 2),
#  ('place:', 2),
#  ('cause', 2),
#  ('denomination', 2),
#  ('percentage (percentage)', 2),
#  ('unnamed: 6', 2),
#  ('unnamed: 10', 2),
#  ('purse ($)', 2),
#  ('majority', 2),
#  ('race distance laps', 2),
#  ('race distance miles (km)', 2),
#  ('race time', 2),
#  ('average speed (mph)', 2),
#  ('ecclesiastical jurisdictions', 2),
#  ('latin name', 2),
#  ('rite', 2),
#  ('ecclesiastical province', 2),
#  ('cylinders', 2),
#  ('vc', 2),
#  ('setting', 2),
#  ('horse', 2),
#  ('time / behind', 2),
#  ('ref', 2),
#  ('home city', 2),
#  ('districts', 2),
#  ('term ended', 2),
#  ('time behind', 2),
#  ('official name', 2),
#  ('race 1 time', 2),
#  ('race 2 time', 2),
#  ('total time', 2),
#  ('total rank', 2),
#  ('versions', 2),
#  ('2 15', 2),
#  ('2015', 2),
#  ('new points', 2),
#  ('years runner up', 2),
#  ('pair', 2),
#  ('semifinalists', 2),
#  ('units', 2),
#  ('genres', 2),
#  ('various', 2),
#  ('namesake', 2),
#  ('date established', 2),
#  ('party affiliation', 2),
#  ('number of votes', 2),
#  ('winning rider', 2),
#  ('constituency number', 2),
#  ('scored', 2),
#  ('event year', 2),
#  ('flag bearer', 2),
#  ('opus', 2),
#  ('links', 2),
#  ('free throws', 2),
#  ('operation', 2),
#  ('avg attendance', 2),
#  ('winpercentage', 2),
#  ('date/time', 2),
#  ('foe', 2),
#  ('species', 2),
#  ('airdate', 2),
#  ('hangul', 2),
#  ('population (2005)', 2),
#  ('population (2009)', 2),
#  ('share', 2),
#  ('run 3', 2),
#  ('run 4', 2),
#  ('work', 2),
#  ('uci rating', 2),
#  ('listing date', 2),
#  ('population (2006)', 2),
#  ('ordered', 2),
#  ('tour', 2),
#  ('official title', 2),
#  ('date start', 2),
#  ('date finish', 2),
#  ('prize money usd', 2),
#  ('h/a', 2),
#  ('ties', 2),
#  ('county 1', 2),
#  ('date built', 2),
#  ('works no ', 2),
#  ('birthdate', 2),
#  ('birthplace', 2),
#  ('distance (miles)', 2),
#  ('theme', 2),
#  ('song choice', 2),
#  ('original artist', 2),
#  ('tally', 2),
#  ('other information', 2),
#  ('deductions', 2),
#  ('fence', 2),
#  ('handicap (st lb)', 2),
#  ('prominence (m)', 2),
#  ...]

# %%
def generate_column_knowledge_graph():
    column_k_graph={}
    for fname in all_schemas:
        for col,dtype in all_schemas[fname]["schema"].items():
            if col not in column_k_graph:
                column_k_graph[col]={"direct":[fname],"similar":{},"d_type":dtype}
            else:
                column_k_graph[col]["direct"].append(fname)
    return column_k_graph

col_k_graph=generate_column_knowledge_graph()

# %%
len(col_k_graph["date of appointment"]["direct"])
# Out:
# 4

# %%
no_of_tables_with_col={}
for i,j in d1:
    if j in no_of_tables_with_col:
        no_of_tables_with_col[j]+=1
    else:
        no_of_tables_with_col[j]=1

# %%
y=sorted(no_of_tables_with_col.items())
print(y)
# Out:
# [(1, 2961), (2, 392), (3, 192), (4, 98), (5, 62), (6, 40), (7, 31), (8, 22), (9, 20), (10, 15), (11, 7), (12, 11), (13, 10), (14, 18), (15, 13), (16, 5), (17, 4), (18, 7), (19, 3), (20, 3), (21, 5), (22, 3), (23, 3), (24, 3), (25, 3), (27, 1), (28, 2), (31, 2), (33, 1), (35, 2), (37, 1), (38, 3), (39, 2), (40, 1), (45, 2), (47, 1), (49, 1), (51, 1), (52, 1), (53, 1), (54, 2), (55, 1), (56, 1), (58, 1), (61, 1), (64, 1), (67, 1), (70, 1), (77, 1), (78, 3), (82, 1), (85, 2), (86, 1), (95, 1), (108, 2), (110, 1), (112, 1), (118, 1), (120, 1), (125, 1), (134, 1), (142, 1), (146, 1), (161, 1), (199, 1), (261, 1), (274, 1), (367, 1), (395, 1)]

# %%
print("With Direct Column Name Match :\n")
for i,j in y:
    print(j," columns are present ",i," times.")
# Out:
# With Direct Column Name Match :
#
# 2961  columns are present  1  times.
# 392  columns are present  2  times.
# 192  columns are present  3  times.
# 98  columns are present  4  times.
# 62  columns are present  5  times.
# 40  columns are present  6  times.
# 31  columns are present  7  times.
# 22  columns are present  8  times.
# 20  columns are present  9  times.
# 15  columns are present  10  times.
# 7  columns are present  11  times.
# 11  columns are present  12  times.
# 10  columns are present  13  times.
# 18  columns are present  14  times.
# 13  columns are present  15  times.
# 5  columns are present  16  times.
# 4  columns are present  17  times.
# 7  columns are present  18  times.
# 3  columns are present  19  times.
# 3  columns are present  20  times.
# 5  columns are present  21  times.
# 3  columns are present  22  times.
# 3  columns are present  23  times.
# 3  columns are present  24  times.
# 3  columns are present  25  times.
# 1  columns are present  27  times.
# 2  columns are present  28  times.
# 2  columns are present  31  times.
# 1  columns are present  33  times.
# 2  columns are present  35  times.
# 1  columns are present  37  times.
# 3  columns are present  38  times.
# 2  columns are present  39  times.
# 1  columns are present  40  times.
# 2  columns are present  45  times.
# 1  columns are present  47  times.
# 1  columns are present  49  times.
# 1  columns are present  51  times.
# 1  columns are present  52  times.
# 1  columns are present  53  times.
# 2  columns are present  54  times.
# 1  columns are present  55  times.
# 1  columns are present  56  times.
# 1  columns are present  58  times.
# 1  columns are present  61  times.
# 1  columns are present  64  times.
# 1  columns are present  67  times.
# 1  columns are present  70  times.
# 1  columns are present  77  times.
# 3  columns are present  78  times.
# 1  columns are present  82  times.
# 2  columns are present  85  times.
# 1  columns are present  86  times.
# 1  columns are present  95  times.
# 2  columns are present  108  times.
# 1  columns are present  110  times.
# 1  columns are present  112  times.
# 1  columns are present  118  times.
# 1  columns are present  120  times.
# 1  columns are present  125  times.
# 1  columns are present  134  times.
# 1  columns are present  142  times.
# 1  columns are present  146  times.
# 1  columns are present  161  times.
# 1  columns are present  199  times.
# 1  columns are present  261  times.
# 1  columns are present  274  times.
# 1  columns are present  367  times.
# 1  columns are present  395  times.

# %%
for i,j in col_k_graph.items():
    print(i)
    print(j)
# Out:
# year
# {'direct': ['200_0.csv', '200_1.csv', '200_10.csv', '200_12.csv', '200_22.csv', '200_3.csv', '200_30.csv', '200_32.csv', '200_36.csv', '200_42.csv', '200_46.csv', '200_48.csv', '201_0.csv', '201_15.csv', '201_21.csv', '201_22.csv', '201_23.csv', '201_28.csv', '201_3.csv', '201_30.csv', '201_33.csv', '201_34.csv', '201_36.csv', '201_37.csv', '201_4.csv', '201_40.csv', '201_42.csv', '201_44.csv', '201_45.csv', '201_48.csv', '201_49.csv', '201_6.csv', '201_7.csv', '201_9.csv', '202_11.csv', '202_110.csv', '202_114.csv', '202_13.csv', '202_135.csv', '202_137.csv', '202_15.csv', '202_167.csv', '202_178.csv', '202_184.csv', '202_195.csv', '202_197.csv', '202_198.csv', '202_200.csv', '202_205.csv', '202_211.csv', '202_218.csv', '202_219.csv', '202_228.csv', '202_241.csv', '202_242.csv', '202_248.csv', '202_257.csv', '202_278.csv', '202_279.csv', '202_28.csv', '202_283.csv', '202_29.csv', '202_290.csv', '202_294.csv', '202_31.csv', '202_32.csv', '202_38.csv', '202_43.csv', '202_57.csv', '202_63.csv', '202_64.csv', '202_65.csv', '202_67.csv', '202_7.csv', '202_72.csv', '202_74.csv', '202_83.csv', '202_99.csv', '203_111.csv', '203_122.csv', '203_124.csv', '203_13.csv', '203_133.csv', '203_136.csv', '203_146.csv', '203_15.csv', '203_157.csv', '203_163.csv', '203_17.csv', '203_174.csv', '203_18.csv', '203_189.csv', '203_191.csv', '203_192.csv', '203_199.csv', '203_20.csv', '203_203.csv', '203_204.csv', '203_205.csv', '203_215.csv', '203_217.csv', '203_225.csv', '203_23.csv', '203_238.csv', '203_239.csv', '203_245.csv', '203_248.csv', '203_258.csv', '203_259.csv', '203_26.csv', '203_262.csv', '203_270.csv', '203_28.csv', '203_284.csv', '203_285.csv', '203_289.csv', '203_299.csv', '203_300.csv', '203_304.csv', '203_325.csv', '203_337.csv', '203_339.csv', '203_355.csv', '203_359.csv', '203_364.csv', '203_367.csv', '203_370.csv', '203_390.csv', '203_393.csv', '203_395.csv', '203_396.cs
# {'direct': ['200_22.csv', '201_0.csv', '201_15.csv', '201_40.csv', '202_219.csv', '202_257.csv', '202_278.csv', '202_72.csv', '203_619.csv', '203_661.csv', '203_696.csv', '203_877.csv', '204_365.csv'], 'similar': {}, 'd_type': 'object'}
# peak chart positions ger
# {'direct': ['200_22.csv', '201_0.csv', '201_48.csv', '202_241.csv', '202_278.csv', '204_471.csv'], 'similar': {}, 'd_type': 'float64'}
# peak chart positions ire
# {'direct': ['200_22.csv'], 'similar': {}, 'd_type': 'float64'}
# peak chart positions uk
# {'direct': ['200_22.csv', '201_40.csv', '201_48.csv', '202_241.csv', '202_278.csv', '203_426.csv', '203_661.csv'], 'similar': {}, 'd_type': 'float64'}
# peak chart positions us
# {'direct': ['200_22.csv', '201_40.csv', '201_48.csv', '202_241.csv', '203_137.csv', '204_394.csv', '204_500.csv'], 'similar': {}, 'd_type': 'float64'}
# peak chart positions us main
# {'direct': ['200_22.csv', '203_751.csv'], 'similar': {}, 'd_type': 'float64'}
# peak chart positions us dance
# {'direct': ['200_22.csv', '202_241.csv'], 'similar': {}, 'd_type': 'float64'}
# album
# {'direct': ['200_22.csv', '201_0.csv', '201_15.csv', '201_40.csv', '201_48.csv', '202_184.csv', '202_251.csv', '202_278.csv', '203_124.csv', '203_426.csv', '203_454.csv', '203_491.csv', '203_512.csv', '203_619.csv', '203_628.csv', '203_629.csv', '203_661.csv', '203_686.csv', '203_696.csv', '203_723.csv', '203_751.csv', '204_193.csv', '204_243.csv', '204_244.csv', '204_365.csv', '204_394.csv', '204_500.csv', '204_529.csv', '204_56.csv', '204_643.csv', '204_654.csv', '204_655.csv', '204_689.csv', '204_804.csv', '204_817.csv', '204_895.csv', '204_927.csv', '204_928.csv', '204_949.csv'], 'similar': {}, 'd_type': 'object'}
# film
# {'direct': ['200_24.csv', '200_36.csv', '201_34.csv', '202_11.csv', '202_137.csv', '202_248.csv', '202_74.csv', '203_157.csv', '203_17.csv', '203_174.csv', '203_18.csv', '203_180.csv', '203_204.csv', '203_393.csv', '203_451.csv', '203_463.csv', '203_641.csv', '203_709.csv', '203_762.csv', '203_79.csv', '203_85.csv', '204_323.csv', '204_377.csv', '204_546.csv', '204_57.csv', '204_573.csv', '204_647.csv', '204_7.csv', '204_723.csv', '204_852.csv', '204_948.csv'], 'similar': {}, 'd_type': 'object'}
# film 1
# {'direct': ['200_24.csv'], 'similar': {}, 'd_type': 'object'}
# service
# {'direct': ['200_25.csv', '203_326.csv', '203_603.csv', '203_71.csv'], 'similar': {}, 'd_type': 'object'}
# 2012/13 total cost (million)
# {'direct': ['200_25.csv'], 'similar': {}, 'd_type': 'float64'}
# comparison with 2011/12 (million)
# {'direct': ['200_25.csv'], 'similar': {}, 'd_type': 'object'}
# city served / location
# {'direct': ['200_26.csv'], 'similar': {}, 'd_type': 'object'}
# icao
# {'direct': ['200_26.csv', '203_58.csv', '204_163.csv', '204_49.csv'], 'similar': {}, 'd_type': 'object'}
# iata
# {'direct': ['200_26.csv', '203_58.csv', '204_163.csv', '204_49.csv'], 'similar': {}, 'd_type': 'object'}
# airport name
# {'direct': ['200_26.csv', '204_139.csv'], 'similar': {}, 'd_type': 'object'}
# usage
# {'direct': ['200_26.csv', '204_309.csv'], 'similar': {}, 'd_type': 'object'}
# party
# {'direct': ['200_28.csv', '200_35.csv', '201_1.csv', '201_25.csv', '201_29.csv', '202_125.csv', '202_150.csv', '202_191.csv', '202_224.csv', '202_231.csv', '202_271.csv', '202_273.csv', '202_76.csv', '202_91.csv', '202_92.csv', '203_106.csv', '203_155.csv', '203_16.csv', '203_194.csv', '203_214.csv', '203_247.csv', '203_316.csv', '203_345.csv', '203_354.csv', '203_372.csv', '203_407.csv', '203_409.csv', '203_423.csv', '203_447.csv', '203_484.csv', '203_494.csv', '203_615.csv', '203_694.csv', '203_705.csv', '203_798.csv', '203_817.csv', '203_850.csv', '204_109.csv', '204_145.csv', '204_223.csv', '204_293.csv', '204_370.csv', '204_400.csv', '204_580.csv', '204_599.csv', '204_659.csv', '204_668.csv', '204_675.csv', '204_677.csv', '204_683.csv', '204_699.csv', '204_736.csv', '204_887.csv'], 'similar': {}, 'd_type': 'object'}
# active voters
# {'direct': ['200_28.csv', '200_35.csv'], 'similar': {}, 'd_type': 'int64'}
# inactive voters
# {'direct': ['200_28.csv', '200_35.csv'], 'similar': {}, 'd_type': 'int64'}
# total voters
# {'direct': ['200_28.csv', '200_35.csv'], 'similar': {}, 'd_type': 'int64'}
# percentage
# {'direct': ['200_28.csv', '200_35.csv', '202_104.csv', '202_125.csv', '202_191.csv', '202_224.csv', '202_231.csv', '202_271.csv', '202_273.csv', '202_91.csv', '202_92.csv', '203_354.csv', '203_494.csv', '203_662.csv', '203_798.csv', '204_190.csv', '204_28.csv', '204_786.csv', '204_951.csv', '204_982.csv'], 'similar': {}, 'd_type': 'object'}
# club performance season norway
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# club performance club norway
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# club performance league norway
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# league apps league
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# league goals league
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# cup apps norwegian cup
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# cup goals norwegian cup
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# total apps total
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# total goals total
# {'direct': ['200_29.csv'], 'similar': {}, 'd_type': 'object'}
# winner
# {'direct': ['200_3.csv', '201_38.csv', '203_140.csv', '203_17.csv', '203_178.csv', '203_225.csv', '203_236.csv', '203_25.csv', '203_255.csv', '203_271.csv', '203_337.csv', '203_397.csv', '203_44.csv', '203_475.csv', '203_531.csv', '203_636.csv', '203_680.csv', '203_704.csv', '203_826.csv', '203_850.csv', '204_166.csv', '204_171.csv', '204_19.csv', '204_212.csv', '204_252.csv', '204_312.csv', '204_373.csv', '204_393.csv', '204
# area size (km2)
# {'direct': ['200_33.csv'], 'similar': {}, 'd_type': 'object'}
# population
# {'direct': ['200_33.csv', '201_11.csv', '203_152.csv', '203_3.csv', '203_413.csv', '203_459.csv', '203_510.csv', '203_568.csv', '203_729.csv', '203_832.csv', '204_158.csv', '204_251.csv', '204_322.csv', '204_332.csv', '204_572.csv', '204_6.csv', '204_600.csv', '204_616.csv', '204_64.csv', '204_646.csv', '204_704.csv', '204_739.csv', '204_890.csv'], 'similar': {}, 'd_type': 'object'}
# density per km2
# {'direct': ['200_33.csv'], 'similar': {}, 'd_type': 'float64'}
# preceded by alfred scott
# {'direct': ['200_37.csv'], 'similar': {}, 'd_type': 'object'}
# member of parliament for ashton under lyne 1910 1916
# {'direct': ['200_37.csv'], 'similar': {}, 'd_type': 'object'}
# succeeded by albert stanley
# {'direct': ['200_37.csv'], 'similar': {}, 'd_type': 'object'}
# new municipality
# {'direct': ['200_38.csv'], 'similar': {}, 'd_type': 'object'}
# old municipalities
# {'direct': ['200_38.csv'], 'similar': {}, 'd_type': 'object'}
# seat
# {'direct': ['200_38.csv', '204_659.csv'], 'similar': {}, 'd_type': 'object'}
# team
# {'direct': ['200_4.csv', '201_38.csv', '202_131.csv', '202_22.csv', '202_242.csv', '202_253.csv', '202_64.csv', '202_65.csv', '202_83.csv', '203_131.csv', '203_149.csv', '203_150.csv', '203_156.csv', '203_161.csv', '203_198.csv', '203_200.csv', '203_208.csv', '203_218.csv', '203_227.csv', '203_254.csv', '203_258.csv', '203_262.csv', '203_271.csv', '203_297.csv', '203_30.csv', '203_309.csv', '203_348.csv', '203_366.csv', '203_450.csv', '203_452.csv', '203_483.csv', '203_486.csv', '203_493.csv', '203_502.csv', '203_516.csv', '203_519.csv', '203_53.csv', '203_532.csv', '203_549.csv', '203_561.csv', '203_582.csv', '203_597.csv', '203_611.csv', '203_618.csv', '203_622.csv', '203_654.csv', '203_659.csv', '203_67.csv', '203_733.csv', '203_761.csv', '203_789.csv', '203_833.csv', '203_99.csv', '204_115.csv', '204_129.csv', '204_162.csv', '204_167.csv', '204_175.csv', '204_192.csv', '204_195.csv', '204_199.csv', '204_205.csv', '204_235.csv', '204_283.csv', '204_288.csv', '204_305.csv', '204_314.csv', '204_329.csv', '204_366.csv', '204_371.csv', '204_391.csv', '204_397.csv', '204_409.csv', '204_417.csv', '204_424.csv', '204_440.csv', '204_448.csv', '204_468.csv', '204_477.csv', '204_48.csv', '204_491.csv', '204_496.csv', '204_497.csv', '204_506.csv', '204_530.csv', '204_531.csv', '204_548.csv', '204_552.csv', '204_567.csv', '204_578.csv', '204_586.csv', '204_604.csv', '204_642.csv', '204_645.csv', '204_661.csv', '204_687.csv', '204_722.csv', '204_735.csv', '204_750.csv', '204_756.csv', '204_772.csv', '204_773.csv', '204_808.csv', '204_833.csv', '204_837.csv', '204_853.csv', '204_864.csv', '204_881.csv', '204_89.csv', '204_905.csv', '204_914.csv', '204_93.csv', '204_946.csv', '204_957.csv', '204_964.csv', '204_973.csv', '204_992.csv', '204_995.csv'], 'similar': {}, 'd_type': 'object'}
# p
# {'direct': ['200_4.csv', '203_237.csv'], 'similar': {}, 'd_type': 'int64'}
# gf
# {'direct': ['200_4.csv', '202_197.csv', '203_469.csv', '204_32.csv'], 'similar': {}, 'd_type': 'int64'}
# ga
# {'direct': ['200_4.csv', '202_197.csv', '203_469.csv', '204_32.csv'], 'similar': {}, 'd_type': 'int64'}
# gd
# {'direct': ['200_4.csv', '204_924.csv'], 'similar': {}, 'd_type': 'float64'}
# pts
# {'direct': ['200_4.csv', '204_924.csv'], 'similar': {}, 'd_type': 'int64'}
# number
# {'direct': ['200_41.csv', '202_119.csv', '202_146.csv', '203_19.csv', '203_27.csv', '203_326.csv', '203_332.csv', '203_348.csv', '203_386.csv', '203_505.csv', '203_573.csv', '203_639.csv', '203_679.csv', '203_717.csv', '203_764.csv', '203_88.csv', '204_115.csv', '204_178.csv', '204_209.csv', '204_33.csv', '204_39.csv', '204_434.csv', '204_452.csv', '204_511.csv', '204_575.csv', '204_61.csv', '204_618.csv', '204_720.csv', '204_77.csv', '204_867.csv', '204_877.csv', '204_882.csv', '204_978.csv'], 'similar': {}, 'd_type': 'object'}
# encoding
# {'direct': ['200_41.csv'], 'similar': {}, 'd_type': 'int64'}
# implied probability
# {'direct': ['200_41.csv'], 'similar': {}, 'd_type': 'object'}
# month
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv', '203_132.csv', '203_419.csv', '203_43.csv', '204_310.csv'], 'similar': {}, 'd_type': 'object'}
# jan
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# feb
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# mar
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# apr
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# may
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# jun
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# jul
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# aug
# {'direct': ['200_42.csv', '200_46.csv', '200_48.csv', '201_22.csv', '201_3.csv', '201_33.csv', '201_37.csv', '201_45.csv', '201_49.csv', '201_6.csv', '202_167.csv', '202_228.csv', '202_57.csv', '202_99.csv'], 'similar': {}, 'd_type': 'object'}
# sep
# ...
# areas established
# {'direct': ['204_869.csv'], 'similar': {}, 'd_type': 'object'}
# pasture type
# {'direct': ['204_869.csv'], 'similar': {}, 'd_type': 'object'}
# named for
# {'direct': ['204_87.csv'], 'similar': {}, 'd_type': 'object'}
# ano
# {'direct': ['204_871.csv'], 'similar': {}, 'd_type': 'object'}
# architect
# {'direct': ['204_872.csv'], 'similar': {}, 'd_type': 'object'}
# year of listing & refs
# {'direct': ['204_872.csv'], 'similar': {}, 'd_type': 'object'}
# marriage date
# {'direct': ['204_873.csv'], 'similar': {}, 'd_type': 'object'}
# tenure 1
# {'direct': ['204_873.csv'], 'similar': {}, 'd_type': 'object'}
# league two
# {'direct': ['204_877.csv'], 'similar': {}, 'd_type': 'int64'}
# fl trophy
# {'direct': ['204_877.csv'], 'similar': {}, 'd_type': 'int64'}
# sensor res , size
# {'direct': ['204_878.csv'], 'similar': {}, 'd_type': 'object'}
# screen size, pixels
# {'direct': ['204_878.csv'], 'similar': {}, 'd_type': 'object'}
# dimensions w (mm) x h (mm) x d (mm)
# {'direct': ['204_878.csv'], 'similar': {}, 'd_type': 'object'}
# host / location
# {'direct': ['204_879.csv'], 'similar': {}, 'd_type': 'object'}
# division i overall
# {'direct': ['204_879.csv'], 'similar': {}, 'd_type': 'object'}
# division i undergraduate
# {'direct': ['204_879.csv'], 'similar': {}, 'd_type': 'object'}
# division ii overall
# {'direct': ['204_879.csv'], 'similar': {}, 'd_type': 'object'}
# division ii community college
# {'direct': ['204_879.csv'], 'similar': {}, 'd_type': 'object'}
# romanization
# {'direct': ['204_88.csv'], 'similar': {}, 'd_type': 'object'}
# opponent's score
# {'direct': ['204_881.csv'], 'similar': {}, 'd_type': 'object'}
# best on ground
# {'direct': ['204_881.csv'], 'similar': {}, 'd_type': 'object'}
# place of birth
# {'direct': ['204_883.csv'], 'similar': {}, 'd_type': 'object'}
# previous club
# {'direct': ['204_883.csv'], 'similar': {}, 'd_type': 'object'}
# date joined
# {'direct': ['204_883.csv'], 'similar': {}, 'd_type': 'object'}
# swimmer
# {'direct': ['204_886.csv'], 'similar': {}, 'd_type': 'object'}
# mile
# {'direct': ['204_888.csv'], 'similar': {}, 'd_type': 'float64'}
# week (stage)
# {'direct': ['204_889.csv'], 'similar': {}, 'd_type': 'object'}
# trucks
# {'direct': ['204_89.csv'], 'similar': {}, 'd_type': 'object'}
# chart year
# {'direct': ['204_895.csv'], 'similar': {}, 'd_type': 'int64'}
# billboard hot 100
# {'direct': ['204_895.csv'], 'similar': {}, 'd_type': 'object'}
# billboard hot r&b/hip hop
# {'direct': ['204_895.csv'], 'similar': {}, 'd_type': 'float64'}
# conf (overall)
# {'direct': ['204_898.csv'], 'similar': {}, 'd_type': 'object'}
# tiebreaker
# {'direct': ['204_898.csv'], 'similar': {}, 'd_type': 'object'}
# tornadoes
# {'direct': ['204_899.csv'], 'similar': {}, 'd_type': 'object'}
# works numbers
# {'direct': ['204_901.csv'], 'similar': {}, 'd_type': 'object'}
# cn numbers
# {'direct': ['204_901.csv'], 'similar': {}, 'd_type': 'object'}
# gt numbers
# {'direct': ['204_901.csv'], 'similar': {}, 'd_type': 'object'}
# broadcaster
# {'direct': ['204_903.csv'], 'similar': {}, 'd_type': 'object'}
# lift name
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'object'}
# top elevation (ft)
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# bottom elevation
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# vertical rise
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# length (ft)
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# slope (percentage)
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'object'}
# capacity (rides/hr)
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# speed (ft/min)
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# lift manufacturer
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'object'}
# year installed
# {'direct': ['204_907.csv'], 'similar': {}, 'd_type': 'int64'}
# match day
# {'direct': ['204_908.csv'], 'similar': {}, 'd_type': 'int64'}
# aberdeen scorers
# {'direct': ['204_908.csv'], 'similar': {}, 'd_type': 'object'}
# pollutant
# {'direct': ['204_909.csv'], 'similar': {}, 'd_type': 'object'}
# emission standard
# {'direct': ['204_909.csv'], 'similar': {}, 'd_type': 'object'}
# coal fired
# {'direct': ['204_909.csv'], 'similar': {}, 'd_type': 'object'}
# petroleum coke fired
# {'direct': ['204_909.csv'], 'similar': {}, 'd_type': 'object'}
# original title
# {'direct': ['204_91.csv'], 'similar': {}, 'd_type': 'object'}
# album / name
# {'direct': ['204_911.csv'], 'similar': {}, 'd_type': 'object'}
# role/credit
# {'direct': ['204_911.csv'], 'similar': {}, 'd_type': 'object'}
# chartnum
# {'direct': ['204_911.csv'], 'similar': {}, 'd_type': 'object'}
# attempts
# {'direct': ['204_914.csv'], 'similar': {}, 'd_type': 'int64'}
# ypc
# {'direct': ['204_914.csv'], 'similar': {}, 'd_type': 'float64'}
# tds
# {'direct': ['204_914.csv'], 'similar': {}, 'd_type': 'int64'}
# ccc
# {'direct': ['204_916.csv'], 'similar': {}, 'd_type': 'object'}
# ieee conference on computational complexity
# {'direct': ['204_916.csv'], 'similar': {}, 'd_type': 'object'}
#
# {'direct': ['204_916.csv'], 'similar': {}, 'd_type': 'object'}
# lineup
# {'direct': ['204_920.csv'], 'similar': {}, 'd_type': 'object'}
# min
# {'direct': ['204_920.csv'], 'similar': {}, 'd_type': 'object'}
# assist/pass
# {'direct': ['204_920.csv'], 'similar': {}, 'd_type': 'object'}
# entered administration
# {'direct': ['204_923.csv'], 'similar': {}, 'd_type': 'object'}
# exited administration
# {'direct': ['204_923.csv'], 'similar': {}, 'd_type': 'object'}
# leagues
# {'direct': ['204_923.csv'], 'similar': {}, 'd_type': 'object'}
# ground
# {'direct': ['204_924.csv', '204_971.csv'], 'similar': {}, 'd_type': 'object'}
# jp trophy
# {'direct': ['204_925.csv'], 'similar': {}, 'd_type': 'int64'}
# writers
# {'direct': ['204_927.csv'], 'similar': {}, 'd_type': 'object'}
# territory
# {'direct': ['204_928.csv'], 'similar': {}, 'd_type': 'object'}
# name of mill and grid reference
# {'direct': ['204_929.csv'], 'similar': {}, 'd_type': 'object'}
# first mention or built
# {'direct': ['204_929.csv'], 'similar': {}, 'd_type': 'object'}
# last mention or demise
# {'direct': ['204_929.csv'], 'similar': {}, 'd_type': 'object'}
# lead vocals
# {'direct': ['204_932.csv'], 'similar': {}, 'd_type': 'object'}
# awarding age
# {'direct': ['204_935.csv'], 'similar': {}, 'd_type': 'object'}
# edmonton hundred
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# elthorne hundred
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# gore hundred
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# isleworth hundred
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# ossulstone hundred holborn division
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# ossulstone hundred finsbury division
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# ossulstone hundred kensington division
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# ossulstone hundred tower division
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# spelthorne hundred
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# london city within the walls
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# london city without the walls
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# inns of court and chancery
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# westminster city and liberty
# {'direct': ['204_938.csv'], 'similar': {}, 'd_type': 'int64'}
# tournaments played
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'int64'}
# cuts made
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'int64'}
# 2nd
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'int64'}
# 3rd
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'int64'}
# top 10s
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'int64'}
# best finish
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'object'}
# earnings ( )
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'float64'}
# scoring average
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'float64'}
# scoring rank
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'float64'}
# rolex ranking
# {'direct': ['204_940.csv'], 'similar': {}, 'd_type': 'float64'}
# percentage decadal growth 2001 2011
# {'direct': ['204_942.csv'], 'similar': {}, 'd_type': 'float64'}
# density (persons per km2)
# {'direct': ['204_942.csv'], 'similar': {}, 'd_type': 'int64'}
# child population 0 6 years
# {'direct': ['204_942.csv'], 'similar': {}, 'd_type': 'int64'}
# child sex ratio
# {'direct': ['204_942.csv'], 'similar': {}, 'd_type': 'int64'}
# literacy rate
# {'direct': ['204_942.csv'], 'similar': {}, 'd_type': 'float64'}
# state (linked to summaries below)
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# incumbent senator
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# incumbent party
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# incumbent electoral history
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# most recent election results
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# 2018 intent
# {'direct': ['204_943.csv'], 'similar': {}, 'd_type': 'object'}
# mine
# {'direct': ['204_944.csv'], 'similar': {}, 'd_type': 'object'}
# sent home
# {'direct': ['204_945.csv'], 'similar': {}, 'd_type': 'object'}
# highest seller
# {'direct': ['204_945.csv'], 'similar': {}, 'd_type': 'object'}
# first year in this position
# {'direct': ['204_95.csv'], 'similar': {}, 'd_type': 'float64'}
# years at nebraska
# {'direct': ['204_95.csv'], 'similar': {}, 'd_type': 'float64'}
# occasion num
# {'direct': ['204_950.csv'], 'similar': {}, 'd_type': 'int64'}
# delegates
# {'direct': ['204_951.csv'], 'similar': {}, 'd_type': 'int64'}
# 2009 winter universiade
# {'direct': ['204_954.csv'], 'similar': {}, 'd_type': 'object'}
# 2007 wjcc
# {'direct': ['204_954.csv'], 'similar': {}, 'd_type': 'object'}
# 2007 wwcc
# {'direct': ['204_954.csv'], 'similar': {}, 'd_type': 'object'}
# 2008 wjcc
# {'direct': ['204_954.csv'], 'similar': {}, 'd_type': 'object'}
# 2008 wwcc
# {'direct': ['204_954.csv'], 'similar': {}, 'd_type': 'object'}
# lak
# {'direct': ['204_955.csv'], 'similar': {}, 'd_type': 'object'}
# ora
# {'direct': ['204_955.csv'], 'similar': {}, 'd_type': 'object'}
# san
# {'direct': ['204_955.csv'], 'similar': {}, 'd_type': 'object'}
# phi
# {'direct': ['204_955.csv'], 'similar': {}, 'd_type': 'object'}
# original broadcast date
# {'direct': ['204_958.csv'], 'similar': {}, 'd_type': 'object'}
# entered competition
# {'direct': ['204_959.csv'], 'similar': {}, 'd_type': 'int64'}
# most recent promotion
# {'direct': ['204_959.csv'], 'similar': {}, 'd_type': 'float64'}
# fips code
# {'direct': ['204_960.csv'], 'similar': {}, 'd_type': 'int64'}
# county seat
# {'direct': ['204_960.csv'], 'similar': {}, 'd_type': 'object'}
# etymology
# {'direct': ['204_960.csv'], 'similar': {}, 'd_type': 'object'}
# population estimate (2011)
# {'direct': ['204_960.csv'], 'similar': {}, 'd_type': 'int64'}
# goal diff
# {'direct': ['204_964.csv'], 'similar': {}, 'd_type': 'object'}
# state, province, dept , etc
# {'direct': ['204_965.csv'], 'similar': {}, 'd_type': 'object'}
# december
# {'direct': ['204_967.csv'], 'similar': {}, 'd_type': 'int64'}
# squad num
# {'direct': ['204_968.csv'], 'similar': {}, 'd_type': 'float64'}
# transferred to
# {'direct': ['204_968.csv'], 'similar': {}, 'd_type': 'object'}
# dinamo scorers
# {'direct': ['204_971.csv'], 'similar': {}, 'd_type': 'object'}
# administration
# {'direct': ['204_974.csv'], 'similar': {}, 'd_type': 'object'}
# qualifying rank
# {'direct': ['204_975.csv'], 'similar': {}, 'd_type': 'int64'}
# qualifying score
# {'direct': ['204_975.csv'], 'similar': {}, 'd_type': 'float64'}
# soproni liga
# {'direct': ['204_978.csv'], 'similar': {}, 'd_type': 'int64'}
# uefa cup
# {'direct': ['204_978.csv'], 'similar': {}, 'd_type': 'int64'}
# hungarian cup
# {'direct': ['204_978.csv'], 'similar': {}, 'd_type': 'int64'}
# 5 hoops
# {'direct': ['204_979.csv'], 'similar': {}, 'd_type': 'object'}
# 3 balls, 2 ribbons
# {'direct': ['204_979.csv'], 'similar': {}, 'd_type': 'object'}
# elevation (ground station)
# {'direct': ['204_980.csv'], 'similar': {}, 'd_type': 'int64'}
# elevation (mountain station)
# {'direct': ['204_980.csv'], 'similar': {}, 'd_type': 'int64'}
# slope length
# {'direct': ['204_980.csv'], 'similar': {}, 'd_type': 'int64'}
# capacity (persons/hour)
# {'direct': ['204_980.csv'], 'similar': {}, 'd_type': 'int64'}
# construction year
# {'direct': ['204_980.csv'], 'similar': {}, 'd_type': 'int64'}
# party/electoral alliance
# {'direct': ['204_982.csv'], 'similar': {}, 'd_type': 'object'}
# 1st venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# 2nd venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# 3rd venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# 4th venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# 5th venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# 6th venue
# {'direct': ['204_983.csv'], 'similar': {}, 'd_type': 'object'}
# islam
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# christianity
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# judaism
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# buddhism
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# none / atheism
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# n/a
# {'direct': ['204_984.csv'], 'similar': {}, 'd_type': 'object'}
# away
# {'direct': ['204_985.csv'], 'similar': {}, 'd_type': 'object'}
# city/municipality
# {'direct': ['204_987.csv'], 'similar': {}, 'd_type': 'object'}
# no of barangays
# {'direct': ['204_987.csv'], 'similar': {}, 'd_type': 'int64'}
# pop density (per km2)
# {'direct': ['204_987.csv'], 'similar': {}, 'd_type': 'object'}
# responsible ministers
# {'direct': ['204_988.csv'], 'similar': {}, 'd_type': 'object'}
# crown entities
# {'direct': ['204_988.csv'], 'similar': {}, 'd_type': 'object'}
# monitoring departments
# {'direct': ['204_988.csv'], 'similar': {}, 'd_type': 'object'}
# category / type
# {'direct': ['204_988.csv'], 'similar': {}, 'd_type': 'object'}
# empowering legislation
# {'direct': ['204_988.csv'], 'similar': {}, 'd_type': 'object'}
# last win
# {'direct': ['204_99.csv'], 'similar': {}, 'd_type': 'float64'}
# last losing final
# {'direct': ['204_99.csv'], 'similar': {}, 'd_type': 'float64'}
# by race
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# white
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# black
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# aian*
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# asian
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# nhpi*
# {'direct': ['204_990.csv'], 'similar': {}, 'd_type': 'object'}
# first held
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'int64'}
# earliest attendance figure known
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'object'}
# 1998 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2000 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2002 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2004 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2006 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2008 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2010 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# 2012 attendance
# {'direct': ['204_991.csv'], 'similar': {}, 'd_type': 'float64'}
# household rating
# {'direct': ['204_996.csv'], 'similar': {}, 'd_type': 'float64'}
# viewers (millions)
# {'direct': ['204_996.csv'], 'similar': {}, 'd_type': 'object'}
# celebrity guests
# {'direct': ['204_997.csv'], 'similar': {}, 'd_type': 'object'}
# timeslot
# {'direct': ['204_998.csv'], 'similar': {}, 'd_type': 'object'}
# 18 49
# {'direct': ['204_998.csv'], 'similar': {}, 'd_type': 'object'}
# weekly rank
# {'direct': ['204_998.csv'], 'similar': {}, 'd_type': 'object'}
# first switch
# {'direct': ['204_999.csv'], 'similar': {}, 'd_type': 'object'}
# second switch
# {'direct': ['204_999.csv'], 'similar': {}, 'd_type': 'object'}
# ghost island
# {'direct': ['204_999.csv'], 'similar': {}, 'd_type': 'object'}

# %%
pd.read_csv("204_63.csv")
# Out:
#    round                                     circuit         date  \
# 0      1  ACI Vallelunga Circuit, Campagnano di Roma      7 April
# 1      2                        Misano World Circuit     28 April
# 2      3                  Autodromo di Pergusa, Enna       19 May
# 3      4                   Autodromo Nazionale Monza      30 June
# 4      5          Autodromo Riccardo Paletti, Varano      21 July
# 5      6        Autodromo Enzo e Dino Ferrari, Imola  1 September
# 6      7              Autodromo del Levante, Binetto  8 September
# 7      8                  Mugello Circuit, Scarperia    6 October
# 8      9              Autodromo dell'Umbria, Magione   20 October
#
#          pole position       winning driver            winning team  \
# 0       Miloš Pavlović       Miloš Pavlović           Target Racing
# 1       Miloš Pavlović       Miloš Pavlović           Target Racing
# 2       Miloš Pavlović  Philip Cloostermans            Azeta Racing
# 3  Philip Cloostermans  Philip Cloostermans            Azeta Racing
# 4       Miloš Pavlović       Miloš Pavlović           Target Racing
# 5    Vitantonio Liuzzi    Vitantonio Liuzzi  Bertram Schäfer Racing
# 6    Christiano Citron       Miloš Pavlović           Target Racing
# 7       Miloš Pavlović       Miloš Pavlović           Target Racing
# 8        Andreas Zuber    Christiano Citron           Target Racing
#
#        trophy winner
# 0          Nino Famà
# 1  Giovanni Faraonio
# 2   Carmine Tancredi
# 3   Carmine Tancredi
# 4   Carmine Tancredi
# 5     Silvio Alberti
# 6   Carmine Tancredi
# 7      Dino Lusuardi
# 8    Alberto Morelli

# %%
x=pd.read_csv("203_148.csv")

# %%
import json
import urllib
api_key = "AIzaSyCJdqNKHF6A9V6CxKCROT1tbp2DoHZgMKk"
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'limit': 100,
    'indent': True,
    'key': api_key,
}
s={}
for row in x["name"]:
    query = row
    params['query']= query
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    
    for element in response['itemListElement']:
        for i in element["result"]["@type"]:
            a=i.lower()
            if a in s:
                s[a]+=1
            else:
                s[a]=1
        if "description" in element["result"]:
            a=element["result"]["description"].lower()
            if a in s:
                s[a]+=1
            else:
                s[a]=1

# %%
s
# Out:
# {'thing': 542,
#  'organization': 24,
#  'sportsteam': 18,
#  'cycling team': 2,
#  'soccer club': 6,
#  'book': 7,
#  'book by antoon sanders': 1,
#  'basketball club': 1,
#  'corporation': 8,
#  'record label': 1,
#  'soccer team': 2,
#  'ship': 13,
#  'place': 60,
#  'professional sports team': 1,
#  'person': 226,
#  "dulce of aragon's son": 1,
#  'philosopher': 1,
#  'argentine goalkeeper': 1,
#  'soccer forward': 1,
#  'event': 35,
#  'soccer player': 8,
#  'road cycling team': 5,
#  'argentine soccer player': 13,
#  'plants': 1,
#  'city': 38,
#  'town in argentina': 1,
#  'argentinean soccer player': 1,
#  'sportsorganization': 2,
#  'league': 2,
#  'soccer goalkeeper': 1,
#  'soccer defender': 1,
#  'sports league season': 4,
#  'belgian bicycler': 1,
#  'tournament': 1,
#  'football league season': 1,
#  'paraguayan soccer player': 1,
#  'aerospace company': 1,
#  'country': 2,
#  'administrativearea': 4,
#  'country in central africa': 1,
#  'company': 2,
#  'bank': 1,
#  'musiccomposition': 1,
#  'opera by claudio monteverdi': 1,
#  'city in chile': 1,
#  'disaster': 1,
#  'stadiumorarena': 2,
#  'arena in hämeenlinna, finland': 1,
#  'tvseries': 7,
#  'brazilian telenovela': 2,
#  'movie': 7,
#  '1917 film': 1,
#  'revolutionary': 1,
#  'musicgroup': 3,
#  'musical group': 2,
#  'italian politician': 1,
#  'light rail station in guadalajara, mexico': 1,
#  'song by franco battiato': 1,
#  '2012 film': 1,
#  'mexican politician': 1,
#  '2015 film': 1,
#  'indonesian politician': 1,
#  'touristattraction': 7,
#  'mountain': 2,
#  'song by bedřich smetana': 1,
#  'territory': 1,
#  'multi-purpose stadium in sucre, bolivia': 1,
#  'civicstructure': 1,
#  'movie theatre in bucharest, romania': 1,
#  'musicalbum': 6,
#  'album by quilapayún': 1,
#  'french politician': 1,
#  'song by inocentes': 1,
#  'town in paraguay': 1,
#  'musical': 1,
#  'museum in santo domingo, dominican republic': 1,
#  'city in italy': 1,
#  'novelist': 1,
#  'article': 1,
#  'poem by juan zorrilla de san martín': 1,
#  'song by alvaro torres': 1,
#  'book by edgar morin': 1,
#  '2017 film': 1,
#  'landmark in rome, italy': 1,
#  'italian race car driver': 1,
#  'song by nomadi': 1,
#  'book by manuel gamio': 1,
#  'bodyofwater': 1,
#  'lakebodyofwater': 1,
#  'lake in italy': 1,
#  'song by rubén blades': 2,
#  'song by minami kuribayashi': 1,
#  'song by rata blanca': 2,
#  'song by el gran combo de puerto rico': 2,
#  'musicrecording': 16,
#  'book by luiz puntel': 1,
#  '1916 film': 1,
#  'song by avelino muñoz': 1,
#  'song by juan carlos baglietto': 1,
#  'song by los lobos': 1,
#  'album by minami kuribayashi': 1,
#  'song by rat-zinger': 1,
#  'song by kazi ploae and specii': 1,
#  'book by sofía lacayo': 1,
#  'song by color humano': 1,
#  'album by don cornelio y la zona': 1,
#  'song by héctor braga': 1,
#  'song by axis mundi and mara ros': 2,
#  'song by hugo moraga': 2,
#  'album by tervahäät': 1,
#  'song by patria': 1,
#  'song by neztic &amp; vate': 1,
#  'song by hugo del valle and ricardo pedevilla': 1,
#  'song by der arbeiter': 2,
#  'actress': 17,
#  'tv producer': 1,
#  'song by the well of sadness': 1,
#  'song by falgar': 1,
#  'album by neztic &amp; vate': 1,
#  'song by adriano correia de oliveira': 2,
#  'asteroid': 1,
#  'american musician': 2,
#  'american singer': 7,
#  'city in california': 2,
#  'american songwriter': 1,
#  'american pornographic actress': 1,
#  'american actress': 20,
#  'u.s. representative': 2,
#  'singer-songwriter': 3,
#  'administrator of the small business administration': 1,
#  'collegeoruniversity': 1,
#  'educationalorganization': 1,
#  'university in loma linda, california': 1,
#  '2005 film': 1,
#  'american television personality': 1,
#  'american teacher': 1,
#  'american singer-songwriter': 2,
#  'canadian model': 1,
#  'american author': 3,
#  'fictional superhero': 1,
#  'american film actress': 4,
#  'cyclist': 1,
#  'polish actor': 1,
#  'american activist': 1,
#  'finnish violinist': 1,
#  'vocal duo': 1,
#  'american-argentine actress': 1,
#  'american television actress': 1,
#  'norwegian politician': 1,
#  'singer': 5,
#  'canadian actress': 1,
#  'swedish soccer player': 1,
#  'swedish singer-songwriter': 1,
#  'telenovela': 1,
#  'member of the bundestag': 2,
#  'french actress': 1,
#  'mexican film actress': 1,
#  'vocalist': 1,
#  'song by projota': 1,
#  'broadcastchannel': 1,
#  'theatergroup': 1,
#  'television network': 1,
#  'former governor of hawaii': 1,
#  'song by the blue hearts': 1,
#  'german soccer player': 1,
#  'american tv program': 1,
#  'japanese singer': 1,
#  'census-designated place in california': 1,
#  'australian senator': 1,
#  'swiss model': 1,
#  'south african musician': 1,
#  'american psychologist': 1,
#  'swedish singer': 3,
#  'american astrologer': 1,
#  'australian politician': 1,
#  'canadian senator': 1,
#  'civil servant': 1,
#  'swedish television presenter': 1,
#  'filipino film actress': 1,
#  'fictional character': 2,
#  'american journalist': 1,
#  'psychologist': 1,
#  'german-greek journalist': 1,
#  'irish singer': 1,
#  'american art historian': 1,
#  'american sportscaster': 1,
#  'swedish rapper': 1,
#  'dutch actress': 1,
#  'american model': 1,
#  'highway in mexico': 2,
#  'author': 1,
#  'british novelist': 1,
#  'correspondent': 1,
#  'american sports announcer': 1,
#  'american biographer': 1,
#  'studio album by earl sweatshirt': 1,
#  'american navy man': 1,
#  'film director': 1,
#  'member of the swiss federal council': 1,
#  'tennis player': 1,
#  'american dancer': 2,
#  'german singer': 2,
#  'australian actress': 1,
#  'member of the national council of austria': 1,
#  'colombian visual artist': 1,
#  'spiritualist': 1,
#  'american film director': 1,
#  "sharon tate's mother": 1,
#  'chairman of banca mediolanum': 1,
#  'canadian author': 1,
#  'american character actress': 1,
#  'nun': 1,
#  'american script supervisor': 1,
#  'venezuelan actress': 1,
#  'french actor': 1,
#  'american painter': 1,
#  'german journalist': 1,
#  'american political activist': 1,
#  'croatian goalkeeper': 1,
#  'scottish costume designer': 1,
#  'brazilian singer': 1,
#  'artist': 1,
#  'journalist': 1,
#  'italian film actress': 1,
#  'educator': 1,
#  'estonian poet': 2,
#  'croatian actress': 1,
#  'taiwanese bassist': 1,
#  'american music composer': 1,
#  'german television actress': 1,
#  'german politician': 1,
#  'swiss cyclist': 1,
#  'american professor': 1,
#  'american businesswoman': 1,
#  'american philanthropist': 1,
#  'american political scientist': 1,
#  'german soprano': 1,
#  'musical artist': 1,
#  'american sitcom': 2,
#  'american mathematician': 1,
#  'canadian comedian': 1,
#  'american translator': 1,
#  '2006 film': 1,
#  'socialite': 2,
#  'american television show': 1,
#  'chinese singer': 1,
#  'american photographer': 1,
#  'german writer': 1,
#  'american screenwriter': 1,
#  'scottish soccer player': 1,
#  'austrian film actress': 1,
#  'bird': 20,
#  'commune': 2,
#  'submarine': 2,
#  'kosovar ballet dancer': 1,
#  'song by jean c. roché': 10,
#  'song by taxim': 2,
#  'albanian fighter': 1,
#  'town in mali': 14,
#  'village in mali': 5,
#  'commune in mali': 3,
#  'village': 2,
#  'town': 3,
#  'estonian coach': 1,
#  'estonian geologist': 1,
#  'chemist': 1,
#  'poet': 1,
#  'song by vladimir vysotsky': 2,
#  'song': 4,
#  'videogame': 1,
#  'video game': 1,
#  'kara-class cruiser': 1,
#  'kara class': 2,
#  'moskva-class helicopter carrier': 2,
#  'aircraft carrier': 1,
#  'boat': 1,
#  'governmentorganization': 2,
#  'gendarmerie': 1,
#  'sports event': 1,
#  'government agency': 1}

# %%
x=set(s)

# %%
x
# Out:
# {'1916 film',
#  '1917 film',
#  '2005 film',
#  '2006 film',
#  '2012 film',
#  '2015 film',
#  '2017 film',
#  'actress',
#  'administrativearea',
#  'administrator of the small business administration',
#  'aerospace company',
#  'aircraft carrier',
#  'albanian fighter',
#  'album by don cornelio y la zona',
#  'album by minami kuribayashi',
#  'album by neztic &amp; vate',
#  'album by quilapayún',
#  'album by tervahäät',
#  'american activist',
#  'american actress',
#  'american art historian',
#  'american astrologer',
#  'american author',
#  'american biographer',
#  'american businesswoman',
#  'american character actress',
#  'american dancer',
#  'american film actress',
#  'american film director',
#  'american journalist',
#  'american mathematician',
#  'american model',
#  'american music composer',
#  'american musician',
#  'american navy man',
#  'american painter',
#  'american philanthropist',
#  'american photographer',
#  'american political activist',
#  'american political scientist',
#  'american pornographic actress',
#  'american professor',
#  'american psychologist',
#  'american screenwriter',
#  'american script supervisor',
#  'american singer',
#  'american singer-songwriter',
#  'american sitcom',
#  'american songwriter',
#  'american sports announcer',
#  'american sportscaster',
#  'american teacher',
#  'american television actress',
#  'american television personality',
#  'american television show',
#  'american translator',
#  'american tv program',
#  'american-argentine actress',
#  'arena in hämeenlinna, finland',
#  'argentine goalkeeper',
#  'argentine soccer player',
#  'argentinean soccer player',
#  'article',
#  'artist',
#  'asteroid',
#  'australian actress',
#  'australian politician',
#  'australian senator',
#  'austrian film actress',
#  'author',
#  'bank',
#  'basketball club',
#  'belgian bicycler',
#  'bird',
#  'boat',
#  'bodyofwater',
#  'book',
#  'book by antoon sanders',
#  'book by edgar morin',
#  'book by luiz puntel',
#  'book by manuel gamio',
#  'book by sofía lacayo',
#  'brazilian singer',
#  'brazilian telenovela',
#  'british novelist',
#  'broadcastchannel',
#  'canadian actress',
#  'canadian author',
#  'canadian comedian',
#  'canadian model',
#  'canadian senator',
#  'census-designated place in california',
#  'chairman of banca mediolanum',
#  'chemist',
#  'chinese singer',
#  'city',
#  'city in california',
#  'city in chile',
#  'city in italy',
#  'civicstructure',
#  'civil servant',
#  'collegeoruniversity',
#  'colombian visual artist',
#  'commune',
#  'commune in mali',
#  'company',
#  'corporation',
#  'correspondent',
#  'country',
#  'country in central africa',
#  'croatian actress',
#  'croatian goalkeeper',
#  'cycling team',
#  'cyclist',
#  'disaster',
#  "dulce of aragon's son",
#  'dutch actress',
#  'educationalorganization',
#  'educator',
#  'estonian coach',
#  'estonian geologist',
#  'estonian poet',
#  'event',
#  'fictional character',
#  'fictional superhero',
#  'filipino film actress',
#  'film director',
#  'finnish violinist',
#  'football league season',
#  'former governor of hawaii',
#  'french actor',
#  'french actress',
#  'french politician',
#  'gendarmerie',
#  'german journalist',
#  'german politician',
#  'german singer',
#  'german soccer player',
#  'german soprano',
#  'german television actress',
#  'german writer',
#  'german-greek journalist',
#  'government agency',
#  'governmentorganization',
#  'highway in mexico',
#  'indonesian politician',
#  'irish singer',
#  'italian film actress',
#  'italian politician',
#  'italian race car driver',
#  'japanese singer',
#  'journalist',
#  'kara class',
#  'kara-class cruiser',
#  'kosovar ballet dancer',
#  'lake in italy',
#  'lakebodyofwater',
#  'landmark in rome, italy',
#  'league',
#  'light rail station in guadalajara, mexico',
#  'member of the bundestag',
#  'member of the national council of austria',
#  'member of the swiss federal council',
#  'mexican film actress',
#  'mexican politician',
#  'moskva-class helicopter carrier',
#  'mountain',
#  'movie',
#  'movie theatre in bucharest, romania',
#  'multi-purpose stadium in sucre, bolivia',
#  'museum in santo domingo, dominican republic',
#  'musical',
#  'musical artist',
#  'musical group',
#  'musicalbum',
#  'musiccomposition',
#  'musicgroup',
#  'musicrecording',
#  'norwegian politician',
#  'novelist',
#  'nun',
#  'opera by claudio monteverdi',
#  'organization',
#  'paraguayan soccer player',
#  'person',
#  'philosopher',
#  'place',
#  'plants',
#  'poem by juan zorrilla de san martín',
#  'poet',
#  'polish actor',
#  'professional sports team',
#  'psychologist',
#  'record label',
#  'revolutionary',
#  'road cycling team',
#  'scottish costume designer',
#  'scottish soccer player',
#  "sharon tate's mother",
#  'ship',
#  'singer',
#  'singer-songwriter',
#  'soccer club',
#  'soccer defender',
#  'soccer forward',
#  'soccer goalkeeper',
#  'soccer player',
#  'soccer team',
#  'socialite',
#  'song',
#  'song by adriano correia de oliveira',
#  'song by alvaro torres',
#  'song by avelino muñoz',
#  'song by axis mundi and mara ros',
#  'song by bedřich smetana',
#  'song by color humano',
#  'song by der arbeiter',
#  'song by el gran combo de puerto rico',
#  'song by falgar',
#  'song by franco battiato',
#  'song by hugo del valle and ricardo pedevilla',
#  'song by hugo moraga',
#  'song by héctor braga',
#  'song by inocentes',
#  'song by jean c. roché',
#  'song by juan carlos baglietto',
#  'song by kazi ploae and specii',
#  'song by los lobos',
#  'song by minami kuribayashi',
#  'song by neztic &amp; vate',
#  'song by nomadi',
#  'song by patria',
#  'song by projota',
#  'song by rat-zinger',
#  'song by rata blanca',
#  'song by rubén blades',
#  'song by taxim',
#  'song by the blue hearts',
#  'song by the well of sadness',
#  'song by vladimir vysotsky',
#  'south african musician',
#  'spiritualist',
#  'sports event',
#  'sports league season',
#  'sportsorganization',
#  'sportsteam',
#  'stadiumorarena',
#  'studio album by earl sweatshirt',
#  'submarine',
#  'swedish rapper',
#  'swedish singer',
#  'swedish singer-songwriter',
#  'swedish soccer player',
#  'swedish television presenter',
#  'swiss cyclist',
#  'swiss model',
#  'taiwanese bassist',
#  'telenovela',
#  'television network',
#  'tennis player',
#  'territory',
#  'theatergroup',
#  'thing',
#  'touristattraction',
#  'tournament',
#  'town',
#  'town in argentina',
#  'town in mali',
#  'town in paraguay',
#  'tv producer',
#  'tvseries',
#  'u.s. representative',
#  'university in loma linda, california',
#  'venezuelan actress',
#  'video game',
#  'videogame',
#  'village',
#  'village in mali',
#  'vocal duo',
#  'vocalist'}

# %%
a=np.nan

# %%
str(a)
# Out:
# 'nan'
