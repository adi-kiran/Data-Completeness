# %%
# importing necessary libraries
import json
import math
import pandas as pd
import numpy as np
from itertools import combinations
from nltk.corpus import wordnet
from IPython.display import display

# %%
#preloading all schemas and categories
all_schemas={}
all_categories={}
all_tablenames={}
with open("final_schema.txt") as ip_file:
    for line in ip_file.readlines():
        json_obj=json.loads(line)
        all_schemas[json_obj["filename"]]=json_obj["schema"]
        all_categories[json_obj["filename"]]=json_obj["categories"]
        all_tablenames[json_obj["filename"]]=json_obj["tablename"]
        
#preloading the candidate keys
with open("Candidate_key_dict.txt",'r') as ip_file:
    cand_key=json.load(ip_file)

#preloading column and category similarity values of tables
with open("cos_similarity.txt",'r') as ip_file:
    json_object=json.load(ip_file)
col_sim = json_object["column_similarity"]
cat_sim = json_object["category_similarity"]

# %%
# all functions needed to generate ontologies
def get_synonyms(word):
    meanings=set()
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for lemma in synset.lemmas():
            meanings.add(lemma.name())
    for synset in wordnet.synsets(word,pos=wordnet.NOUN):
        for hypernym in synset.hypernyms():
            meanings.add(hypernym.lemma_names()[0])
    meanings.add(word)
    return list(meanings)

# takes input list and returns ontology as dictionary with every word in list as the key
def generate_list_ontology(list1):
    ontology={}
    for word in list1:
        ontology[word]=get_synonyms(word)
    return ontology

# takes the input as a schema and returns ontology for every column in the schema
def generate_schema_ontology(input_schema):
    ontology={}
    for col in input_schema:
        ontology[col]=get_synonyms(col)
    return ontology

# %%
# to generate cos similarity between two lists
def cos_sim(list1, list2):
    terms = set(list1).union(list2)
    intersect = set(list1) & set(list2)
    others = (set(list1)-intersect).union(set(list2)-intersect)
    product=0
    for word in terms:
        if word in intersect:
            product+=1
    l1mag = math.sqrt(len(list1))
    l2mag = math.sqrt(len(list2))
    if len(list1)==0 or len(list2)==0:
        return 0.0
    else:
        return product / (l1mag * l2mag)

# %%
# both the following functions
# col_only_list() and cat_and_col_list()
# functions return all the posssible tables that are suitable matches with input schema

# if input has only schema(columns and their dataypes)
# it returns a list of all tables with one or more columns that match with input schema(or its ontology)
def col_only_list(input_schema,input_sch_onto):
    possible_tables={}
    for file in all_schemas:
        schema=all_schemas[file]
        for col,d_type in schema.items():
            if (col in input_schema) and (input_schema[col]==d_type):
                if file in possible_tables:
                    possible_tables[file].append(col)
                else:
                    possible_tables[file]=[]
                    possible_tables[file].append(col)
            else:
                for a in input_sch_onto:
                    if (col in input_sch_onto[a]) and (input_schema[a]==d_type):
                        if file in possible_tables:
                            possible_tables[file].append(a)
                        else:
                            possible_tables[file]=[]
                            possible_tables[file].append(a)
    return possible_tables

# if input has categories as well as schema(columns and their dataypes)
# we consider it a match under the assumption that at least 75% category match exists
# then all tables that meet this criteria and have one or more columns that match are retured as a list 
def cat_and_col_list(input_categories,input_cat_onto,input_schema,input_sch_onto):
    possible_tables={}
    print("Category cosine similarity values that are greater than 75% :")
    print("File Name\t\tcategory cos similarity value")
    for file in all_categories:
        cat_list=[]
        category=all_categories[file]
        for cat in category:
            if cat in input_categories:
                cat_list.append(cat)
            else:
                for cat1 in input_cat_onto:
                    if cat in input_cat_onto[cat1]:
                        cat_list.append(cat1)
        cos_val=cos_sim(cat_list,input_categories)
        if cos_val > 0.75 :
            print(file,"\t\t",cos_val)
            schema=all_schemas[file]
            for col,d_type in schema.items():
                if (col in input_schema) and (input_schema[col]==d_type):
                    if file in possible_tables:
                        possible_tables[file].append(col)
                    else:
                        possible_tables[file]=[]
                        possible_tables[file].append(col)
                else:
                    for a in input_sch_onto:
                        if (col in input_sch_onto[a]) and (input_schema[a]==d_type):
                            if file in possible_tables:
                                possible_tables[file].append(a)
                            else:
                                possible_tables[file]=[]
                                possible_tables[file].append(a)
    print()
    return possible_tables

# %%
# function generates all possible combinations of list l taking elements n to 2 at a time and returns a dictionary
def generate_all_combinations(l):
    x={}
    a=len(l)
    for i in range(a,1,-1):
        x[i]=list(combinations(l,i))
    return x

# function generates all matching columns between the res_cols schema and columns of table in fname
def generate_matching_columns(res_cols,fname):
    a=all_schemas[fname]
    matching_columns={}
    res_onto=generate_schema_ontology(res_cols)
    for col , d_type in a.items():
        if (col in res_cols) and (d_type==res_cols[col]):
            matching_columns[col] = col
        else:
            for col_res in res_onto:
                if (col in res_onto[col_res]) and (d_type==res_cols[col_res]):
                    matching_columns[col] = col_res
                    break
    return matching_columns

# returns a merged table of all tables given in input list l
def merge_list(l):
    t1=pd.read_csv(l[0])
    t2=pd.read_csv(l[1])
    a=all_schemas[l[0]]
    b=all_schemas[l[1]]
    matching_columns={}
    a_onto=generate_schema_ontology(a)
    for col , d_type in b.items():
        if (col in a) and (d_type==a[col]):
            matching_columns[col] = col
        else:
            for col_a in a_onto:
                if (col in a_onto[col_a]) and (d_type==a[col_a]):
                    matching_columns[col] = col_a
                    break
    t2.rename(columns = matching_columns,inplace=True)
    res=t1.merge(t2,how='outer')
    for fname in l[2:]:
        d_types=[]
        res_cols={}
        for i in res.dtypes:
            d_types.append(str(i))
        for i,j in zip(res.columns,d_types):
            res_cols[i]=j
        matching_columns=generate_matching_columns(res_cols,fname)
        t=pd.read_csv(fname)
        t.rename(columns = matching_columns,inplace=True)
        res=res.merge(t,how='outer')
    return res

# %%
# metrics calculated :
# 1)nan_score(number of nulls in each column)
# 2)coverage_score(no of matching columns with input schema/total number of columns in input schema)
# 3)completeness_score(a combination of coverage and nan scores to determine how complete the result dataset is)

# nan score = {x : (no on nans in column/no of entries in column)} where x is each column in the table
# gives the nan score(no on nans/no of entries in table) for each column in the input table
def nan_score(table=-1,fname=-1):
    if fname!=-1:
        table=pd.read_csv(fname)
    nan_count={}
    a=len(table)
    for i in table.columns:
        x=a-table[i].count()
        s=str(x)+'/'+str(a)
        nan_count[i]=s
    return nan_count

#returns the coverage score and completeness score of a given table
#coverage score is calculated as : 
# coverage = (no of columns matching with input schema/total number of columns in input schema)
#completeness score is calculated as : 
# completeness = (sum(x*(non null entries)/(total entries in the column))/total number of columns in input schema) 
#  where x=1 if column present in input schema and x=0 if column is not present in the input schema
def coverage_and_completeness(table):
    ctr=0
    comp=0
    cols=table.columns
    l=len(table)
    for col in cols:
        if col in input_schema:
            ctr+=1
            comp+=1*(1-sum(pd.isnull(table[col]))/l)
    comp=comp/len(input_schema)
    cov=ctr/len(input_schema)
    return (cov,comp)

# %%
def ranking_display(comp_score,no_of_rows):
    print()
    comp_rank=sorted(comp_score,reverse=True)
    count=0
    l=sorted(no_of_rows, key=lambda k: no_of_rows[k],reverse=True)
    for i in comp_rank:
        if len(comp_score[i])==1:
            count+=1
            print("Rank "+str(count)+" : ",comp_score[i][0],"\t\tcompleteness score : ",i,"\t\tnumber of rows: ",no_of_rows[comp_score[i][0]])
        else:
            for j in l:
                if j in comp_score[i]:
                    count+=1
                    print("Rank "+str(count)+" : ",j,"\t\tcompleteness score : ",i,"\t\tnumber of rows: ",no_of_rows[j])
    print("\nRanking Complete!!\n")

# %%
#making a list of transformation functions
tf_onto={}
transform_funct_list={"int64":['average','sum','maximum','minimum','range','median','variance','standard deviation','mode','frequency','avg'],"float64":['average','sum','maximum','minimum','range','median','variance','standard deviation','mode','frequency','avg'],"object":["funct1","funct2","funct3"]}
for dtype,funct_list in transform_funct_list.items():
    tf_onto[dtype]=generate_list_ontology(transform_funct_list)

# %%
# takes output tables schema(columns and data_types) as the input, compare it with input schema and transformations required and
# returns a list of all the transformations applicable
def get_possible_transformations(cols):
    l={}
    for col,tran in transformations.items():
        if (col in cols):
            for i in tran:
                if i in transform_funct_list[input_schema[col]]:
                    if col in l:
                        l[col].append(i)
                    else:
                        l[col]=[]
                        l[col].append(i)
    return l

# %%
# this is a function to print the individual tables names, their nan score, columns that match with input schema, 
# coverage score, and completeness score along with possible transformations if any
def display_individual_matches(matching_tables,matching_tables_dict):
    global comp_score
    global no_of_rows
    f=open("demo/results.txt",'a')
    if transformations==-1:
        flag=0
    else:
        flag=1
    for i in matching_tables:
        print(i+"("+all_tablenames[i]+")",file=f)
        res=pd.read_csv(i)
        cov,comp=coverage_and_completeness(res)
        if flag==1:
            cols=res.columns
            l=get_possible_transformations(cols)
            print("possible transformations are : ",l,file=f)
            cov,comp=coverage_and_completeness(res)
        print('Missing Values(NANs score): ',nan_score(fname=i),file=f)
        print("Columns that match with input_schema:\n "+i+' : ',matching_tables_dict[i],file=f)
        print("Coverage Score : ",cov,"\t Completeness Score : ",comp,"\t Number of Rows : ",len(res),file=f)
        no_of_rows[i]=len(res)
        if comp in comp_score:
            comp_score[comp].append(i)
        else:
            comp_score[comp]=[]
            comp_score[comp].append(i)
        print(file=f)

# %%
# this functions calls the col_only_list() or cat_and_col_list() based on input query requirements
# it recieves a list of tbales with one or more columns matching with input schema and if categories involved then 75% category cos similarity with input schema
# then we check for 75% column cosine cimilarity score and return a list of all tables having 75% column cosine similarity score
def check_possible_matches():
    input_sch_onto=generate_schema_ontology(input_schema)
    if input_categories==-1:
        print('only schema')
        possible_tables=col_only_list(input_schema,input_sch_onto)
    else:
        print('category and schema\n')
        input_cat_onto=generate_list_ontology(input_categories)
        possible_tables=cat_and_col_list(input_categories,input_cat_onto,input_schema,input_sch_onto)
    matching_tables={}
    print("Columns cosine similarity values that are greater than 75% :")
    print("File Name\t\tcolumn cos similarity value")
    for i in possible_tables:
        cos_val=cos_sim(possible_tables[i],list(input_schema))
        if cos_val>0.75:
            print(i,"\t\t",cos_val)
            matching_tables[i]=possible_tables[i]
    print()
    return matching_tables

# %%
# the main function that is to be invoked and will call all the required functions to obtain the required matches and merges
# we have a list with all possible tables that are matches
# we generate all combinations of them in order to merge them
# a valid combination is one where every pair of tables have 50% cosine column and category similarity
# then we merge them and calculate the coverage score, null score and the completeness score
# all these details are displayed for each of the valid merges as well as individual tables
# the output is displayed in the output file "results.txt" along with the outputs in csv form
def get_matches():
    global comp_score
    global no_of_rows
    global ctr
    comp_score={}
    no_of_rows={}
    matching_tables_dict=check_possible_matches()
    matching_tables=list(matching_tables_dict)
    with open("demo/results.txt",'a') as f:
        print('******************************',file=f)
        print(file=f)
        print("All Possible Matches",file=f)
        print(file=f)
        print("Matching Tables : ",matching_tables,file=f)
        print("Matching Tables : ",matching_tables)
        for i in matching_tables:
            print(i,'\t',all_tablenames[i])
        if transformations==-1:
            print("\nNo Transformations In Input Schema",file=f)
            print(file=f)
        else:
            print('\nTransformations detected from input are : ',transformations,file=f)
            print(file=f)
    op_str1='demo/'
    op_str2='.csv'
    x=len(matching_tables)
    print(matching_tables)
    if x==0:
        with open("demo/results.txt",'a') as f:
            print("NO MATCHES FOUND",file=f)
            print(file=f)
    elif x==1:
        display_individual_matches(matching_tables,matching_tables_dict)
    elif x==2:
        a=matching_tables[0]+' : '+matching_tables[1]
        b=matching_tables[1]+' : '+matching_tables[0]
        if (a in cat_sim) or (b in cat_sim):
            if (cat_sim[a]>.50 and col_sim[a]>0.50) or (cat_sim[b]>.50 and col_sim[b]>0.50):
                ctr+=1
                res=res=merge_list([matching_tables[0],matching_tables[1]])
                op_string=op_str1+str(ctr)+op_str2
                res.to_csv(op_string,sep=',', index=False)
                cols=res.columns
                cov,comp=coverage_and_completeness(res)
                with open("demo/results.txt",'a') as f:
                    print(op_string,file=f)
                    if transformations!=-1:
                        l=get_possible_transformations(cols)
                        print("possible transformations are : ",l,file=f)
                    print('Missing Values(NANs): ',nan_score(table=res),file=f)
                    print("Columns that match with input_schema: ",file=f)
                    for j in matching_tables:
                        print(j+' : ',matching_tables_dict[j],file=f)
                    print("Coverage Score : ",cov,"\t Completeness Score : ",comp,"\t Number of Rows : ",len(res),file=f)
                    no_of_rows["output_"+str(ctr)+op_str2]=len(res)
                    if comp in comp_score:
                        comp_score[comp].append("output_"+str(ctr)+op_str2)
                    else:
                        comp_score[comp]=[]
                        comp_score[comp].append("output_"+str(ctr)+op_str2)
                    print(file=f)
        display_individual_matches(matching_tables,matching_tables_dict)
    else:
        count_comb=len(matching_tables)
        all_combos=generate_all_combinations(matching_tables)
        for i in range(count_comb,1,-1):
            for l in all_combos[i]:
                a=list(l)
                comb=list(combinations(a,2))
                flag=0
                for pair in comb:
                    if flag==0:
                        t1,t2=pair
                        if ((t1+' : '+t2) in cat_sim):
                            if (cat_sim[t1+' : '+t2]>=.50 and col_sim[t1+' : '+t2]>=0.50):
                                pass
                            else:
                                flag=1
                        else:
                            flag=1
                    else:
                        break
                if flag==0:
                    res=merge_list(a)
                    ctr+=1
                    op_string=op_str1+str(ctr)+op_str2
                    res.to_csv(op_string,sep=',', index=False)
                    cols=res.columns
                    cov,comp=coverage_and_completeness(res)
                    with open("demo/results.txt",'a') as f:
                        print(str(ctr)+op_str2+' : ',end='',file=f)
                        for j in a:
                            print(j+"("+all_tablenames[j]+")"+'\t\t',end='',file=f)
                        print(file=f)
                        if transformations!=-1:
                            l=get_possible_transformations(cols)
                            print("possible transformations are : ",l,file=f)
                        print('Missing Values(NANs): ',nan_score(table=res),file=f)
                        print("Columns that match with input_schema: ",file=f)
                        for j in a:
                            print(j+' : ',matching_tables_dict[j],file=f)
                        print("Coverage Score : ",cov,"\t Completeness Score : ",comp,"\t Number of Rows : ",len(res),file=f)
                        no_of_rows["output_"+str(ctr)+op_str2]=len(res)
                        if comp in comp_score:
                            comp_score[comp].append("output_"+str(ctr)+op_str2)
                        else:
                            comp_score[comp]=[]
                            comp_score[comp].append("output_"+str(ctr)+op_str2)
                        print(file=f)
        display_individual_matches(matching_tables,matching_tables_dict)
    with open("demo/results.txt",'a') as f:
        print('******************************',file=f)
    ranking_display(comp_score,no_of_rows)

# %%
ctr=0
comp_score={}
no_of_rows={}
with open("demo_inputs.txt") as ip_file:
    count=0
    for line in ip_file.readlines():
        ip_schema=json.loads(line)
        count+=1
        print("INPUT "+str(count))
        print(line)
        input_schema=ip_schema["schema"]
        if "categories" in ip_schema:
            input_categories=ip_schema["categories"]
        else:
            input_categories=-1
        if "transformations" in ip_schema:
            transformations=ip_schema["transformations"]
        else:
            transformations=-1
        with open("demo/results.txt",'a') as f:
            print("-------------------------------",file=f)
            print("INPUT "+str(count),file=f)
            print("Input Schema : ",file=f)
            print(line,file=f)
        get_matches()
        with open("demo/results.txt",'a') as f:
            print("-------------------------------",file=f)
# Out:
# INPUT 1
# {"schema": {"Round": "int64", "Round.1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"}}
#
# only schema
# Columns cosine similarity values that are greater than 75% :
# File Name		column cos similarity value
# 203_408.csv 		 0.7559289460184544
# 203_514.csv 		 0.8451542547285165
# 204_253.csv 		 0.9258200997725514
# 204_40.csv 		 0.9258200997725514
# 204_455.csv 		 0.7559289460184544
# 204_569.csv 		 0.9999999999999999
# 204_63.csv 		 0.7559289460184544
#
# Matching Tables :  ['203_408.csv', '203_514.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv']
# 203_408.csv 	 1989 Formula One season
# 203_514.csv 	 2008 Superleague Formula season
# 204_253.csv 	 1990 Superbike World Championship season
# 204_40.csv 	 2008 Superbike World Championship season
# 204_455.csv 	 1989 Formula One season
# 204_569.csv 	 1998 Swedish Touring Car Championship season
# 204_63.csv 	 2002 Italian Formula Three season
# ['203_408.csv', '203_514.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv']
#
# Rank 1 :  204_569.csv 		completeness score :  0.9285714285714286 		number of rows:  12
# Rank 2 :  output_8.csv 		completeness score :  0.8796992481203008 		number of rows:  38
# Rank 3 :  output_10.csv 		completeness score :  0.8785714285714284 		number of rows:  40
# Rank 4 :  output_2.csv 		completeness score :  0.8701298701298701 		number of rows:  66
# Rank 5 :  output_7.csv 		completeness score :  0.8571428571428571 		number of rows:  54
# Rank 6 :  204_40.csv 		completeness score :  0.8571428571428571 		number of rows:  28
# Rank 7 :  204_253.csv 		completeness score :  0.8571428571428571 		number of rows:  26
# Rank 8 :  output_1.csv 		completeness score :  0.8241758241758241 		number of rows:  52
# Rank 9 :  output_3.csv 		completeness score :  0.8206686930091186 		number of rows:  47
# Rank 10 :  output_5.csv 		completeness score :  0.7928571428571428 		number of rows:  40
# Rank 11 :  output_6.csv 		completeness score :  0.7857142857142857 		number of rows:  24
# Rank 12 :  output_9.csv 		completeness score :  0.7836734693877551 		number of rows:  35
# Rank 13 :  output_11.csv 		completeness score :  0.7755102040816325 		number of rows:  21
# Rank 14 :  203_514.csv 		completeness score :  0.6428571428571429 		number of rows:  12
# Rank 15 :  output_4.csv 		completeness score :  0.5714285714285714 		number of rows:  16
# Rank 16 :  203_408.csv 		completeness score :  0.5714285714285714 		number of rows:  16
# Rank 17 :  204_455.csv 		completeness score :  0.5714285714285714 		number of rows:  16
# Rank 18 :  204_63.csv 		completeness score :  0.5714285714285714 		number of rows:  9
#
# Ranking Complete!!
#
# INPUT 2
# {"schema": {"Round": "int64", "Round.1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"},"categories": ["motorsport", "car", "seasons"]}
#
# category and schema
#
# Category cosine similarity values that are greater than 75% :
# File Name		category cos similarity value
# 203_101.csv 		 0.8164965809277259
# 203_142.csv 		 0.8164965809277259
# 203_181.csv 		 1.0000000000000002
# 203_218.csv 		 0.8164965809277259
# 203_271.csv 		 0.8164965809277259
# 203_399.csv 		 0.8164965809277259
# 203_514.csv 		 0.8164965809277259
# 203_704.csv 		 0.8164965809277259
# 203_742.csv 		 1.0000000000000002
# 203_761.csv 		 0.8164965809277259
# 204_137.csv 		 0.8164965809277259
# 204_210.csv 		 0.8164965809277259
# 204_253.csv 		 0.8164965809277259
# 204_305.csv 		 0.8164965809277259
# 204_496.csv 		 0.8164965809277259
# 204_531.csv 		 1.0000000000000002
# 204_569.csv 		 1.0000000000000002
# 204_63.csv 		 0.8164965809277259
# 204_630.csv 		 0.8164965809277259
# 204_808.csv 		 0.8164965809277259
#
# Columns cosine similarity values that are greater than 75% :
# File Name		column cos similarity value
# 203_514.csv 		 0.8451542547285165
# 204_253.csv 		 0.9258200997725514
# 204_569.csv 		 0.9999999999999999
# 204_63.csv 		 0.7559289460184544
#
# Matching Tables :  ['203_514.csv', '204_253.csv', '204_569.csv', '204_63.csv']
# 203_514.csv 	 2008 Superleague Formula season
# 204_253.csv 	 1990 Superbike World Championship season
# 204_569.csv 	 1998 Swedish Touring Car Championship season
# 204_63.csv 	 2002 Italian Formula Three season
# ['203_514.csv', '204_253.csv', '204_569.csv', '204_63.csv']
#
# Rank 1 :  204_569.csv 		completeness score :  0.9285714285714286 		number of rows:  12
# Rank 2 :  output_14.csv 		completeness score :  0.8796992481203008 		number of rows:  38
# Rank 3 :  204_253.csv 		completeness score :  0.8571428571428571 		number of rows:  26
# Rank 4 :  output_12.csv 		completeness score :  0.8206686930091186 		number of rows:  47
# Rank 5 :  output_13.csv 		completeness score :  0.7857142857142857 		number of rows:  24
# Rank 6 :  output_15.csv 		completeness score :  0.7836734693877551 		number of rows:  35
# Rank 7 :  output_16.csv 		completeness score :  0.7755102040816325 		number of rows:  21
# Rank 8 :  203_514.csv 		completeness score :  0.6428571428571429 		number of rows:  12
# Rank 9 :  204_63.csv 		completeness score :  0.5714285714285714 		number of rows:  9
#
# Ranking Complete!!
#
# INPUT 3
# {"schema": {"Date": "object", "Nationality": "object", "Tonnage (GRT)": "int64", "Fate": "object"},"transformations":{"Tonnage (GRT)":["sum"],"Nationality":["funct1"]}}
#
# only schema
# Columns cosine similarity values that are greater than 75% :
# File Name		column cos similarity value
# 202_117.csv 		 0.8660254037844387
# 203_148.csv 		 1.0
# 203_268.csv 		 1.0
# 204_100.csv 		 0.8660254037844387
#
# Matching Tables :  ['202_117.csv', '203_148.csv', '203_268.csv', '204_100.csv']
# 202_117.csv 	 German submarine U-559
# 203_148.csv 	 German submarine U-9 (1935)
# 203_268.csv 	 German submarine U-502
# 204_100.csv 	 Hans-Rudolf Rosing
# ['202_117.csv', '203_148.csv', '203_268.csv', '204_100.csv']
#
# Rank 1 :  output_20.csv 		completeness score :  1.0 		number of rows:  25
# Rank 2 :  203_268.csv 		completeness score :  1.0 		number of rows:  16
# Rank 3 :  203_148.csv 		completeness score :  1.0 		number of rows:  9
# Rank 4 :  output_17.csv 		completeness score :  0.9516129032258065 		number of rows:  31
# Rank 5 :  output_19.csv 		completeness score :  0.9318181818181819 		number of rows:  22
# Rank 6 :  output_18.csv 		completeness score :  0.9 		number of rows:  15
# Rank 7 :  204_100.csv 		completeness score :  0.75 		number of rows:  13
# Rank 8 :  202_117.csv 		completeness score :  0.75 		number of rows:  6
#
# Ranking Complete!!
#
# INPUT 4
# {"schema": {"Date": "object", "Nationality": "object", "Tonnage (GRT)": "int64", "Fate": "object"},"transformations":{"Tonnage (GRT)":["sum","avg"],"Nationality":["funct1"]},"categories":["submarines", "war", "ships", "sea", "aircraft", "germany", "shipwrecks", "maritime", "world", "german", "sunk", "navy", "uboats"]}
# category and schema
#
# Category cosine similarity values that are greater than 75% :
# File Name		category cos similarity value
# 202_117.csv 		 0.8770580193070293
# 203_148.csv 		 1.0000000000000002
# 203_268.csv 		 0.960768922830523
#
# Columns cosine similarity values that are greater than 75% :
# File Name		column cos similarity value
# 202_117.csv 		 0.8660254037844387
# 203_148.csv 		 1.0
# 203_268.csv 		 1.0
#
# Matching Tables :  ['202_117.csv', '203_148.csv', '203_268.csv']
# 202_117.csv 	 German submarine U-559
# 203_148.csv 	 German submarine U-9 (1935)
# 203_268.csv 	 German submarine U-502
# ['202_117.csv', '203_148.csv', '203_268.csv']
#
# Rank 1 :  output_24.csv 		completeness score :  1.0 		number of rows:  25
# Rank 2 :  203_268.csv 		completeness score :  1.0 		number of rows:  16
# Rank 3 :  203_148.csv 		completeness score :  1.0 		number of rows:  9
# Rank 4 :  output_21.csv 		completeness score :  0.9516129032258065 		number of rows:  31
# Rank 5 :  output_23.csv 		completeness score :  0.9318181818181819 		number of rows:  22
# Rank 6 :  output_22.csv 		completeness score :  0.9 		number of rows:  15
# Rank 7 :  202_117.csv 		completeness score :  0.75 		number of rows:  6
#
# Ranking Complete!!

# %%
input_schema={"Round": "int64", "Round.1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"}
input_categories=-1
transformations=-1
comp_score={}
no_of_rows={}
matching_tables_dict=check_possible_matches()
matching_tables=list(matching_tables_dict)
print(matching_tables,matching_tables_dict)
display_individual_matches(matching_tables,matching_tables_dict)
ranking_display(comp_score,no_of_rows)
# Out:
# only schema
# Columns cosine similarity values that are greater than 75% :
# File Name		column cos similarity value
# 203_408.csv 		 0.7559289460184544
# 203_514.csv 		 0.8451542547285165
# 204_253.csv 		 0.9258200997725514
# 204_40.csv 		 0.9258200997725514
# 204_455.csv 		 0.7559289460184544
# 204_569.csv 		 0.9999999999999999
# 204_63.csv 		 0.7559289460184544
#
# ['203_408.csv', '203_514.csv', '204_253.csv', '204_40.csv', '204_455.csv', '204_569.csv', '204_63.csv'] {'203_408.csv': ['Date', 'Pole Position', 'Fastest Lap', 'Winning Driver'], '203_514.csv': ['Round', 'Round.1', 'Date', 'Pole Position', 'Fastest Lap'], '204_253.csv': ['Round', 'Round.1', 'Circuit', 'Date', 'Pole Position', 'Fastest Lap'], '204_40.csv': ['Round', 'Round.1', 'Circuit', 'Date', 'Pole Position', 'Fastest Lap'], '204_455.csv': ['Date', 'Pole Position', 'Fastest Lap', 'Winning Driver'], '204_569.csv': ['Round', 'Round.1', 'Circuit', 'Date', 'Pole Position', 'Fastest Lap', 'Winning Driver'], '204_63.csv': ['Round', 'Circuit', 'Date', 'Pole Position']}
#
# Rank 1 :  204_569.csv 		completeness score :  0.9285714285714286 		number of rows:  12
# Rank 2 :  204_40.csv 		completeness score :  0.8571428571428571 		number of rows:  28
# Rank 3 :  204_253.csv 		completeness score :  0.8571428571428571 		number of rows:  26
# Rank 4 :  203_514.csv 		completeness score :  0.6428571428571429 		number of rows:  12
# Rank 5 :  203_408.csv 		completeness score :  0.5714285714285714 		number of rows:  16
# Rank 6 :  204_455.csv 		completeness score :  0.5714285714285714 		number of rows:  16
# Rank 7 :  204_63.csv 		completeness score :  0.5714285714285714 		number of rows:  9
#
# Ranking Complete!!

# %%
input_schema={"Round": "int64", "Round.1": "object", "Circuit": "object", "Date": "object", "Pole Position": "object", "Fastest Lap": "object", "Winning Driver": "object"}

# %%
pd.read_csv("demo/12.csv")
# Out:
#     Round Round.1                                     Circuit          Date  \
# 0       1      R1                                       Jerez      18 March
# 1       1      R2                                       Jerez      18 March
# 2       2      R1                                   Donington      16 April
# 3       2      R2                                   Donington      16 April
# 4       3      R1                                 Hungaroring      30 April
# 5       3      R2                                 Hungaroring      30 April
# 6       4      R1                                  Hockenheim         6 May
# 7       4      R2                                  Hockenheim         6 May
# 8       5      R1                                     Mosport        3 June
# 9       5      R2                                     Mosport        3 June
# 10      6      R1                                    Brainerd       10 June
# 11      6      R2                                    Brainerd       10 June
# 12      7      R1                              Österreichring        1 July
# 13      7      R2                              Österreichring        1 July
# 14      8      R1                                        Sugo     26 August
# 15      8      R2                                        Sugo     26 August
# 16      9      R1                                     Le Mans   9 September
# 17      9      R2                                     Le Mans   9 September
# 18     10      R1                                       Monza     7 October
# 19     10      R2                                       Monza     7 October
# 20     11      R1                                   Shah Alam    4 November
# 21     11      R2                                   Shah Alam    4 November
# 22     12      R1                              Phillip Island   11 November
# 23     12      R2                              Phillip Island   11 November
# 24     13      R1                                    Manfeild   18 November
# 25     13      R2                                    Manfeild   18 November
# 26      1      R1                                Mantorp Park        10 May
# 27      1      R2                                Mantorp Park        10 May
# 28      2      R3                        Karlskoga-Gelleråsen        31 May
# 29      2      R4                        Karlskoga-Gelleråsen        31 May
# 30      3      R5                                  Anderstorp       28 June
# 31      3      R6                                  Anderstorp       28 June
# 32      4      R7                                  Falkenberg        9 July
# 33      4      R8                                  Falkenberg        9 July
# 34      5      R9                              Ring Knutstorp   6 September
# 35      5     R10                              Ring Knutstorp   6 September
# 36      6     R11                                Mantorp Park  27 September
# 37      6     R12                                Mantorp Park  27 September
# 38      1     NaN  ACI Vallelunga Circuit, Campagnano di Roma       7 April
# 39      2     NaN                        Misano World Circuit      28 April
# 40      3     NaN                  Autodromo di Pergusa, Enna        19 May
# 41      4     NaN                   Autodromo Nazionale Monza       30 June
# 42      5     NaN          Autodromo Riccardo Paletti, Varano       21 July
# 43      6     NaN        Autodromo Enzo e Dino Ferrari, Imola   1 September
# 44      7     NaN              Autodromo del Levante, Binetto   8 September
# 45      8     NaN                  Mugello Circuit, Scarperia     6 October
# 46      9     NaN              Autodromo dell'Umbria, Magione    20 October
#
#            Pole Position        Fastest Lap      Winning Rider  \
# 0          Raymond Roche   Stephane Mertens      Raymond Roche
# 1          Raymond Roche      Raymond Roche      Raymond Roche
# 2      Giancarlo Falappa        Rob Phillis        Fred Merkel
# 3      Giancarlo Falappa      Raymond Roche  Giancarlo Falappa
# 4       Malcolm Campbell      Raymond Roche        Fred Merkel
# 5       Malcolm Campbell        Fred Merkel      Raymond Roche
# 6          Raymond Roche        Fred Merkel        Fred Merkel
# 7          Raymond Roche      Raymond Roche   Stephane Mertens
# 8      Giancarlo Falappa      Raymond Roche      Raymond Roche
# 9      Giancarlo Falappa        Jamie James      Raymond Roche
# 10         Doug Chandler      Doug Chandler   Stephane Mertens
# 11         Doug Chandler  Fabrizio Pirovano      Doug Chandler
# 12      Stephane Mertens        Rob McElnea  Fabrizio Pirovano
# 13      Stephane Mertens   Stephane Mertens   Stephane Mertens
# 14         Raymond Roche      Raymond Roche      Raymond Roche
# 15         Raymond Roche      Peter Goddard      Doug Chandler
# 16     Baldassarre Monti      Raymond Roche      Raymond Roche
# 17     Baldassarre Monti        Jamie James      Raymond Roche
# 18     Baldassarre Monti        Rob Phillis  Fabrizio Pirovano
# 19     Baldassarre Monti        Rob Phillis  Fabrizio Pirovano
# 20           Rob Phillis  Fabrizio Pirovano  Fabrizio Pirovano
# 21           Rob Phillis      Raymond Roche  Fabrizio Pirovano
# 22         Peter Goddard  Fabrizio Pirovano      Peter Goddard
# 23         Peter Goddard   Malcolm Campbell        Rob Phillis
# 24           Rob Phillis     Brian Morrison        Terry Rymer
# 25           Rob Phillis      Raymond Roche        Rob Phillis
# 26       Mattias Ekström     Fredrik Ekblom                NaN
# 27                   NaN   Peggen Andersson                NaN
# 28           Jan Nilsson        Jan Nilsson                NaN
# 29                   NaN     Fredrik Ekblom                NaN
# 30       Mattias Ekström     Fredrik Ekblom                NaN
# 31                   NaN   Peggen Andersson                NaN
# 32            Jens Edman         Jens Edman                NaN
# 33                   NaN    Mattias Ekström                NaN
# 34        Fredrik Ekblom     Fredrik Ekblom                NaN
# 35                   NaN        Mats Linden                NaN
# 36  Tommy Kristoffersson     Fredrik Ekblom                NaN
# 37                   NaN   Peggen Andersson                NaN
# 38        Miloš Pavlović                NaN                NaN
# 39        Miloš Pavlović                NaN                NaN
# 40        Miloš Pavlović                NaN                NaN
# 41   Philip Cloostermans                NaN                NaN
# 42        Miloš Pavlović                NaN                NaN
# 43     Vitantonio Liuzzi                NaN                NaN
# 44     Christiano Citron                NaN                NaN
# 45        Miloš Pavlović                NaN                NaN
# 46         Andreas Zuber                NaN                NaN
#
#       Winning Driver               Winning Team  Winning Privateer  \
# 0                NaN                        NaN                NaN
# 1                NaN                        NaN                NaN
# 2                NaN                        NaN                NaN
# 3                NaN                        NaN                NaN
# 4                NaN                        NaN                NaN
# 5                NaN                        NaN                NaN
# 6                NaN                        NaN                NaN
# 7                NaN                        NaN                NaN
# 8                NaN                        NaN                NaN
# 9                NaN                        NaN                NaN
# 10               NaN                        NaN                NaN
# 11               NaN                        NaN                NaN
# 12               NaN                        NaN                NaN
# 13               NaN                        NaN                NaN
# 14               NaN                        NaN                NaN
# 15               NaN                        NaN                NaN
# 16               NaN                        NaN                NaN
# 17               NaN                        NaN                NaN
# 18               NaN                        NaN                NaN
# 19               NaN                        NaN                NaN
# 20               NaN                        NaN                NaN
# 21               NaN                        NaN                NaN
# 22               NaN                        NaN                NaN
# 23               NaN                        NaN                NaN
# 24               NaN                        NaN                NaN
# 25               NaN                        NaN                NaN
# 26       Mats Linden  Kristoffersson Motorsport  Richard Göransson
# 27    Fredrik Ekblom            BMW Dealer Team       Pontus Mörth
# 28       Jan Nilsson          Flash Engineering       Pontus Mörth
# 29  Peggen Andersson            BMW Dealer Team       Pontus Mörth
# 30       Jan Nilsson          Flash Engineering       Pontus Mörth
# 31  Peggen Andersson            BMW Dealer Team      Georg Bakajev
# 32       Jan Nilsson          Flash Engineering       Pontus Mörth
# 33        Jens Edman          Flash Engineering       Pontus Mörth
# 34    Fredrik Ekblom            BMW Dealer Team       Pontus Mörth
# 35       Jan Nilsson          Flash Engineering      Georg Bakajev
# 36    Fredrik Ekblom            BMW Dealer Team       Pontus Mörth
# 37       Jan Nilsson          Flash Engineering       Pontus Mörth
# 38               NaN                        NaN                NaN
# 39               NaN                        NaN                NaN
# 40               NaN                        NaN                NaN
# 41               NaN                        NaN                NaN
# 42               NaN                        NaN                NaN
# 43               NaN                        NaN                NaN
# 44               NaN                        NaN                NaN
# 45               NaN                        NaN                NaN
# 46               NaN                        NaN                NaN
#
#          Winning driver            Winning team      Trophy winner
# 0                   NaN                     NaN                NaN
# 1                   NaN                     NaN                NaN
# 2                   NaN                     NaN                NaN
# 3                   NaN                     NaN                NaN
# 4                   NaN                     NaN                NaN
# 5                   NaN                     NaN                NaN
# 6                   NaN                     NaN                NaN
# 7                   NaN                     NaN                NaN
# 8                   NaN                     NaN                NaN
# 9                   NaN                     NaN                NaN
# 10                  NaN                     NaN                NaN
# 11                  NaN                     NaN                NaN
# 12                  NaN                     NaN                NaN
# 13                  NaN                     NaN                NaN
# 14                  NaN                     NaN                NaN
# 15                  NaN                     NaN                NaN
# 16                  NaN                     NaN                NaN
# 17                  NaN                     NaN                NaN
# 18                  NaN                     NaN                NaN
# 19                  NaN                     NaN                NaN
# 20                  NaN                     NaN                NaN
# 21                  NaN                     NaN                NaN
# 22                  NaN                     NaN                NaN
# 23                  NaN                     NaN                NaN
# 24                  NaN                     NaN                NaN
# 25                  NaN                     NaN                NaN
# 26                  NaN                     NaN                NaN
# 27                  NaN                     NaN                NaN
# 28                  NaN                     NaN                NaN
# 29                  NaN                     NaN                NaN
# 30                  NaN                     NaN                NaN
# 31                  NaN                     NaN                NaN
# 32                  NaN                     NaN                NaN
# 33                  NaN                     NaN                NaN
# 34                  NaN                     NaN                NaN
# 35                  NaN                     NaN                NaN
# 36                  NaN                     NaN                NaN
# 37                  NaN                     NaN                NaN
# 38       Miloš Pavlović           Target Racing          Nino Famà
# 39       Miloš Pavlović           Target Racing  Giovanni Faraonio
# 40  Philip Cloostermans            Azeta Racing   Carmine Tancredi
# 41  Philip Cloostermans            Azeta Racing   Carmine Tancredi
# 42       Miloš Pavlović           Target Racing   Carmine Tancredi
# 43    Vitantonio Liuzzi  Bertram Schäfer Racing     Silvio Alberti
# 44       Miloš Pavlović           Target Racing   Carmine Tancredi
# 45       Miloš Pavlović           Target Racing      Dino Lusuardi
# 46    Christiano Citron           Target Racing    Alberto Morelli

# %%
d={"1":"2","2":"3",4:5,6:7}
e={"1":"2","2":"3",4:'5',6:7}

# %%
d==e
# Out:
# False

# %%
print("21.csv : 202_117.csv(German submarine U-559)   203_148.csv(German submarine U-9 (1935))   203_268.csv(German submarine U-502)\npossible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}\n22.csv : 202_117.csv(German submarine U-559)		203_148.csv(German submarine U-9 (1935))\npossible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}\n23.csv : 202_117.csv(German submarine U-559)		203_268.csv(German submarine U-502)\npossible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}\n24.csv : 203_148.csv(German submarine U-9 (1935))		203_268.csv(German submarine U-502)	\npossible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['funct1']}\n202_117.csv(German submarine U-559)\npossible transformations are :  {'Nationality': ['substring']}\n203_148.csv(German submarine U-9 (1935))\npossible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['funct1']}")
# Out:
# 21.csv : 202_117.csv(German submarine U-559)   203_148.csv(German submarine U-9 (1935))   203_268.csv(German submarine U-502)
# possible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}
# 22.csv : 202_117.csv(German submarine U-559)		203_148.csv(German submarine U-9 (1935))
# possible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}
# 23.csv : 202_117.csv(German submarine U-559)		203_268.csv(German submarine U-502)
# possible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['substring']}
# 24.csv : 203_148.csv(German submarine U-9 (1935))		203_268.csv(German submarine U-502)
# possible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['funct1']}
# 202_117.csv(German submarine U-559)
# possible transformations are :  {'Nationality': ['substring']}
# 203_148.csv(German submarine U-9 (1935))
# possible transformations are :  {'Tonnage (GRT)': ['sum', 'avg'], 'Nationality': ['funct1']}
